# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import numpy as np
import tensorflow as tf
import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:24, 369kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

np.random.seed(100)

def sub_sampling(int_words, threshold):
    w_counter = Counter(int_words)
    t_count = len(int_words)
    freqs = {word: count/t_count for word, count in w_counter.items()}
    p_drop = {word: (1 - np.sqrt(threshold/freqs[word])) for word in w_counter}
    tr_words = [word for word in int_words if p_drop[word] < np.random.random()]
    return tr_words

train_words = sub_sampling(int_words, threshold = 1e-5 )

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs)    # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab)) 
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-13-0352002820d4>:15: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6484 0.0900 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6121 0.0526 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4571 0.0523 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6022 0.0520 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5038 0.0534 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5305 0.0524 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5388 0.0526 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5227 0.0529 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4813 0.0534 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4152 0.0517 sec/batch
# Nearest to been: compounded, refine, miscellaneous, alcan, israelis, cinereus, amphitheatre, trapdoor,
# Nearest to war: perfumery, khoisan, him, additivity, yukon, microcode, hui, misfit,
# Nearest to between: clansman, abnormally, canister, to, syndicalist, hardest, maru, gilpin,
# Nearest to up: marvellous, lu, teg, imc, cpes, petitions, exits, reestablishing,
# Nearest to has: cpan, veganism, birger, follow, legrand, retailing, dinners, encode,
# Nearest to may: hamas, relena, rutskoy, sieves, spoiling, viability, harmonizing, connoisseur,
# Nearest to he: maternally, weimar, chugach, monde, stefan, resent, unplugged, vila,
# Nearest to time: cadillac, electrochemical, torres, longest, butyrate, superboy, fullness, diena,
# Nearest to lived: mirth, foreseen, sizeof, orexin, albi, cement, portraiture, incumbent,
# Nearest to know: limbaugh, spectacular, enchanter, myocardial, immunology, laird, thuringiensis, bic,
# Nearest to instance: yung, queene, praeparatio, pacman, lupin, methyl, operating, bulbous,
# Nearest to primarily: straight, capacitive, mim, hironaka, sliders, childless, manoeuvre, caldera,
# Nearest to pressure: woken, atle, donne, devotes, marysville, missy, moorgate, services,
# Nearest to versions: rsdlp, dame, criollos, patronymic, findable, rudimentary, stock, schillinger,
# Nearest to troops: swayed, continuously, transcended, bullpen, redundant, pentatonic, slays, dissonances,
# Nearest to ice: complete, catapult, modulus, animalium, algorism, radiocommunications, mazovia, cdot,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4902 0.0565 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3926 0.0524 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3159 0.0521 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2432 0.0517 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1674 0.0518 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1364 0.0518 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1051 0.0517 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0386 0.0518 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0160 0.0526 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9732 0.0521 sec/batch
# Nearest to been: refine, differs, miscellaneous, never, really, compounded, standard, alcan,
# Nearest to war: him, on, m, resigned, microcode, plagued, yukon, molecular,
# Nearest to between: to, abnormally, clansman, critical, hardest, canister, syndicalist, kinetochores,
# Nearest to up: lu, supported, teg, marvellous, knopf, unofficial, disagreed, ultimately,
# Nearest to has: follow, therefore, cpan, veganism, wouldn, favor, encode, legrand,
# Nearest to may: therefore, virtual, sieves, viability, rutskoy, harmonizing, hamas, relena,
# Nearest to he: maternally, chugach, weimar, htm, monde, turing, tensile, sari,
# Nearest to time: longest, electrochemical, pre, torres, controllers, therein, assumed, fullness,
# Nearest to lived: mirth, albi, verdun, cement, incumbent, foreseen, portraiture, toxicity,
# Nearest to know: spectacular, rolling, immunology, annually, eminent, descendant, enchanter, kinetochores,
# Nearest to instance: operating, yung, minerals, late, spread, larger, jahwist, methyl,
# Nearest to primarily: straight, capacitive, commonly, toppling, caldera, discrete, speed, sliders,
# Nearest to pressure: demands, services, employed, atle, devotes, cements, meagre, mml,
# Nearest to versions: dame, rsdlp, notes, stock, usually, rudimentary, inland, findable,
# Nearest to troops: continuously, bullpen, transcended, swayed, redundant, designing, slays, pentatonic,
# Nearest to ice: complete, detailed, cdot, completed, wolves, modulus, algorism, nm,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9353 0.0538 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8869 0.0517 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8915 0.0522 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8540 0.0517 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8163 0.0518 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8278 0.0519 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8081 0.0516 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7770 0.0520 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7703 0.0517 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7882 0.0518 sec/batch
# Nearest to been: miscellaneous, compounded, refine, attitude, alcan, never, israelis, differs,
# Nearest to war: him, on, resigned, sustainability, microcode, accept, plagued, bought,
# Nearest to between: abnormally, clansman, to, critical, atlantic, syndicalist, canister, hardest,
# Nearest to up: lu, marvellous, teg, disloyalty, reestablishing, supported, petitions, sophistication,
# Nearest to has: follow, wouldn, therefore, veganism, cpan, encode, poetic, adhere,
# Nearest to may: sieves, therefore, viability, virtual, hamas, relena, harmonizing, rutskoy,
# Nearest to he: weimar, maternally, monde, chugach, htm, damned, turing, stefan,
# Nearest to time: longest, electrochemical, prussia, fullness, torres, cadillac, pre, fares,
# Nearest to lived: mirth, albi, incumbent, verdun, caching, elven, toxicity, foreseen,
# Nearest to know: spectacular, annually, descendant, enchanter, eminent, limbaugh, pronunciations, appealing,
# Nearest to instance: operating, yung, minerals, kiln, methyl, jahwist, kuhn, larger,
# Nearest to primarily: straight, capacitive, commonly, toppling, discrete, childless, caldera, manoeuvre,
# Nearest to pressure: services, demands, employed, devotes, atle, culminating, correcting, disturbance,
# Nearest to versions: dame, rsdlp, stock, notes, criollos, rudimentary, usually, rewrote,
# Nearest to troops: continuously, bullpen, transcended, profound, redundant, swayed, simultaneous, designing,
# Nearest to ice: complete, modulus, algorism, herrick, elicit, cdot, catapult, radiocommunications,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7595 0.0537 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7633 0.0516 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6971 0.0514 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7106 0.0521 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7392 0.0521 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7030 0.0521 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7080 0.0516 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7151 0.0517 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7076 0.0516 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6665 0.0518 sec/batch
# Nearest to been: refine, miscellaneous, compounded, alcan, israelis, never, attitude, really,
# Nearest to war: him, resigned, noam, on, khoisan, assimilate, plagued, microcode,
# Nearest to between: abnormally, clansman, critical, atlantic, syndicalist, to, canister, cooperates,
# Nearest to up: lu, marvellous, reestablishing, teg, sophistication, disloyalty, petitions, disagreed,
# Nearest to has: encode, follow, retailing, wouldn, veganism, cpan, adhere, therefore,
# Nearest to may: hamas, viability, therefore, sieves, shaping, relena, onslaught, virtual,
# Nearest to he: monde, weimar, maternally, chugach, htm, damned, resent, turing,
# Nearest to time: longest, cadillac, electrochemical, prussia, torres, fares, quakers, fullness,
# Nearest to lived: mirth, albi, verdun, incumbent, caching, elven, portraiture, tempel,
# Nearest to know: spectacular, thuringiensis, enchanter, annually, pronunciations, descendant, interventions, depend,
# Nearest to instance: operating, yung, minerals, kiln, methyl, jahwist, mediating, cyclic,
# Nearest to primarily: straight, capacitive, manoeuvre, dili, commonly, sliders, childless, toppling,
# Nearest to pressure: services, demands, devotes, correcting, disturbance, meagre, receptors, atle,
# Nearest to versions: rsdlp, dame, stock, notes, majestic, rudimentary, criollos, usually,
# Nearest to troops: bullpen, transcended, continuously, slays, simultaneous, daimlerchrysler, redundant, swayed,
# Nearest to ice: algorism, complete, elicit, catapult, modulus, herrick, radiocommunications, gi,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6760 0.0540 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6665 0.0522 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6191 0.0517 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6251 0.0522 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6207 0.0519 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6497 0.0517 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5919 0.0381 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5366 0.0518 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5390 0.0521 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4920 0.0518 sec/batch
# Nearest to been: refine, attitude, miscellaneous, israelis, never, alcan, solon, compounded,
# Nearest to war: resigned, him, khoisan, milt, noam, christy, plagued, hui,
# Nearest to between: abnormally, to, clansman, critical, cooperates, syndicalist, implosive, canister,
# Nearest to up: marvellous, lu, teg, reestablishing, sophistication, petitions, sheds, disloyalty,
# Nearest to has: encode, follow, therefore, retailing, veganism, level, cpan, adhere,
# Nearest to may: hamas, sieves, therefore, viability, virtual, shaping, rutskoy, onslaught,
# Nearest to he: monde, weimar, maternally, chugach, resent, father, htm, turing,
# Nearest to time: cadillac, electrochemical, longest, pre, fullness, fares, assistance, prussia,
# Nearest to lived: mirth, albi, verdun, incumbent, elven, tempel, foreseen, portraiture,
# Nearest to know: spectacular, thuringiensis, enchanter, word, depend, dozens, interventions, occuring,
# Nearest to instance: operating, methyl, kiln, minerals, yung, finite, jahwist, cyclic,
# Nearest to primarily: straight, toppling, manoeuvre, commonly, dili, capacitive, childless, caldera,
# Nearest to pressure: services, devotes, correcting, demands, receptors, disturbance, meagre, metastable,
# Nearest to versions: rsdlp, usually, majestic, dame, stock, notes, rudimentary, side,
# Nearest to troops: bullpen, transcended, parrish, daimlerchrysler, deprived, slays, rebound, initiative,
# Nearest to ice: algorism, elicit, catapult, herrick, complete, radiocommunications, nm, mali,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5099 0.0544 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5061 0.0523 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4408 0.0520 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5101 0.0515 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5130 0.0519 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4910 0.0514 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4550 0.0526 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3844 0.0516 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4172 0.0518 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4341 0.0517 sec/batch
# Nearest to been: israelis, attitude, refine, never, compounded, miscellaneous, solon, alcan,
# Nearest to war: resigned, khoisan, him, milt, assimilate, troops, christy, interned,
# Nearest to between: to, clansman, migrated, atlantic, critical, syndicalist, abnormally, canister,
# Nearest to up: marvellous, reestablishing, lu, teg, petitions, bouzouki, sheds, sophistication,
# Nearest to has: encode, retailing, therefore, follow, veganism, level, tdma, cpan,
# Nearest to may: sieves, hamas, therefore, virtual, viability, shaping, rutskoy, absorbed,
# Nearest to he: monde, weimar, chugach, father, resent, maternally, harem, episcopacy,
# Nearest to time: cadillac, fullness, longest, electrochemical, quakers, pre, assistance, torres,
# Nearest to lived: mirth, albi, incumbent, elven, foreseen, verdun, muslims, portraiture,
# Nearest to know: enchanter, word, spectacular, thuringiensis, depend, occuring, intelligible, interventions,
# Nearest to instance: operating, cyclic, finite, kiln, methyl, minerals, jahwist, additivity,
# Nearest to primarily: straight, manoeuvre, toppling, commonly, dili, childless, caldera, eec,
# Nearest to pressure: services, receptors, correcting, operate, atf, metastable, meagre, devotes,
# Nearest to versions: rsdlp, usually, majestic, dame, notes, developers, stock, rudimentary,
# Nearest to troops: transcended, bullpen, war, parrish, rebound, daimlerchrysler, slays, initiative,
# Nearest to ice: algorism, catapult, herrick, elicit, nm, carbonate, radiocommunications, gi,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4363 0.0533 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4134 0.0514 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4293 0.0514 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3955 0.0515 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4096 0.0518 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4497 0.0525 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3667 0.0535 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3646 0.0541 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4190 0.0532 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3591 0.0536 sec/batch
# Nearest to been: attitude, israelis, never, refine, compounded, miscellaneous, alcan, interests,
# Nearest to war: resigned, him, assimilate, troops, milt, khoisan, christy, interned,
# Nearest to between: clansman, migrated, critical, to, clustered, canister, syndicalist, notions,
# Nearest to up: marvellous, lu, reestablishing, petitions, sheds, teg, sophistication, moo,
# Nearest to has: retailing, encode, follow, veganism, therefore, level, tdma, jotham,
# Nearest to may: hamas, therefore, sieves, viability, virtual, rutskoy, shaping, objective,
# Nearest to he: weimar, monde, father, chugach, resent, maternally, damned, episcopacy,
# Nearest to time: longest, fullness, torres, inclined, cadillac, quakers, bruises, controllers,
# Nearest to lived: mirth, verdun, albi, muslims, portraiture, incisors, foreseen, incumbent,
# Nearest to know: word, enchanter, thuringiensis, dogmas, depend, kickstart, electrophilic, appealing,
# Nearest to instance: finite, cyclic, kiln, operating, methyl, jahwist, avoided, spheroidal,
# Nearest to primarily: straight, toppling, manoeuvre, dili, commonly, buddhism, caldera, mim,
# Nearest to pressure: services, receptors, correcting, operate, metastable, atf, woken, disturbance,
# Nearest to versions: majestic, rsdlp, usually, notes, dame, developers, criollos, microsoft,
# Nearest to troops: transcended, bullpen, war, daimlerchrysler, initiative, congress, parrish, rebound,
# Nearest to ice: catapult, algorism, herrick, carbonate, nm, elicit, radiocommunications, completed,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3722 0.0548 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4293 0.0543 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3569 0.0528 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3766 0.0528 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3676 0.0523 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.4001 0.0527 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3944 0.0529 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3965 0.0527 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3379 0.0523 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3248 0.0526 sec/batch
# Nearest to been: israelis, attitude, never, miscellaneous, compounded, refine, several, wyoming,
# Nearest to war: resigned, troops, forces, armies, milt, interned, khoisan, assimilate,
# Nearest to between: migrated, clansman, critical, abnormally, clustered, syndicalist, implosive, atlantic,
# Nearest to up: marvellous, reestablishing, lu, teg, sheds, petitions, cpes, knee,
# Nearest to has: veganism, encode, retailing, follow, tdma, level, therefore, parliamentarism,
# Nearest to may: hamas, therefore, rutskoy, viability, sieves, shaping, absorbed, objective,
# Nearest to he: weimar, father, resent, monde, chugach, damned, besieges, maternally,
# Nearest to time: longest, fullness, cadillac, inclined, torres, rosary, havilland, bruises,
# Nearest to lived: mirth, verdun, travers, muslims, eastern, incisors, elven, albi,
# Nearest to know: word, dogmas, enchanter, kickstart, thuringiensis, descendant, depend, electrophilic,
# Nearest to instance: finite, cyclic, operating, methyl, jahwist, yung, kiln, spheroidal,
# Nearest to primarily: straight, dili, toppling, manoeuvre, caldera, commonly, buddhism, capacitive,
# Nearest to pressure: woken, receptors, gases, services, metastable, meagre, electro, atf,
# Nearest to versions: majestic, rsdlp, microsoft, developers, notes, usually, dame, graphic,
# Nearest to troops: war, transcended, civilians, bullpen, initiative, seizing, congress, slays,
# Nearest to ice: catapult, carbonate, nm, algorism, herrick, northeast, radiocommunications, elicit,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3517 0.0541 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2824 0.0522 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3835 0.0519 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4112 0.0520 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3693 0.0517 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2864 0.0520 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3140 0.0519 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3506 0.0520 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2186 0.0523 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3012 0.0521 sec/batch
# Nearest to been: israelis, never, attitude, refine, miscellaneous, compounded, several, supranational,
# Nearest to war: resigned, troops, forces, armies, interned, khoisan, him, milt,
# Nearest to between: migrated, clustered, turkmenistan, adriatic, clansman, insatiable, atlantic, implosive,
# Nearest to up: marvellous, knee, lu, reestablishing, sheds, teg, petitions, cinematographers,
# Nearest to has: retailing, follow, level, encode, veganism, tdma, unsupported, electrostatics,
# Nearest to may: hamas, shaping, rutskoy, therefore, sieves, viability, remixing, willing,
# Nearest to he: weimar, chugach, resent, father, monde, damned, maternally, seneca,
# Nearest to time: longest, cadillac, fullness, directed, torres, inclined, rosary, havilland,
# Nearest to lived: mirth, verdun, travers, portraiture, tempel, yeti, albi, eastern,
# Nearest to know: word, dogmas, enchanter, kickstart, thuringiensis, say, descendant, virtualization,
# Nearest to instance: finite, cyclic, jahwist, operating, numerically, additivity, methyl, kiln,
# Nearest to primarily: straight, toppling, manoeuvre, caldera, dili, commonly, diaspora, buddhism,
# Nearest to pressure: woken, gases, metastable, services, missy, atf, meagre, piston,
# Nearest to versions: majestic, developers, usually, microsoft, rsdlp, windows, rigours, notes,
# Nearest to troops: war, bullpen, civilians, seizing, transcended, slays, deprived, uprising,
# Nearest to ice: catapult, carbonate, nm, northeast, algorism, radiocommunications, herrick, elicit,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2980 0.0541 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3124 0.0521 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3101 0.0244 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2340 0.0521 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2638 0.0524 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1959 0.0528 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2057 0.0523 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2224 0.0523 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2219 0.0522 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1869 0.0526 sec/batch
# Nearest to been: israelis, never, attitude, compounded, miscellaneous, several, refine, chos,
# Nearest to war: resigned, troops, forces, armies, assimilate, interned, him, army,
# Nearest to between: migrated, adriatic, clustered, turkmenistan, clansman, insatiable, implosive, abnormally,
# Nearest to up: marvellous, knee, lu, sheds, explosions, put, baggins, reestablishing,
# Nearest to has: level, retailing, follow, administrative, encode, recovery, tdma, livelihood,
# Nearest to may: hamas, shaping, sieves, therefore, rutskoy, spoiling, remixing, viability,
# Nearest to he: weimar, father, resent, chugach, monde, damned, his, harem,
# Nearest to time: longest, fullness, cadillac, inclined, directed, astarte, bruises, controllers,
# Nearest to lived: mirth, portraiture, verdun, travers, yeti, albi, tah, tempel,
# Nearest to know: dogmas, kickstart, word, say, enchanter, depend, lessening, thuringiensis,
# Nearest to instance: jahwist, cyclic, finite, numerically, kiln, heavenly, avoided, operating,
# Nearest to primarily: toppling, manoeuvre, straight, caldera, commonly, dili, buddhism, diaspora,
# Nearest to pressure: woken, gases, atf, metastable, piston, missy, receptors, heated,
# Nearest to versions: microsoft, developers, majestic, usually, windows, webmineral, rsdlp, scalable,
# Nearest to troops: war, bullpen, seizing, civilians, slays, transcended, surrender, uprising,
# Nearest to ice: catapult, nm, northeast, carbonate, radiocommunications, pavements, herrick, sandstone,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2642 0.0547 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2213 0.0528 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2443 0.0523 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1488 0.0521 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1615 0.0518 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1787 0.0519 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1883 0.0516 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1900 0.0527 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1889 0.0523 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1774 0.0520 sec/batch
# Nearest to been: israelis, attitude, refine, never, several, compounded, miscellaneous, most,
# Nearest to war: forces, resigned, armies, troops, interned, army, plagued, assimilate,
# Nearest to between: migrated, adriatic, implosive, clustered, turkmenistan, critical, clansman, irrelevent,
# Nearest to up: marvellous, knee, lu, put, chd, sheds, baggins, explosions,
# Nearest to has: level, retailing, unsupported, livelihood, follow, spitting, shocks, electrostatics,
# Nearest to may: hamas, sieves, therefore, shaping, rutskoy, exist, spoiling, viability,
# Nearest to he: weimar, resent, chugach, damned, father, his, harem, monde,
# Nearest to time: fullness, longest, inclined, directed, rosary, cadillac, the, illustrate,
# Nearest to lived: mirth, portraiture, yeti, wakefield, verdun, travers, albi, foreseen,
# Nearest to know: you, dogmas, kickstart, say, word, thuringiensis, enchanter, question,
# Nearest to instance: cyclic, finite, jahwist, operating, numerically, bulbous, methyl, kiln,
# Nearest to primarily: caldera, toppling, commonly, manoeuvre, straight, buddhism, dili, diaspora,
# Nearest to pressure: heated, piston, gases, metastable, woken, atf, receptors, missy,
# Nearest to versions: microsoft, developers, scalable, webmineral, majestic, usually, rsdlp, windows,
# Nearest to troops: war, bullpen, civilians, slays, seizing, transcended, peralta, uprising,
# Nearest to ice: catapult, carbonate, nm, pavements, northeast, sandstone, herrick, radiocommunications,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1778 0.0546 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2376 0.0529 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1820 0.0521 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1786 0.0519 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1682 0.0518 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1767 0.0513 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2034 0.0515 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1405 0.0516 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1627 0.0521 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2047 0.0525 sec/batch
# Nearest to been: israelis, never, attitude, compounded, refine, several, miscellaneous, additional,
# Nearest to war: forces, armies, resigned, troops, interned, army, willingly, him,
# Nearest to between: migrated, adriatic, clansman, insatiable, clustered, critical, vagueness, irrelevent,
# Nearest to up: marvellous, knee, lu, put, chd, sheds, baggins, diode,
# Nearest to has: level, retailing, unsupported, follow, veganism, electrostatics, livelihood, unscr,
# Nearest to may: hamas, rutskoy, shaping, sieves, viability, spoiling, therefore, remixing,
# Nearest to he: weimar, father, chugach, resent, damned, his, harem, monde,
# Nearest to time: longest, fullness, inclined, directed, the, phantom, lax, havilland,
# Nearest to lived: mirth, yeti, travers, portraiture, wakefield, foreseen, verdun, oppressors,
# Nearest to know: say, you, dogmas, kickstart, question, whatever, depend, virtualization,
# Nearest to instance: operating, jahwist, cyclic, numerically, finite, bulbous, avoided, many,
# Nearest to primarily: caldera, commonly, toppling, straight, dili, buddhism, diaspora, manoeuvre,
# Nearest to pressure: piston, heated, metastable, woken, gases, missy, polarized, traction,
# Nearest to versions: microsoft, webmineral, developers, majestic, scalable, rsdlp, rigours, usually,
# Nearest to troops: war, bullpen, seizing, slays, civilians, functioned, transcended, uprising,
# Nearest to ice: catapult, carbonate, nm, sandstone, periods, pavements, northeast, herrick,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1911 0.0532 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1799 0.0520 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1826 0.0523 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1806 0.0523 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1265 0.0527 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1420 0.0521 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1551 0.0528 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1513 0.0533 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2056 0.0525 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2058 0.0529 sec/batch
# Nearest to been: israelis, never, several, attitude, compounded, refine, wyoming, miscellaneous,
# Nearest to war: forces, armies, troops, army, resigned, interned, him, barbosa,
# Nearest to between: migrated, adriatic, turkmenistan, insatiable, critical, clansman, clustered, gonz,
# Nearest to up: marvellous, knee, chd, sheds, lu, exits, reestablishing, put,
# Nearest to has: level, retailing, unsupported, follow, statewide, birger, parliamentarism, prevenient,
# Nearest to may: hamas, shaping, rutskoy, remixing, sieves, prayer, finnegan, willing,
# Nearest to he: weimar, his, chugach, father, damned, resent, harem, tommy,
# Nearest to time: longest, inclined, fullness, lasted, directed, rosary, the, until,
# Nearest to lived: mirth, portraiture, travers, wakefield, verdun, yeti, deborah, nicolson,
# Nearest to know: say, you, dogmas, whatever, kickstart, depend, question, virtualization,
# Nearest to instance: operating, jahwist, cyclic, finite, numerically, bulbous, heavenly, webs,
# Nearest to primarily: commonly, buddhism, caldera, toppling, dili, diaspora, manoeuvre, straight,
# Nearest to pressure: piston, metastable, heated, polarized, missy, woken, consequently, disturbance,
# Nearest to versions: microsoft, webmineral, developers, scalable, rigours, graphic, majestic, rsdlp,
# Nearest to troops: war, bullpen, seizing, slays, uprising, civilians, functioned, sent,
# Nearest to ice: catapult, carbonate, periods, sandstone, wolves, herrick, pavements, nm,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2306 0.0542 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1363 0.0529 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1283 0.0516 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1254 0.0521 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0576 0.0523 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1517 0.0523 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1317 0.0523 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1293 0.0518 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1902 0.0101 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1086 0.0521 sec/batch
# Nearest to been: never, several, videos, israelis, refine, compounded, attitude, wyoming,
# Nearest to war: forces, troops, armies, army, interned, resigned, ushant, allied,
# Nearest to between: migrated, adriatic, turkmenistan, clustered, critical, vagueness, notions, relative,
# Nearest to up: marvellous, knee, exits, sheds, chd, explosions, put, yell,
# Nearest to has: level, retailing, unsupported, follow, livelihood, unscr, rented, statewide,
# Nearest to may: hamas, shaping, sieves, rutskoy, childlike, remixing, prayer, strenuous,
# Nearest to he: weimar, his, chugach, damned, father, resent, mame, farel,
# Nearest to time: inclined, longest, lasted, fullness, directed, the, until, lax,
# Nearest to lived: mirth, portraiture, wakefield, travers, nicolson, yeti, murad, prudence,
# Nearest to know: say, you, kickstart, virtualization, question, whatever, dogmas, depend,
# Nearest to instance: operating, jahwist, cyclic, numerically, finite, bulbous, heavenly, lupin,
# Nearest to primarily: commonly, caldera, buddhism, straight, diaspora, dili, toppling, schools,
# Nearest to pressure: piston, missy, metastable, polarized, heated, consequently, atf, disturbance,
# Nearest to versions: microsoft, developers, webmineral, windows, rigours, scalable, majestic, binaries,
# Nearest to troops: war, bullpen, seizing, slays, sent, civilians, uprising, surrender,
# Nearest to ice: catapult, carbonate, periods, sandstone, pavements, strata, wolves, boulder,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0723 0.0538 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0863 0.0524 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1072 0.0527 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0674 0.0527 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0750 0.0523 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0234 0.0524 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1059 0.0531 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1088 0.0526 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1336 0.0521 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0337 0.0517 sec/batch
# Nearest to been: israelis, several, never, compounded, videos, refine, additional, miscellaneous,
# Nearest to war: forces, armies, troops, army, interned, ushant, allied, fighting,
# Nearest to between: migrated, adriatic, turkmenistan, clustered, critical, border, relative, becoming,
# Nearest to up: marvellous, knee, put, chd, exits, lu, layout, explosions,
# Nearest to has: level, retailing, unsupported, follow, rented, livelihood, covered, redeveloped,
# Nearest to may: hamas, rutskoy, sieves, shaping, strenuous, prayer, childlike, spoiling,
# Nearest to he: his, weimar, chugach, father, damned, resent, harem, scion,
# Nearest to time: inclined, lasted, longest, directed, fullness, until, the, pre,
# Nearest to lived: mirth, portraiture, quantitatively, prudence, wakefield, foreseen, yeti, murad,
# Nearest to know: you, say, kickstart, question, depend, virtualization, whatever, enchanter,
# Nearest to instance: operating, jahwist, cyclic, lupin, numerically, avoided, bulbous, heavenly,
# Nearest to primarily: commonly, buddhism, caldera, straight, schools, dili, manoeuvre, diaspora,
# Nearest to pressure: piston, polarized, metastable, atf, heated, missy, consequently, disturbance,
# Nearest to versions: microsoft, webmineral, scalable, developers, rigours, majestic, windows, criollos,
# Nearest to troops: war, seizing, sent, slays, bullpen, civilians, uprising, surrender,
# Nearest to ice: catapult, carbonate, sandstone, pavements, periods, radiocommunications, boulder, rink,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0165 0.0535 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0558 0.0519 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0222 0.0525 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0676 0.0523 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0710 0.0520 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0580 0.0519 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0762 0.0522 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1049 0.0519 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0587 0.0516 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0392 0.0518 sec/batch
# Nearest to been: several, israelis, compounded, never, refine, videos, attitude, most,
# Nearest to war: forces, interned, troops, armies, army, ushant, resigned, fighting,
# Nearest to between: migrated, adriatic, critical, turkmenistan, clustered, relative, border, clansman,
# Nearest to up: marvellous, knee, lu, put, chd, exits, sheds, trimmed,
# Nearest to has: level, retailing, unsupported, rented, follow, livelihood, unscr, neighbourhoods,
# Nearest to may: hamas, shaping, rutskoy, strenuous, sieves, prayer, spoiling, smac,
# Nearest to he: weimar, chugach, his, damned, bailly, resent, farel, father,
# Nearest to time: inclined, angular, lasted, longest, directed, the, fullness, until,
# Nearest to lived: mirth, quantitatively, portraiture, yeti, oppressors, wakefield, nicolson, foreseen,
# Nearest to know: you, say, whatever, question, kickstart, virtualization, do, wag,
# Nearest to instance: operating, cyclic, jahwist, bulbous, numerically, lupin, many, avoided,
# Nearest to primarily: buddhism, commonly, dili, diaspora, caldera, schools, aphrodisias, straight,
# Nearest to pressure: piston, polarized, heated, gases, metastable, atf, consequently, disturbance,
# Nearest to versions: webmineral, scalable, microsoft, rigours, majestic, excavators, developers, criollos,
# Nearest to troops: war, seizing, slays, bullpen, sent, uprising, functioned, surrender,
# Nearest to ice: catapult, carbonate, sandstone, pavements, periods, coals, rink, strata,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0481 0.0533 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0918 0.0520 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0855 0.0517 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0968 0.0520 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0926 0.0581 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0728 0.0520 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0889 0.0545 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0833 0.0518 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0689 0.0521 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0530 0.0518 sec/batch
# Nearest to been: several, israelis, never, compounded, ariana, videos, attitude, most,
# Nearest to war: forces, troops, interned, armies, army, allied, ushant, fighting,
# Nearest to between: adriatic, migrated, critical, turkmenistan, border, relative, clansman, clustered,
# Nearest to up: marvellous, knee, put, exits, lu, trimmed, clocking, confinement,
# Nearest to has: level, unsupported, follow, retailing, rented, statewide, preceding, an,
# Nearest to may: strenuous, rutskoy, hamas, prayer, shaping, sieves, depraved, finnegan,
# Nearest to he: weimar, his, chugach, bailly, damned, father, wend, resent,
# Nearest to time: lasted, the, inclined, fullness, until, longest, directed, angular,
# Nearest to lived: mirth, quantitatively, yeti, montpellier, portraiture, nicolson, prudence, murad,
# Nearest to know: say, you, whatever, virtualization, dogmas, question, do, enchanter,
# Nearest to instance: cyclic, operating, jahwist, heavenly, avoided, numerically, bulbous, webs,
# Nearest to primarily: buddhism, dili, commonly, straight, caldera, diaspora, schools, hironaka,
# Nearest to pressure: gases, piston, heated, polarized, consequently, metastable, stillness, atf,
# Nearest to versions: webmineral, microsoft, scalable, rigours, graphic, pharyngeal, excavators, developers,
# Nearest to troops: war, slays, seizing, functioned, sent, bullpen, uprising, resistance,
# Nearest to ice: carbonate, catapult, periods, coals, sandstone, pavements, toxins, strata,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0414 0.0538 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0115 0.0519 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0365 0.0515 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0647 0.0521 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0637 0.0520 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1189 0.0521 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1528 0.0516 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0515 0.0518 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0321 0.0516 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0530 0.0518 sec/batch
# Nearest to been: several, compounded, israelis, never, videos, ariana, most, additional,
# Nearest to war: forces, interned, troops, reasserted, cromwell, armies, allied, army,
# Nearest to between: adriatic, migrated, critical, relative, turkmenistan, border, equilibrium, becoming,
# Nearest to up: marvellous, knee, lu, exits, trimmed, put, nineties, clocking,
# Nearest to has: level, unsupported, retailing, follow, an, such, rented, statewide,
# Nearest to may: strenuous, prayer, shaping, rutskoy, hamas, sieves, apa, finnegan,
# Nearest to he: his, weimar, chugach, bailly, farel, resent, damned, career,
# Nearest to time: lasted, the, inclined, directed, until, fullness, wobble, angular,
# Nearest to lived: mirth, wakefield, quantitatively, portraiture, nicolson, montpellier, yeti, murad,
# Nearest to know: say, you, withheld, don, question, enchanter, cole, virtualization,
# Nearest to instance: operating, cyclic, heavenly, jahwist, numerically, lupin, avoided, webs,
# Nearest to primarily: dili, caldera, diaspora, buddhism, commonly, schools, straight, manoeuvre,
# Nearest to pressure: piston, gases, consequently, polarized, heated, metastable, stillness, atf,
# Nearest to versions: microsoft, webmineral, scalable, rigours, windows, suite, graphic, majestic,
# Nearest to troops: war, slays, sent, bullpen, functioned, resistance, kagan, seizing,
# Nearest to ice: periods, carbonate, catapult, tusk, coals, strata, elicit, radiocommunications,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9710 0.0537 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0466 0.0520 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0569 0.0522 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0209 0.0522 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0907 0.0516 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0271 0.0483 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0225 0.0521 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9747 0.0516 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0110 0.0522 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9618 0.0520 sec/batch
# Nearest to been: several, israelis, compounded, never, videos, ariana, most, intruded,
# Nearest to war: forces, interned, troops, ushant, recapture, army, barbosa, allied,
# Nearest to between: adriatic, migrated, relative, turkmenistan, border, critical, pacified, obscured,
# Nearest to up: marvellous, knee, put, lu, exits, yell, chd, trimmed,
# Nearest to has: level, unsupported, retailing, follow, statewide, such, an, rented,
# Nearest to may: strenuous, prayer, rutskoy, hamas, apa, childlike, shaping, finnegan,
# Nearest to he: his, weimar, chugach, resent, bailly, father, fellow, damned,
# Nearest to time: lasted, inclined, until, the, marangella, directed, wobble, angular,
# Nearest to lived: mirth, montpellier, murad, quantitatively, prudence, wakefield, portraiture, yeti,
# Nearest to know: say, you, whatever, withheld, question, depend, wag, don,
# Nearest to instance: jahwist, heavenly, lupin, operating, avoided, numerically, cyclic, webs,
# Nearest to primarily: schools, buddhism, dili, caldera, manoeuvre, commonly, diaspora, straight,
# Nearest to pressure: piston, gases, polarized, heated, stillness, metastable, consequently, disturbance,
# Nearest to versions: microsoft, webmineral, scalable, support, windows, developers, suite, rigours,
# Nearest to troops: war, slays, bullpen, sent, seizing, functioned, kagan, miyamoto,
# Nearest to ice: periods, carbonate, catapult, tusk, elicit, coals, radiocommunications, pueblo,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9868 0.0539 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9342 0.0518 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0245 0.0519 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0104 0.0521 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0287 0.0519 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0060 0.0519 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9142 0.0523 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9860 0.0523 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9430 0.0516 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9958 0.0521 sec/batch
# Nearest to been: several, israelis, compounded, most, never, predynastic, additional, rhodesia,
# Nearest to war: forces, interned, troops, fighting, ushant, army, allied, recapture,
# Nearest to between: adriatic, migrated, critical, border, relative, turkmenistan, clustered, becoming,
# Nearest to up: marvellous, knee, put, exits, yell, lu, lineman, chd,
# Nearest to has: level, follow, such, an, unsupported, statewide, retailing, unscr,
# Nearest to may: strenuous, rutskoy, prayer, shaping, sieves, hamas, childlike, willing,
# Nearest to he: his, weimar, chugach, resent, bailly, damned, wend, asked,
# Nearest to time: lasted, inclined, until, angular, wobble, marangella, the, directed,
# Nearest to lived: mirth, quantitatively, prudence, portraiture, murad, yeti, wakefield, montpellier,
# Nearest to know: say, you, whatever, don, we, question, withheld, wag,
# Nearest to instance: cyclic, avoided, methyl, numerically, operating, lupin, heavenly, jahwist,
# Nearest to primarily: buddhism, schools, diaspora, caldera, dili, commonly, straight, manoeuvre,
# Nearest to pressure: piston, gases, heated, polarized, metastable, stillness, traction, consequently,
# Nearest to versions: scalable, webmineral, microsoft, developers, pharyngeal, gbu, rigours, excavators,
# Nearest to troops: war, sent, slays, bullpen, seizing, functioned, kagan, miyamoto,
# Nearest to ice: periods, carbonate, catapult, coals, rink, radiocommunications, tusk, elicit,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0159 0.0534 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0043 0.0518 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9750 0.0518 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0151 0.0517 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0348 0.0517 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9295 0.0516 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0234 0.0517 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0140 0.0515 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9603 0.0521 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9997 0.0514 sec/batch
# Nearest to been: several, never, israelis, most, compounded, predynastic, rhodesia, ariana,
# Nearest to war: forces, interned, troops, ushant, allied, cromwell, adriana, barbosa,
# Nearest to between: adriatic, critical, migrated, border, turkmenistan, relative, vagueness, constitutions,
# Nearest to up: marvellous, knee, put, lu, yell, lineman, sanctification, exits,
# Nearest to has: level, follow, an, statewide, unscr, rented, a, unsupported,
# Nearest to may: strenuous, prayer, rutskoy, hamas, apa, shaping, harmonizing, childlike,
# Nearest to he: his, weimar, bailly, chugach, resent, wend, sympathisers, devotion,
# Nearest to time: lasted, until, wobble, inclined, the, marangella, angular, punter,
# Nearest to lived: mirth, murad, prudence, quantitatively, montpellier, yeti, wakefield, portraiture,
# Nearest to know: you, say, whatever, don, wag, do, we, question,
# Nearest to instance: cyclic, numerically, jahwist, avoided, operating, methyl, heavenly, praeparatio,
# Nearest to primarily: buddhism, dili, diaspora, caldera, straight, schools, hironaka, aphrodisias,
# Nearest to pressure: piston, gases, heated, polarized, stillness, consequently, metastable, traction,
# Nearest to versions: scalable, webmineral, microsoft, pharyngeal, rudimentary, excavators, gbu, rigours,
# Nearest to troops: war, slays, sent, bullpen, seizing, functioned, kagan, miyamoto,
# Nearest to ice: periods, carbonate, catapult, radiocommunications, tusk, coals, rink, elicit,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9961 0.0534 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9952 0.0524 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9814 0.0521 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9980 0.0517 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0124 0.0517 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0114 0.0519 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9659 0.0523 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9742 0.0518 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9726 0.0516 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0043 0.0522 sec/batch
# Nearest to been: several, israelis, rhodesia, most, never, predynastic, ariana, compounded,
# Nearest to war: forces, interned, troops, allied, ushant, weapons, fighting, recapture,
# Nearest to between: adriatic, critical, border, migrated, relative, implosive, turkmenistan, to,
# Nearest to up: marvellous, exits, knee, lu, put, chd, trimmed, spirals,
# Nearest to has: an, level, follow, a, retailing, such, statewide, the,
# Nearest to may: strenuous, rutskoy, prayer, shaping, apa, hamas, harmonizing, should,
# Nearest to he: his, weimar, bailly, chugach, career, fellow, sympathisers, wend,
# Nearest to time: lasted, until, wobble, inclined, fullness, marangella, angular, punter,
# Nearest to lived: mirth, prudence, murad, montpellier, quantitatively, yeti, seaworthy, wakefield,
# Nearest to know: say, you, don, whatever, do, question, we, word,
# Nearest to instance: cyclic, heavenly, jahwist, methyl, numerically, avoided, praeparatio, webs,
# Nearest to primarily: buddhism, dili, diaspora, schools, caldera, hironaka, aphrodisias, commonly,
# Nearest to pressure: piston, gases, heated, polarized, stillness, metastable, consequently, prompted,
# Nearest to versions: microsoft, webmineral, scalable, pharyngeal, gbu, suite, rudimentary, excavators,
# Nearest to troops: war, slays, sent, bullpen, functioned, miyamoto, seizing, kagan,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8563 0.0583 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8382 0.0546 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8693 0.0560 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8919 0.0593 sec/batch
# Nearest to been: several, most, was, least, fact, suggested, probably, by,
# Nearest to war: workstations, abduction, generals, forces, world, downpours, allied, troops,
# Nearest to between: border, to, digamma, modi, ends, golan, differences, adriatic,
# Nearest to up: spirals, entries, sanctification, put, orb, exits, nominal, fairway,
# Nearest to has: a, the, is, such, an, and, some, for,
# Nearest to may: strenuous, prayer, can, the, there, are, domino, a,
# Nearest to he: his, career, had, fellow, asked, him, assistant, resent,
# Nearest to time: the, until, wobble, minutes, during, lasted, pre, angular,
# Nearest to lived: mirth, uniquely, bombarding, decays, krugerrand, portraiture, jagiellon, flavonoids,
# Nearest to know: say, you, do, we, yes, me, hear, whatever,
# Nearest to instance: heavenly, many, methyl, praeparatio, intentionally, replace, operating, avoided,
# Nearest to primarily: other, tv, schools, buddhism, gully, eponyms, emphasize, spectroscopy,
# Nearest to pressure: piston, stillness, heated, acoustical, gases, harmonically, traction, recant,
# Nearest to versions: version, gbu, excavators, aps, pharyngeal, cursive, poset, scalable,
# Nearest to troops: miyamoto, dnieper, war, onetime, middlemen, kagan, surrender, slays,
# Nearest to ice: periods, rink, svoboda, coals, frawley, puck, radiocommunications, smf,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8270 0.0564 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8484 0.0580 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8607 0.0589 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8501 0.0582 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8726 0.0621 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8909 0.0557 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8557 0.0561 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8165 0.0551 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8918 0.0561 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8503 0.0559 sec/batch
# Nearest to been: several, most, was, least, the, have, since, by,
# Nearest to war: workstations, allied, generals, forces, abduction, syndicalists, multinational, world,
# Nearest to between: to, border, and, ends, digamma, modi, golan, disconnected,
# Nearest to up: sanctification, spirals, entries, put, nominal, exits, fall, hiding,
# Nearest to has: a, the, such, is, for, other, some, and,
# Nearest to may: strenuous, prayer, can, are, the, there, most, only,
# Nearest to he: his, career, had, him, himself, bailly, zurich, fellow,
# Nearest to time: the, until, wobble, during, lasted, minutes, shavuot, pre,
# Nearest to lived: mirth, uniquely, jagiellon, bombarding, decays, ancestors, trickle, emits,
# Nearest to know: say, you, we, do, yes, hear, cole, wag,
# Nearest to instance: many, heavenly, intentionally, methyl, for, topic, praeparatio, operating,
# Nearest to primarily: other, eponyms, gully, emphasize, dili, tv, buddhism, schools,
# Nearest to pressure: piston, stillness, heated, recant, patronymic, acoustical, gases, praetors,
# Nearest to versions: version, excavators, poset, gbu, findable, cursive, microsoft, features,
# Nearest to troops: miyamoto, onetime, voronin, war, dnieper, middlemen, flanders, nonconformists,
# Nearest to ice: periods, rink, svoboda, radiocommunications, coals, puck, limelight, smf,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8439 0.0580 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8181 0.0605 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8356 0.0557 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8064 0.0550 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8928 0.0563 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8504 0.0555 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9489 0.0568 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9153 0.0541 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9165 0.0530 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8033 0.0526 sec/batch
# Nearest to been: several, most, was, least, fact, by, probably, have,
# Nearest to war: world, multinational, allied, workstations, syndicalists, conflict, forces, troops,
# Nearest to between: to, and, border, golan, which, ends, manica, modi,
# Nearest to up: sanctification, nominal, entries, spirals, hiding, put, fall, lured,
# Nearest to has: the, a, such, an, other, currently, some, and,
# Nearest to may: prayer, strenuous, the, can, are, most, there, shaping,
# Nearest to he: his, career, had, him, fellow, himself, zurich, bailly,
# Nearest to time: the, until, wobble, during, minutes, shavuot, marangella, lasted,
# Nearest to lived: mirth, uniquely, bombarding, born, krugerrand, jagiellon, trickle, decays,
# Nearest to know: say, you, we, do, hear, cole, yes, me,
# Nearest to instance: intentionally, heavenly, many, methyl, praeparatio, required, can, deprecated,
# Nearest to primarily: other, schools, largest, eponyms, dili, emphasize, spectroscopy, gully,
# Nearest to pressure: piston, stillness, heated, recant, patronymic, praetors, apollonia, internal,
# Nearest to versions: version, poset, excavators, gbu, findable, microsoft, sects, webmineral,
# Nearest to troops: dnieper, war, middlemen, miyamoto, voronin, authorized, resistance, kagan,
# Nearest to ice: periods, rink, puck, radiocommunications, coals, svoboda, smf, limelight,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7907 0.0543 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8394 0.0526 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7876 0.0523 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8771 0.0525 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8326 0.0524 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8665 0.0521 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8931 0.0304 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8033 0.0528 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8277 0.0535 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8475 0.0524 sec/batch
# Nearest to been: several, was, most, fact, least, probably, have, suggested,
# Nearest to war: world, abduction, allied, workstations, multinational, troops, generals, firefight,
# Nearest to between: to, and, border, the, with, ends, adriatic, golan,
# Nearest to up: sanctification, nominal, spirals, put, lured, entries, plutinos, fall,
# Nearest to has: a, the, some, such, currently, an, is, for,
# Nearest to may: strenuous, prayer, can, the, are, there, most, or,
# Nearest to he: his, had, him, himself, career, fellow, posthumous, took,
# Nearest to time: the, until, during, wobble, minutes, lasted, shavuot, pre,
# Nearest to lived: mirth, bombarding, jagiellon, trickle, krugerrand, uniquely, decays, born,
# Nearest to know: say, you, do, we, hear, yes, it, wag,
# Nearest to instance: heavenly, methyl, praeparatio, intentionally, required, webs, jahwist, many,
# Nearest to primarily: other, eponyms, emphasize, gully, dili, largest, schools, spectroscopy,
# Nearest to pressure: piston, stillness, acoustical, clicks, recant, gases, heated, praetors,
# Nearest to versions: version, poset, gbu, excavators, microsoft, sects, aps, features,
# Nearest to troops: dnieper, war, miyamoto, middlemen, voronin, surrender, onetime, authorized,
# Nearest to ice: periods, rink, puck, coals, radiocommunications, svoboda, smf, frawley,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8153 0.0543 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8128 0.0525 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8332 0.0527 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8030 0.0525 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8451 0.0523 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8385 0.0522 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8886 0.0526 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7432 0.0524 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8200 0.0525 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7969 0.0523 sec/batch
# Nearest to been: was, several, most, least, fact, have, by, suggested,
# Nearest to war: world, workstations, multinational, allied, generals, logbook, abduction, fought,
# Nearest to between: to, and, border, which, adriatic, the, this, in,
# Nearest to up: spirals, sanctification, entries, nominal, put, yell, fall, orb,
# Nearest to has: a, the, and, is, currently, an, some, such,
# Nearest to may: can, prayer, strenuous, a, there, most, are, the,
# Nearest to he: his, him, career, had, himself, fellow, asked, posthumous,
# Nearest to time: the, during, minutes, until, wobble, pre, lasted, angular,
# Nearest to lived: mirth, jagiellon, trickle, krugerrand, bombarding, uniquely, wealth, decays,
# Nearest to know: say, you, we, do, hear, it, our, me,
# Nearest to instance: heavenly, methyl, required, praeparatio, can, many, intentionally, jahwist,
# Nearest to primarily: other, schools, gully, dili, toxic, emphasize, eponyms, jungles,
# Nearest to pressure: piston, heated, stillness, viscosity, pungent, acoustical, recant, gases,
# Nearest to versions: version, poset, gbu, excavators, sects, scalable, pharyngeal, findable,
# Nearest to troops: dnieper, middlemen, war, miyamoto, flanders, onetime, voronin, slays,
# Nearest to ice: rink, periods, puck, coals, radiocommunications, svoboda, smf, drink,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7284 0.0544 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8204 0.0525 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8764 0.0527 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8432 0.0530 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8067 0.0534 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9194 0.0529 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8371 0.0532 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8275 0.0529 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8080 0.0526 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8549 0.0574 sec/batch
# Nearest to been: several, was, most, fact, least, suggested, by, have,
# Nearest to war: workstations, world, multinational, abduction, generals, logbook, allied, antietam,
# Nearest to between: to, border, and, distinction, which, within, ends, digamma,
# Nearest to up: spirals, sanctification, entries, fall, nominal, by, put, orb,
# Nearest to has: a, the, currently, such, an, is, some, and,
# Nearest to may: can, prayer, strenuous, a, the, most, or, there,
# Nearest to he: his, career, had, him, himself, work, bailly, zurich,
# Nearest to time: the, until, minutes, during, wobble, mull, a, lasted,
# Nearest to lived: mirth, jagiellon, trickle, born, krugerrand, bombarding, decays, ancestors,
# Nearest to know: say, you, do, we, hear, our, yes, it,
# Nearest to instance: heavenly, many, methyl, praeparatio, required, intentionally, can, for,
# Nearest to primarily: other, toxic, gully, largest, eponyms, schools, emphasize, are,
# Nearest to pressure: piston, heated, stillness, gases, viscosity, pungent, recant, acoustical,
# Nearest to versions: version, poset, gbu, findable, pharyngeal, masamune, excavators, sects,
# Nearest to troops: dnieper, flanders, voronin, middlemen, drachmae, war, miyamoto, onetime,
# Nearest to ice: rink, periods, puck, coals, radiocommunications, svoboda, drink, smf,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8393 0.0601 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8527 0.0529 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8060 0.0527 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8412 0.0532 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8750 0.0525 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8463 0.0530 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8368 0.0522 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8413 0.0527 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7980 0.0523 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8179 0.0523 sec/batch
# Nearest to been: was, most, several, least, has, by, the, have,
# Nearest to war: world, workstations, multinational, abduction, allied, wars, syndicalists, conflict,
# Nearest to between: to, and, which, border, distinction, in, the, with,
# Nearest to up: spirals, sanctification, fall, nominal, entries, put, for, by,
# Nearest to has: the, a, such, for, to, in, is, currently,
# Nearest to may: can, strenuous, prayer, or, a, the, are, most,
# Nearest to he: his, career, him, himself, had, fellow, zurich, studied,
# Nearest to time: the, until, during, wobble, minutes, period, lasted, unit,
# Nearest to lived: jagiellon, trickle, bombarding, mirth, decays, krugerrand, born, flavonoids,
# Nearest to know: say, you, we, do, hear, our, really, yes,
# Nearest to instance: heavenly, for, many, methyl, praeparatio, can, required, replace,
# Nearest to primarily: other, eponyms, largest, toxic, schools, primary, jungles, gully,
# Nearest to pressure: piston, stillness, gases, recant, heated, viscosity, air, internal,
# Nearest to versions: version, poset, findable, gbu, seraphim, specialised, pharyngeal, features,
# Nearest to troops: dnieper, war, voronin, middlemen, uprising, flanders, drachmae, authorized,
# Nearest to ice: periods, rink, puck, coals, svoboda, radiocommunications, drink, completes,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8433 0.0544 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8152 0.0532 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9389 0.0524 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8977 0.0520 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8800 0.0531 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8489 0.0527 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7902 0.0522 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8416 0.0527 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7458 0.0527 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8571 0.0523 sec/batch
# Nearest to been: was, several, most, has, least, fact, since, by,
# Nearest to war: world, workstations, multinational, troops, syndicalists, abduction, wendell, generals,
# Nearest to between: to, and, border, which, the, with, within, distinction,
# Nearest to up: spirals, sanctification, by, nominal, fall, plutinos, entries, orb,
# Nearest to has: a, the, is, currently, such, in, some, for,
# Nearest to may: prayer, strenuous, can, the, or, a, most, are,
# Nearest to he: his, him, career, had, fellow, zurich, himself, graduating,
# Nearest to time: the, during, minutes, wobble, until, mull, period, shavuot,
# Nearest to lived: jagiellon, trickle, bombarding, born, mirth, decays, uniquely, krugerrand,
# Nearest to know: you, say, we, do, hear, really, yes, our,
# Nearest to instance: heavenly, for, praeparatio, methyl, intentionally, iberville, required, can,
# Nearest to primarily: other, schools, largest, eponyms, gully, emphasize, toxic, jungles,
# Nearest to pressure: piston, stillness, recant, heated, internal, apollonia, patronymic, viscosity,
# Nearest to versions: version, poset, features, gbu, findable, pharyngeal, excavators, microsoft,
# Nearest to troops: voronin, war, dnieper, flanders, kagan, drachmae, middlemen, resistance,
# Nearest to ice: periods, puck, rink, coals, svoboda, bailey, radiocommunications, pforzheim,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8279 0.0545 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8416 0.0525 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
