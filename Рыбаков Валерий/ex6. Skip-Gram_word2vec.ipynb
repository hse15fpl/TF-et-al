# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function converts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

t = 0.0001
word_counts = Counter(int_words)
all_words = len(int_words)

if_discard = {}
for word, count in word_counts.items():
    word_count = count/all_words
    if_discard[word] = 1 - np.sqrt(t/word_count)

threshold = 0.9
train_words = [word for word in int_words if if_discard[word] < threshold]

# %%
print(len(int_words))
print(len(train_words))
print(len(int_words)-len(train_words),'words discarded')
# Out:
# 16680599
# 12291481
# 4389118 words discarded

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    
    R = np.random.randint(1, window_size+1)
    if (idx - R) > 0:
        before = idx - R
    else:
        before = 0
    after = idx + R
    words_list = words[before:idx] + words[idx+1:after+1]
    
    return list(words_list)

get_target([234,654,23,1, 54, 42, 82, 43, 6, 2], 5, window_size=5)
# Out:
# [234, 654, 23, 1, 54, 82, 43, 6, 2]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# Џ®¤Ї ЇЄ  Ё«Ё д ©« checkpoints г¦Ґ бгйҐбвўгҐв.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 7.3215 0.2222 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 7.1505 0.2061 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.8995 0.2045 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.5341 0.2159 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1573 0.2185 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.8562 0.2464 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5677 0.2333 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.3437 0.2229 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.3408 0.2244 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.2408 0.2239 sec/batch
# Nearest to seven: spirit, born, controversy, aquae, ellen, resistance, interesting, march,
# Nearest to with: language, enveloping, medieval, neurologists, removed, microprocessors, taken, proved,
# Nearest to that: met, greater, allenby, spent, worldly, groups, only, synonymous,
# Nearest to at: commission, being, bmj, college, louis, anchoring, customs, convention,
# Nearest to be: synonymous, mev, ways, assume, whole, initial, bjelke, suggested,
# Nearest to american: compostela, architecture, represented, donate, updated, courted, algebra, master,
# Nearest to over: publication, website, xiv, pair, radio, his, prime, avoided,
# Nearest to world: also, bushmen, stubborn, scoring, applied, american, kau, reassigned,
# Nearest to experience: practical, tilting, language, fact, million, ccgs, hizbullah, king,
# Nearest to taking: uss, confronted, invasion, involve, makkah, cultures, habsburg, variously,
# Nearest to frac: sophia, anil, cambodian, fortunate, evils, pitman, decryption, hiiumaa,
# Nearest to joseph: elsewhere, mother, females, isomers, camera, task, advertise, wife,
# Nearest to mathematics: bone, motto, bore, arbitrate, focused, literally, different, using,
# Nearest to report: village, pork, start, supersymmetry, ii, immunological, genscher, julian,
# Nearest to square: defection, observed, comprised, reconciled, underwent, sliced, reached, isolationists,
# Nearest to mainly: manny, installation, fansubs, aleksandra, roughly, gregorian, con, weight,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.1739 0.2298 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.1323 0.2183 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.0471 0.2311 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.0121 0.2512 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0100 0.2362 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 4.9482 0.2250 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 4.9718 0.2259 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 4.8266 0.2221 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9446 0.2302 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.8490 0.2187 sec/batch
# Nearest to seven: born, aquae, ellen, interesting, spirit, march, folk, disagreed,
# Nearest to with: language, vancouver, microprocessors, enveloping, abundance, neurologists, medieval, proved,
# Nearest to that: greater, met, worldly, allenby, ideological, spent, synonymous, only,
# Nearest to at: commission, being, customs, louis, bmj, joy, seeing, notoriously,
# Nearest to be: synonymous, ways, mev, initial, sulphate, bjelke, exceedingly, assume,
# Nearest to american: compostela, architecture, oval, algebra, donate, represented, updated, courted,
# Nearest to over: website, dave, pair, exchanged, xiv, publication, vandal, hump,
# Nearest to world: scoring, bushmen, also, gears, reassigned, summer, migration, stubborn,
# Nearest to experience: practical, tilting, hizbullah, haredi, ccgs, fact, humorous, luxurious,
# Nearest to taking: involve, confronted, uss, habsburg, variously, makkah, invasion, survived,
# Nearest to frac: sophia, fortunate, evils, cambodian, anil, hiiumaa, pitman, afloat,
# Nearest to joseph: females, camera, elsewhere, isomers, sans, trustworthy, taxi, filling,
# Nearest to mathematics: bone, motto, arbitrate, bore, focused, literally, blatant, timo,
# Nearest to report: pork, composing, max, village, improvisational, immunological, adapt, supersymmetry,
# Nearest to square: comprised, defection, inc, observed, underwent, reached, reduce, isolationists,
# Nearest to mainly: installation, manny, con, fansubs, aleksandra, contribute, hath, proud,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8926 0.1964 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8194 0.2175 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.7619 0.2082 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.7448 0.2142 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8017 0.2082 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8096 0.2041 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7590 0.2036 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7410 0.2115 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7549 0.2192 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.6223 0.2206 sec/batch
# Nearest to seven: born, chi, march, harman, ellen, aquae, disagreed, four,
# Nearest to with: abundance, vancouver, microprocessors, inconsistency, language, enveloping, stake, provision,
# Nearest to that: greater, met, worldly, allenby, frei, ideological, synonymous, only,
# Nearest to at: commission, customs, maldives, bmj, being, college, joy, louis,
# Nearest to be: synonymous, ways, mev, concepts, initial, exceedingly, bjelke, assume,
# Nearest to american: compostela, architecture, oval, migrant, algebra, updated, courted, represented,
# Nearest to over: website, dave, vandal, hump, pebble, xiv, guided, publication,
# Nearest to world: scoring, bushmen, reassigned, also, gears, stubborn, oscillating, cold,
# Nearest to experience: practical, tilting, haredi, hizbullah, fact, luxurious, positing, ccgs,
# Nearest to taking: confronted, involve, uss, habsburg, variously, makkah, invasion, merino,
# Nearest to frac: sophia, cambodian, decryption, fortunate, afloat, evils, hiiumaa, pitman,
# Nearest to joseph: taxi, trustworthy, camera, isomers, sans, restitution, females, bac,
# Nearest to mathematics: bone, arbitrate, motto, literally, timo, focused, bore, blatant,
# Nearest to report: adapt, pork, composing, cdots, improvisational, village, upset, morocco,
# Nearest to square: comprised, inc, defection, isolationists, reconciled, renner, reached, est,
# Nearest to mainly: installation, manny, con, contribute, fansubs, aleksandra, hath, proud,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.6401 0.2043 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7232 0.2163 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.6839 0.2135 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6821 0.2204 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.6875 0.2097 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6897 0.2139 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6307 0.2083 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6920 0.2064 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6655 0.2001 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6564 0.1925 sec/batch
# Nearest to seven: march, aquae, chi, ellen, julio, born, harman, disagreed,
# Nearest to with: inconsistency, enveloping, abundance, vancouver, microprocessors, tropospheric, alerting, malicious,
# Nearest to that: worldly, met, greater, allenby, frei, not, only, navigational,
# Nearest to at: bmj, cleanly, scar, maldives, being, notoriously, commission, seeing,
# Nearest to be: mev, concepts, ways, exceedingly, initial, bjelke, synonymous, whole,
# Nearest to american: compostela, architecture, oval, migrant, courted, algebra, essequibo, tunis,
# Nearest to over: vandal, pebble, website, hump, exchanged, after, pair, xiv,
# Nearest to world: bushmen, scoring, reassigned, also, gears, cold, oscillating, liberec,
# Nearest to experience: practical, tilting, haredi, hizbullah, luxurious, polluting, positing, confess,
# Nearest to taking: confronted, involve, uss, habsburg, variously, invasion, portes, makkah,
# Nearest to frac: sophia, cambodian, decryption, fortunate, afloat, crumbs, anil, hiiumaa,
# Nearest to joseph: taxi, wingspan, sans, females, trustworthy, bac, restitution, advertise,
# Nearest to mathematics: bone, arbitrate, focused, blatant, rejuvenation, literally, midland, consulship,
# Nearest to report: cdots, pork, adapt, improvisational, composing, upset, immunological, dependencies,
# Nearest to square: reconciled, serra, isolationists, defection, renner, sliced, comprised, reached,
# Nearest to mainly: installation, con, manny, aleksandra, atheroma, fansubs, hath, ensures,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6379 0.1971 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6066 0.1961 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6247 0.1932 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6613 0.1931 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6260 0.1930 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.5875 0.1926 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.5943 0.1945 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.5709 0.1975 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6286 0.1926 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.5781 0.1937 sec/batch
# Nearest to seven: march, chi, ellen, born, harman, grimm, aquae, julio,
# Nearest to with: inconsistency, tropospheric, abundance, microprocessors, vancouver, enveloping, alerting, corresponded,
# Nearest to that: worldly, met, navigational, greater, compatibles, not, frei, allenby,
# Nearest to at: bmj, cleanly, meditative, scar, subsonic, maldives, laches, katy,
# Nearest to be: mev, nebulae, deficiencies, bjelke, recordings, ways, initial, exceedingly,
# Nearest to american: compostela, migrant, architecture, oval, templates, tunis, benjamin, francs,
# Nearest to over: vandal, pebble, verso, hump, nodules, exchanged, guided, after,
# Nearest to world: bushmen, reassigned, scoring, cold, gears, also, liberec, contented,
# Nearest to experience: practical, tilting, haredi, hizbullah, confess, ccgs, polluting, positing,
# Nearest to taking: confronted, eightfold, variously, uss, portes, habsburg, makkah, invasion,
# Nearest to frac: decryption, sophia, crumbs, cambodian, talk, afloat, lagging, fortunate,
# Nearest to joseph: trustworthy, taxi, presidency, bac, wingspan, sister, females, weaver,
# Nearest to mathematics: rejuvenation, arbitrate, blatant, bone, focused, consulship, declarative, midland,
# Nearest to report: cdots, pork, improvisational, adapt, dependencies, genosha, composing, immunological,
# Nearest to square: defection, serra, reconciled, sliced, renner, isolationists, reached, ravine,
# Nearest to mainly: installation, con, manny, climactic, atheroma, contribute, aleksandra, ensures,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.5818 0.1957 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6261 0.1944 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.5507 0.1939 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.5076 0.1937 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5588 0.1849 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.5042 0.1842 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.5824 0.1849 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5639 0.1811 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.5248 0.1808 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.5592 0.1806 sec/batch
# Nearest to seven: chi, march, harman, born, julio, ellen, aquae, grimm,
# Nearest to with: abundance, alerting, inconsistency, seasonings, malicious, corresponded, enveloping, microprocessors,
# Nearest to that: worldly, met, compatibles, greater, not, navigational, frei, allenby,
# Nearest to at: bmj, cleanly, subsonic, katy, nongovernmental, meditative, maldives, scar,
# Nearest to be: deficiencies, mev, nebulae, tilting, bjelke, initial, recordings, ways,
# Nearest to american: compostela, architecture, templates, tunis, migrant, essequibo, francs, oval,
# Nearest to over: vandal, pebble, verso, gmail, guided, greystone, nodules, hump,
# Nearest to world: bushmen, reassigned, scoring, cold, also, contented, stubborn, liberec,
# Nearest to experience: tilting, practical, haredi, positing, ccgs, confess, hizbullah, exerting,
# Nearest to taking: confronted, eightfold, portes, tito, uss, variously, involve, makkah,
# Nearest to frac: decryption, sophia, crumbs, talk, lagging, linde, universitas, fortunate,
# Nearest to joseph: sister, taxi, wingspan, trustworthy, benn, bac, iverson, repulsive,
# Nearest to mathematics: rejuvenation, different, tate, consulship, arbitrate, timo, declarative, focused,
# Nearest to report: cdots, adapt, dependencies, improvisational, pork, diglossia, abernathy, genosha,
# Nearest to square: serra, renner, reconciled, sliced, defection, ravine, curving, isolationists,
# Nearest to mainly: installation, manny, con, afrikaners, atheroma, climactic, contribute, aleksandra,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5043 0.1843 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.5645 0.1831 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.4792 0.1801 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.5224 0.1876 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.5506 0.1835 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.4839 0.1824 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5127 0.1817 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5207 0.1820 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.5061 0.1814 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.4041 0.1820 sec/batch
# Nearest to seven: chi, julio, ellen, marc, grimm, march, aquae, harman,
# Nearest to with: vancouver, abundance, seasonings, fairies, callet, microprocessors, neurologists, enveloping,
# Nearest to that: worldly, compatibles, met, greater, navigational, allenby, bangalore, not,
# Nearest to at: bmj, cleanly, near, scar, meditative, customs, nongovernmental, katy,
# Nearest to be: deficiencies, nebulae, tilting, mev, bjelke, exceedingly, recordings, initial,
# Nearest to american: compostela, essequibo, templates, tunis, architecture, benjamin, chet, migrant,
# Nearest to over: pebble, years, vandal, greystone, after, fell, gmail, verso,
# Nearest to world: reassigned, bushmen, cold, scoring, stubborn, contented, also, liberec,
# Nearest to experience: tilting, practical, positing, haredi, ccgs, confess, exerting, hizbullah,
# Nearest to taking: confronted, eightfold, portes, involve, tito, hedging, makkah, variously,
# Nearest to frac: decryption, crumbs, sophia, lagging, linde, talk, universitas, distributes,
# Nearest to joseph: sister, iverson, benn, inattention, bac, wingspan, trustworthy, taxi,
# Nearest to mathematics: different, rejuvenation, consulship, declarative, using, uncanny, timo, tate,
# Nearest to report: cdots, adapt, dependencies, rodan, diglossia, morocco, supersymmetry, improvisational,
# Nearest to square: serra, renner, sliced, reconciled, reached, lira, defection, ravine,
# Nearest to mainly: installation, con, afrikaners, manny, promulgates, jansen, climactic, contribute,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.5423 0.1829 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.5449 0.1815 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5390 0.1903 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5316 0.2008 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5502 0.1947 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.5278 0.1931 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.4395 0.1974 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.5028 0.1958 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.5053 0.1942 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.5074 0.2014 sec/batch
# Nearest to seven: chi, ellen, julio, harman, marc, grimm, march, aquae,
# Nearest to with: intercepts, seasonings, abundance, inconsistency, corresponded, enveloping, fairies, alerting,
# Nearest to that: worldly, compatibles, allenby, not, greater, met, bangalore, navigational,
# Nearest to at: bmj, near, cleanly, katy, scar, nongovernmental, notoriously, fru,
# Nearest to be: nebulae, deficiencies, bjelke, tilting, mev, recordings, exceedingly, indexes,
# Nearest to american: compostela, essequibo, architecture, templates, tunis, magneto, venue, taj,
# Nearest to over: pebble, greystone, vandal, fell, after, verso, gmail, fighting,
# Nearest to world: reassigned, bushmen, stubborn, cold, contented, scoring, liberec, kau,
# Nearest to experience: tilting, practical, haredi, positing, hizbullah, confess, ccgs, prefixing,
# Nearest to taking: confronted, eightfold, portes, makkah, hedging, untrained, toga, habsburg,
# Nearest to frac: decryption, crumbs, linde, universitas, lagging, sophia, talk, distributes,
# Nearest to joseph: sister, inattention, benn, iverson, trustworthy, bac, swivel, taxi,
# Nearest to mathematics: tate, rejuvenation, consulship, declarative, thesis, different, timo, luminiferous,
# Nearest to report: cdots, rodan, adapt, dependencies, reliance, morocco, improvisational, subsidizes,
# Nearest to square: serra, renner, lira, sliced, reached, reconciled, ravine, defection,
# Nearest to mainly: installation, afrikaners, con, manny, promulgates, aleksandra, montag, fallacious,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.4847 0.1981 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.5292 0.1937 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.4863 0.1924 sec/batch
# Epoch 1/10 Iteration: 8400 Avg. Training loss: 4.5366 0.1936 sec/batch
# Epoch 1/10 Iteration: 8500 Avg. Training loss: 4.4804 0.1928 sec/batch
# Epoch 1/10 Iteration: 8600 Avg. Training loss: 4.3744 0.1953 sec/batch
# Epoch 1/10 Iteration: 8700 Avg. Training loss: 4.4290 0.1935 sec/batch
# Epoch 1/10 Iteration: 8800 Avg. Training loss: 4.4584 0.1920 sec/batch
# Epoch 1/10 Iteration: 8900 Avg. Training loss: 4.4274 0.1948 sec/batch
# Epoch 1/10 Iteration: 9000 Avg. Training loss: 4.4368 0.1856 sec/batch
# Nearest to seven: chi, julio, marc, ellen, harman, march, grimm, til,
# Nearest to with: seasonings, intercepts, microprocessors, abundance, fairies, alerting, neurologists, feelin,
# Nearest to that: worldly, supercooled, compatibles, not, navigational, frei, chalcedonian, pauses,
# Nearest to at: bmj, cleanly, near, fru, mass, katy, nongovernmental, maldives,
# Nearest to be: deficiencies, bjelke, nebulae, tilting, mev, initial, indexes, gandhara,
# Nearest to american: compostela, essequibo, architecture, tunis, templates, magneto, organisational, taj,
# Nearest to over: pebble, greystone, verso, gmail, vandal, productive, levon, unnecessarily,
# Nearest to world: bushmen, reassigned, cold, contented, stubborn, liberec, scoring, withdrawals,
# Nearest to experience: tilting, practical, haredi, positing, prefixing, confess, exerting, hizbullah,
# Nearest to taking: portes, eightfold, confronted, hedging, involve, makkah, untrained, toga,
# Nearest to frac: decryption, linde, z, crumbs, universitas, lagging, talk, sophia,
# Nearest to joseph: sister, iverson, inattention, benn, bac, swivel, wikimedia, rockford,
# Nearest to mathematics: rejuvenation, consulship, different, declarative, thesis, timo, tate, excel,
# Nearest to report: rodan, adapt, cdots, reliance, dependencies, subsidizes, morocco, hexagon,
# Nearest to square: serra, renner, sliced, lira, elevations, reached, pittsfield, ravine,
# Nearest to mainly: installation, afrikaners, aleksandra, con, promulgates, montag, manny, southwest,
# Epoch 1/10 Iteration: 9100 Avg. Training loss: 4.4085 0.1852 sec/batch
# Epoch 1/10 Iteration: 9200 Avg. Training loss: 4.4652 0.1833 sec/batch
# Epoch 1/10 Iteration: 9300 Avg. Training loss: 4.1418 0.1853 sec/batch
# Epoch 1/10 Iteration: 9400 Avg. Training loss: 4.3581 0.1830 sec/batch
# Epoch 1/10 Iteration: 9500 Avg. Training loss: 4.2742 0.1846 sec/batch
# Epoch 1/10 Iteration: 9600 Avg. Training loss: 4.3576 0.1862 sec/batch
# Epoch 1/10 Iteration: 9700 Avg. Training loss: 4.4450 0.1845 sec/batch
# Epoch 1/10 Iteration: 9800 Avg. Training loss: 4.4380 0.1832 sec/batch
# Epoch 1/10 Iteration: 9900 Avg. Training loss: 4.4530 0.1852 sec/batch
# Epoch 1/10 Iteration: 10000 Avg. Training loss: 4.5322 0.1841 sec/batch
# Nearest to seven: marc, harman, julio, til, neutralisation, berger, chi, ellen,
# Nearest to with: intercepts, inconsistency, seasonings, fairies, corresponded, back, microprocessors, footwear,
# Nearest to that: worldly, bangalore, met, navigational, supercooled, supposing, claiming, pauses,
# Nearest to at: bmj, near, college, cleanly, maldives, katy, fru, mass,
# Nearest to be: nebulae, deficiencies, bjelke, exceedingly, gandhara, mev, tilting, taca,
# Nearest to american: compostela, essequibo, templates, tunis, taj, magneto, chet, architecture,
# Nearest to over: pebble, greystone, vandal, levon, fell, years, gmail, productive,
# Nearest to world: bushmen, reassigned, cold, contented, liberec, stubborn, kau, cherokees,
# Nearest to experience: practical, tilting, haredi, positing, confess, prefixing, zut, exerting,
# Nearest to taking: eightfold, ellice, portes, makkah, hedging, yamamoto, confronted, entrepot,
# Nearest to frac: linde, decryption, z, universitas, crumbs, talk, lagging, tallulah,
# Nearest to joseph: benn, inattention, iverson, swivel, wikimedia, bac, heineken, taxi,
# Nearest to mathematics: rejuvenation, consulship, thesis, different, declarative, timo, liffey, tate,
# Nearest to report: rodan, adapt, reliance, cdots, hexagon, govt, subsidizes, cade,
# Nearest to square: serra, renner, lira, ravine, sliced, reached, elevations, pittsfield,
# Nearest to mainly: installation, promulgates, con, afrikaners, aleksandra, montag, manny, jansen,
# Epoch 1/10 Iteration: 10100 Avg. Training loss: 4.5225 0.1849 sec/batch
# Epoch 1/10 Iteration: 10200 Avg. Training loss: 4.4833 0.1830 sec/batch
# Epoch 1/10 Iteration: 10300 Avg. Training loss: 4.4506 0.1842 sec/batch
# Epoch 1/10 Iteration: 10400 Avg. Training loss: 4.3055 0.2157 sec/batch
# Epoch 1/10 Iteration: 10500 Avg. Training loss: 4.4392 0.2207 sec/batch
# Epoch 1/10 Iteration: 10600 Avg. Training loss: 4.4512 0.2135 sec/batch
# Epoch 1/10 Iteration: 10700 Avg. Training loss: 4.4343 0.2346 sec/batch
# Epoch 1/10 Iteration: 10800 Avg. Training loss: 4.4632 0.2182 sec/batch
# Epoch 1/10 Iteration: 10900 Avg. Training loss: 4.4611 0.2129 sec/batch
# Epoch 1/10 Iteration: 11000 Avg. Training loss: 4.4686 0.2016 sec/batch
# Nearest to seven: marc, harman, neutralisation, julio, berger, til, lumpur, margin,
# Nearest to with: seasonings, abundance, thicknesses, microprocessors, churned, intercepts, inconsistency, swings,
# Nearest to that: worldly, navigational, supercooled, kami, supposing, compatibles, pauses, chalcedonian,
# Nearest to at: bmj, near, college, cleanly, maldives, nongovernmental, mass, katy,
# Nearest to be: nebulae, bjelke, indexes, deficiencies, exceedingly, mev, gandhara, initial,
# Nearest to american: compostela, essequibo, templates, magneto, taj, tunis, chet, architecture,
# Nearest to over: pebble, vandal, greystone, productive, hermaphrodite, levon, gmail, ago,
# Nearest to world: bushmen, reassigned, cold, kau, contented, liberec, cherokees, withdrawals,
# Nearest to experience: practical, tilting, positing, haredi, prefixing, confess, zut, hizbullah,
# Nearest to taking: ellice, portes, involve, makkah, hedging, entrepot, untrained, eightfold,
# Nearest to frac: linde, decryption, z, talk, tallulah, universitas, lagging, crumbs,
# Nearest to joseph: benn, iverson, swivel, taxi, inattention, phylogenetically, sister, bac,
# Nearest to mathematics: rejuvenation, different, consulship, declarative, thesis, liffey, timo, theoretical,
# Nearest to report: rodan, adapt, reliance, hexagon, cdots, subsidizes, govt, abernathy,
# Nearest to square: serra, ravine, sliced, lira, elevations, reached, renner, pittsfield,
# Nearest to mainly: installation, con, promulgates, afrikaners, aleksandra, montag, southwest, tourists,
# Epoch 1/10 Iteration: 11100 Avg. Training loss: 4.4368 0.2073 sec/batch
# Epoch 1/10 Iteration: 11200 Avg. Training loss: 4.3233 0.2020 sec/batch
# Epoch 1/10 Iteration: 11300 Avg. Training loss: 4.2265 0.2177 sec/batch
# Epoch 1/10 Iteration: 11400 Avg. Training loss: 4.4507 0.2253 sec/batch
# Epoch 1/10 Iteration: 11500 Avg. Training loss: 4.3691 0.2313 sec/batch
# Epoch 1/10 Iteration: 11600 Avg. Training loss: 4.3449 0.2271 sec/batch
# Epoch 1/10 Iteration: 11700 Avg. Training loss: 4.4286 0.2075 sec/batch
# Epoch 1/10 Iteration: 11800 Avg. Training loss: 4.4107 0.2023 sec/batch
# Epoch 1/10 Iteration: 11900 Avg. Training loss: 4.3666 0.2002 sec/batch
# Epoch 1/10 Iteration: 12000 Avg. Training loss: 4.3406 0.1952 sec/batch
# Nearest to seven: marc, berger, julio, four, redgrave, harman, til, neutralisation,
# Nearest to with: seasonings, microprocessors, fairies, maceo, abundance, intercepts, feelin, thicknesses,
# Nearest to that: worldly, navigational, supercooled, pauses, supposing, kami, allenby, compatibles,
# Nearest to at: bmj, college, near, cleanly, maldives, katy, rated, grooming,
# Nearest to be: bjelke, nebulae, deficiencies, indexes, exceedingly, mev, constancy, venosus,
# Nearest to american: compostela, essequibo, taj, templates, chet, tunis, magneto, architecture,
# Nearest to over: pebble, greystone, years, vandal, levon, ago, hermaphrodite, verso,
# Nearest to world: bushmen, reassigned, cold, kau, contented, liberec, cherokees, stubborn,
# Nearest to experience: practical, tilting, positing, prefixing, haredi, exerting, nature, confess,
# Nearest to taking: ellice, portes, involve, untrained, hedging, eightfold, entrepot, makkah,
# Nearest to frac: linde, decryption, tallulah, universitas, z, lagging, talk, cataphract,
# Nearest to joseph: iverson, benn, archduke, bac, swivel, phylogenetically, underwrite, inattention,
# Nearest to mathematics: rejuvenation, thesis, different, declarative, liffey, consulship, tate, theoretical,
# Nearest to report: rodan, adapt, reliance, cdots, abernathy, subsidizes, hexagon, govt,
# Nearest to square: serra, lira, ravine, renner, sliced, elevations, reached, pittsfield,
# Nearest to mainly: installation, con, afrikaners, promulgates, aleksandra, montag, tourists, southwest,
# Epoch 1/10 Iteration: 12100 Avg. Training loss: 4.4190 0.1974 sec/batch
# Epoch 1/10 Iteration: 12200 Avg. Training loss: 4.4437 0.1929 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.4774 0.0198 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.4108 0.1935 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.3550 0.1957 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.4042 0.1944 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.3463 0.1923 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.3612 0.1928 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.3747 0.1955 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.2961 0.1902 sec/batch
# Nearest to seven: marc, julio, ellen, harman, berger, neutralisation, grimm, redgrave,
# Nearest to with: neurologists, thicknesses, corresponded, lviv, seasonings, intercepts, feelin, swings,
# Nearest to that: worldly, but, because, kami, allenby, stripper, memorize, not,
# Nearest to at: bmj, near, college, cleanly, scar, katy, fru, professor,
# Nearest to be: nebulae, bjelke, deficiencies, tilting, mev, exceedingly, taca, constancy,
# Nearest to american: compostela, essequibo, templates, taj, chet, guitarist, architecture, tunis,
# Nearest to over: pebble, greystone, ago, vandal, levon, years, angelico, hermaphrodite,
# Nearest to world: bushmen, reassigned, liberec, cold, kau, contented, cherokees, antiprotons,
# Nearest to experience: practical, tilting, positing, haredi, confess, exerting, nature, prefixing,
# Nearest to taking: ellice, portes, involve, anguished, untrained, toga, sapiens, makkah,
# Nearest to frac: linde, decryption, tallulah, universitas, z, laurentiis, lagging, projector,
# Nearest to joseph: iverson, benn, archduke, bac, phylogenetically, taxi, rer, starfighter,
# Nearest to mathematics: thesis, rejuvenation, different, liffey, declarative, theoretical, tate, consulship,
# Nearest to report: rodan, reliance, adapt, cdots, abernathy, hexagon, curled, subsidizes,
# Nearest to square: serra, lira, renner, elevations, ravine, reached, pittsfield, sliced,
# Nearest to mainly: installation, con, afrikaners, promulgates, aleksandra, montag, southwest, landforms,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.2719 0.1845 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.3551 0.1856 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.3638 0.1833 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.3648 0.1835 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.3516 0.1855 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.3705 0.1804 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.3457 0.1804 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.4093 0.1804 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.3487 0.1816 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.3964 0.1819 sec/batch
# Nearest to seven: marc, til, julio, neutralisation, ellen, aquae, harman, berger,
# Nearest to with: neurologists, corresponded, seasonings, swings, fairies, thicknesses, feelin, flybys,
# Nearest to that: worldly, stripper, but, kami, memorize, supercooled, maga, allenby,
# Nearest to at: bmj, near, cleanly, college, rated, katy, fru, tibetans,
# Nearest to be: nebulae, deficiencies, bjelke, taca, constancy, tilting, mev, determine,
# Nearest to american: compostela, essequibo, taj, templates, architecture, chet, rhyming, magneto,
# Nearest to over: pebble, greystone, ago, levon, hermaphrodite, years, vandal, hump,
# Nearest to world: bushmen, cold, reassigned, cherokees, liberec, kau, antiprotons, contented,
# Nearest to experience: practical, tilting, positing, compares, confess, nature, prefixing, exerting,
# Nearest to taking: ellice, makkah, anguished, entrepot, portes, untrained, involve, abusers,
# Nearest to frac: linde, decryption, tallulah, universitas, z, projector, talk, laurentiis,
# Nearest to joseph: iverson, benn, bac, archduke, taxi, rer, paley, phylogenetically,
# Nearest to mathematics: thesis, rejuvenation, theoretical, liffey, declarative, consulship, timo, tate,
# Nearest to report: rodan, reliance, abernathy, adapt, govt, cdots, curled, hexagon,
# Nearest to square: lira, serra, ravine, renner, pittsfield, reached, sliced, elevations,
# Nearest to mainly: installation, con, afrikaners, promulgates, aleksandra, landforms, montag, southwest,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.2038 0.1860 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.4000 0.1838 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.4036 0.1806 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.4008 0.1797 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.3988 0.1803 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.3611 0.1817 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.3649 0.1808 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.3860 0.1809 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.3823 0.1803 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.3858 0.1808 sec/batch
# Nearest to seven: til, neutralisation, marc, racquets, harman, julio, margin, grimm,
# Nearest to with: neurologists, swings, feelin, between, flybys, intercepts, thicknesses, abundance,
# Nearest to that: worldly, but, stripper, because, supposing, maga, supercooled, allenby,
# Nearest to at: bmj, near, college, rated, katy, cleanly, grooming, tibetans,
# Nearest to be: nebulae, taca, bjelke, deficiencies, mev, representationalism, constancy, determine,
# Nearest to american: compostela, essequibo, taj, templates, rhyming, magneto, courted, architecture,
# Nearest to over: pebble, greystone, ago, hermaphrodite, levon, erbia, years, beset,
# Nearest to world: bushmen, cold, kau, reassigned, liberec, cherokees, antiprotons, contented,
# Nearest to experience: practical, tilting, positing, confess, exerting, nature, prefixing, compares,
# Nearest to taking: ellice, untrained, anguished, grandparent, makkah, entrepot, petronius, blame,
# Nearest to frac: linde, decryption, tallulah, z, n, universitas, omega, laurentiis,
# Nearest to joseph: iverson, benn, starfighter, bac, taxi, archduke, paley, wikimedia,
# Nearest to mathematics: thesis, theoretical, rejuvenation, liffey, consulship, timo, tate, declarative,
# Nearest to report: rodan, reliance, adapt, abernathy, govt, backplanes, subsidizes, curled,
# Nearest to square: serra, lira, ravine, pittsfield, renner, reached, sliced, elevations,
# Nearest to mainly: installation, con, afrikaners, promulgates, landforms, aleksandra, montag, contribute,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.3285 0.1822 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.3358 0.1814 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.2074 0.1802 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.2995 0.1803 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.3603 0.1810 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.3074 0.1804 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.3036 0.1797 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.3348 0.1839 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.3705 0.1811 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.2559 0.1799 sec/batch
# Nearest to seven: til, margin, neutralisation, racquets, marc, harman, ellen, controversy,
# Nearest to with: between, neurologists, feelin, intercepts, microprocessors, flybys, seasonings, rada,
# Nearest to that: worldly, gch, because, supposing, supercooled, navigational, stripper, but,
# Nearest to at: bmj, near, cleanly, grooming, katy, rated, college, professor,
# Nearest to be: nebulae, bjelke, deficiencies, taca, mev, representationalism, indexes, constancy,
# Nearest to american: compostela, essequibo, taj, rhyming, templates, courted, organisational, tunis,
# Nearest to over: pebble, ago, greystone, hermaphrodite, levon, years, erbia, previous,
# Nearest to world: bushmen, cold, kau, cherokees, reassigned, liberec, antiprotons, contented,
# Nearest to experience: practical, tilting, positing, nature, prefixing, confess, haredi, compares,
# Nearest to taking: ellice, toga, petronius, anguished, grandparent, sapiens, makkah, involve,
# Nearest to frac: decryption, linde, tallulah, universitas, z, laurentiis, spruce, projector,
# Nearest to joseph: iverson, bac, benn, taxi, wikimedia, pressuring, pesach, archduke,
# Nearest to mathematics: thesis, theoretical, declarative, liffey, rejuvenation, consulship, uncanny, tate,
# Nearest to report: rodan, reliance, adapt, backplanes, abernathy, govt, subsidizes, curled,
# Nearest to square: serra, ravine, lira, sliced, reached, pittsfield, renner, elevations,
# Nearest to mainly: installation, con, afrikaners, landforms, promulgates, aleksandra, montag, contribute,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.3686 0.1824 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.3797 0.1810 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.3567 0.1830 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.3502 0.1820 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.3263 0.1813 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.3266 0.1800 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.4007 0.1794 sec/batch
# Epoch 2/10 Iteration: 16800 Avg. Training loss: 4.2753 0.1815 sec/batch
# Epoch 2/10 Iteration: 16900 Avg. Training loss: 4.3425 0.1797 sec/batch
# Epoch 2/10 Iteration: 17000 Avg. Training loss: 4.2834 0.1798 sec/batch
# Nearest to seven: marc, til, berger, harman, grimm, four, neutralisation, ellen,
# Nearest to with: swings, neurologists, between, microprocessors, feelin, seasonings, intercepts, juxtaposed,
# Nearest to that: worldly, navigational, because, supposing, stripper, supercooled, but, gch,
# Nearest to at: bmj, near, cleanly, grooming, stylists, rated, huangdi, sardar,
# Nearest to be: nebulae, bjelke, representationalism, taca, deficiencies, mev, constancy, plenty,
# Nearest to american: compostela, essequibo, taj, templates, rhyming, chet, nonaligned, tunis,
# Nearest to over: pebble, ago, greystone, previous, hermaphrodite, erbia, years, levon,
# Nearest to world: bushmen, cold, cherokees, reassigned, kau, liberec, contented, antiprotons,
# Nearest to experience: practical, positing, tilting, prefixing, compares, nature, exerting, confess,
# Nearest to taking: ellice, petronius, anguished, toga, covertly, grandparent, involve, makkah,
# Nearest to frac: linde, decryption, omega, tallulah, laurentiis, z, universitas, rangle,
# Nearest to joseph: iverson, benn, bac, archduke, taxi, pressuring, wikimedia, mosaics,
# Nearest to mathematics: thesis, theoretical, rejuvenation, liffey, declarative, consulship, tate, timo,
# Nearest to report: rodan, reliance, backplanes, adapt, abernathy, govt, curled, subsidizes,
# Nearest to square: lira, sliced, serra, ravine, pittsfield, reached, comprised, infty,
# Nearest to mainly: installation, con, afrikaners, promulgates, landforms, montag, aleksandra, contribute,
# Epoch 2/10 Iteration: 17100 Avg. Training loss: 4.3469 0.1819 sec/batch
# Epoch 2/10 Iteration: 17200 Avg. Training loss: 4.3724 0.1802 sec/batch
# Epoch 2/10 Iteration: 17300 Avg. Training loss: 4.3460 0.1812 sec/batch
# Epoch 2/10 Iteration: 17400 Avg. Training loss: 4.3721 0.1821 sec/batch
# Epoch 2/10 Iteration: 17500 Avg. Training loss: 4.3775 0.1863 sec/batch
# Epoch 2/10 Iteration: 17600 Avg. Training loss: 4.3067 0.1805 sec/batch
# Epoch 2/10 Iteration: 17700 Avg. Training loss: 4.2599 0.1799 sec/batch
# Epoch 2/10 Iteration: 17800 Avg. Training loss: 4.3076 0.1802 sec/batch
# Epoch 2/10 Iteration: 17900 Avg. Training loss: 4.3019 0.1807 sec/batch
# Epoch 2/10 Iteration: 18000 Avg. Training loss: 4.3534 0.1804 sec/batch
# Nearest to seven: marc, til, harman, controversy, neutralisation, grimm, julio, margin,
# Nearest to with: between, neurologists, intercepts, torsion, rada, flybys, feelin, juxtaposed,
# Nearest to that: worldly, because, but, stripper, which, supposing, navigational, gch,
# Nearest to at: bmj, near, cleanly, grooming, stylists, hyi, huangdi, rated,
# Nearest to be: nebulae, bjelke, deficiencies, taca, representationalism, constancy, venosus, plenty,
# Nearest to american: compostela, essequibo, templates, taj, rhyming, chet, magneto, nonaligned,
# Nearest to over: ago, pebble, greystone, hermaphrodite, erbia, years, previous, levon,
# Nearest to world: bushmen, cold, cherokees, kau, liberec, reassigned, antiprotons, contented,
# Nearest to experience: practical, positing, tilting, compares, nature, prefixing, exerting, confess,
# Nearest to taking: ellice, anguished, petronius, sapiens, toga, grandparent, involve, lied,
# Nearest to frac: linde, decryption, omega, tallulah, laurentiis, rangle, qquad, universitas,
# Nearest to joseph: benn, iverson, archduke, bac, paley, pressuring, mosaics, taxi,
# Nearest to mathematics: thesis, theoretical, declarative, tate, rejuvenation, algebra, liffey, priori,
# Nearest to report: reliance, rodan, adapt, backplanes, abernathy, govt, subsidizes, curled,
# Nearest to square: serra, ravine, lira, sliced, infty, pittsfield, comprised, reached,
# Nearest to mainly: installation, con, promulgates, afrikaners, landforms, contribute, aleksandra, montag,
# Epoch 2/10 Iteration: 18100 Avg. Training loss: 4.3432 0.1824 sec/batch
# Epoch 2/10 Iteration: 18200 Avg. Training loss: 4.3279 0.1812 sec/batch
# Epoch 2/10 Iteration: 18300 Avg. Training loss: 4.3448 0.1829 sec/batch
# Epoch 2/10 Iteration: 18400 Avg. Training loss: 4.2785 0.1831 sec/batch
# Epoch 2/10 Iteration: 18500 Avg. Training loss: 4.3424 0.1812 sec/batch
# Epoch 2/10 Iteration: 18600 Avg. Training loss: 4.2531 0.1799 sec/batch
# Epoch 2/10 Iteration: 18700 Avg. Training loss: 4.3025 0.1803 sec/batch
# Epoch 2/10 Iteration: 18800 Avg. Training loss: 4.3425 0.1829 sec/batch
# Epoch 2/10 Iteration: 18900 Avg. Training loss: 4.2591 0.1804 sec/batch
# Epoch 2/10 Iteration: 19000 Avg. Training loss: 4.3456 0.1798 sec/batch
# Nearest to seven: til, harman, marc, controversy, grimm, lumpur, margin, julio,
# Nearest to with: between, neurologists, seasonings, intercepts, microprocessors, torsion, swings, kostas,
# Nearest to that: worldly, because, but, which, stripper, navigational, supposing, supercooled,
# Nearest to at: near, bmj, cleanly, grooming, stylists, katy, hyi, rated,
# Nearest to be: nebulae, taca, deficiencies, bjelke, representationalism, constancy, recordings, encyclopedic,
# Nearest to american: compostela, essequibo, templates, taj, chet, rhyming, activist, guitarist,
# Nearest to over: ago, pebble, greystone, erbia, previous, years, hermaphrodite, sent,
# Nearest to world: bushmen, cold, liberec, reassigned, cherokees, kau, antiprotons, contented,
# Nearest to experience: practical, positing, tilting, exerting, nature, compares, prefixing, confess,
# Nearest to taking: ellice, anguished, involve, petronius, grandparent, lied, toga, avis,
# Nearest to frac: linde, decryption, tallulah, rangle, omega, laurentiis, universitas, qquad,
# Nearest to joseph: iverson, benn, archduke, bac, paley, taxi, task, starfighter,
# Nearest to mathematics: thesis, theoretical, declarative, rejuvenation, liffey, tate, priori, luminiferous,
# Nearest to report: reliance, rodan, adapt, backplanes, curled, govt, subsidizes, abernathy,
# Nearest to square: lira, ravine, serra, sliced, infty, pittsfield, comprised, reached,
# Nearest to mainly: installation, con, promulgates, landforms, afrikaners, contribute, aleksandra, montag,
# Epoch 2/10 Iteration: 19100 Avg. Training loss: 4.3318 0.1841 sec/batch
# Epoch 2/10 Iteration: 19200 Avg. Training loss: 4.3149 0.1813 sec/batch
# Epoch 2/10 Iteration: 19300 Avg. Training loss: 4.1644 0.1802 sec/batch
# Epoch 2/10 Iteration: 19400 Avg. Training loss: 4.3478 0.1805 sec/batch
# Epoch 2/10 Iteration: 19500 Avg. Training loss: 4.3276 0.1841 sec/batch
# Epoch 2/10 Iteration: 19600 Avg. Training loss: 4.3280 0.1814 sec/batch
# Epoch 2/10 Iteration: 19700 Avg. Training loss: 4.3477 0.1811 sec/batch
# Epoch 2/10 Iteration: 19800 Avg. Training loss: 4.3754 0.1814 sec/batch
# Epoch 2/10 Iteration: 19900 Avg. Training loss: 4.3268 0.1804 sec/batch
# Epoch 2/10 Iteration: 20000 Avg. Training loss: 4.2637 0.1801 sec/batch
# Nearest to seven: til, margin, controversy, marc, lumpur, harman, neutralisation, four,
# Nearest to with: between, flybys, neurologists, seasonings, feelin, vancouver, microprocessors, intercepts,
# Nearest to that: worldly, because, stripper, but, which, supposing, nondisjunction, allenby,
# Nearest to at: near, bmj, cleanly, grooming, stylists, sardar, hyi, anchoring,
# Nearest to be: nebulae, taca, bjelke, deficiencies, representationalism, menial, constancy, recordings,
# Nearest to american: compostela, essequibo, templates, magneto, rhyming, taj, nonaligned, mexicana,
# Nearest to over: ago, pebble, greystone, years, erbia, previous, levon, hump,
# Nearest to world: bushmen, cold, cherokees, liberec, kau, reassigned, antiprotons, contented,
# Nearest to experience: practical, positing, tilting, compares, nature, exerting, prefixing, zut,
# Nearest to taking: ellice, lied, anguished, grandparent, involve, covertly, toga, avis,
# Nearest to frac: linde, decryption, rangle, tallulah, laurentiis, omega, undefined, universitas,
# Nearest to joseph: iverson, bac, benn, task, starfighter, paley, archduke, rer,
# Nearest to mathematics: thesis, theoretical, tate, declarative, rejuvenation, consulship, liffey, norton,
# Nearest to report: reliance, rodan, adapt, backplanes, govt, subsidizes, hexagon, abernathy,
# Nearest to square: lira, serra, ravine, sliced, comprised, pittsfield, infty, reached,
# Nearest to mainly: installation, con, promulgates, landforms, afrikaners, montag, aleksandra, ensures,
# Epoch 2/10 Iteration: 20100 Avg. Training loss: 4.3495 0.1825 sec/batch
# Epoch 2/10 Iteration: 20200 Avg. Training loss: 4.3291 0.1797 sec/batch
# Epoch 2/10 Iteration: 20300 Avg. Training loss: 4.3274 0.1810 sec/batch
# Epoch 2/10 Iteration: 20400 Avg. Training loss: 4.3546 0.1850 sec/batch
# Epoch 2/10 Iteration: 20500 Avg. Training loss: 4.3409 0.1807 sec/batch
# Epoch 2/10 Iteration: 20600 Avg. Training loss: 4.3153 0.1802 sec/batch
# Epoch 2/10 Iteration: 20700 Avg. Training loss: 4.3396 0.1805 sec/batch
# Epoch 2/10 Iteration: 20800 Avg. Training loss: 4.3110 0.1862 sec/batch
# Epoch 2/10 Iteration: 20900 Avg. Training loss: 4.2208 0.1808 sec/batch
# Epoch 2/10 Iteration: 21000 Avg. Training loss: 4.2798 0.1799 sec/batch
# Nearest to seven: til, margin, four, marc, harman, controversy, neutralisation, racquets,
# Nearest to with: between, neurologists, flybys, feelin, intercepts, seasonings, nanotechnology, torsion,
# Nearest to that: worldly, because, which, stripper, but, supposing, nondisjunction, hafiz,
# Nearest to at: near, bmj, cleanly, hyi, stylists, grooming, fru, anchoring,
# Nearest to be: nebulae, taca, deficiencies, bjelke, representationalism, constancy, encyclopedic, expect,
# Nearest to american: compostela, essequibo, magneto, taj, templates, rhyming, mexicana, nonaligned,
# Nearest to over: ago, pebble, greystone, years, previous, extend, malaise, erbia,
# Nearest to world: bushmen, cherokees, cold, liberec, kau, reassigned, antiprotons, withdrawals,
# Nearest to experience: practical, positing, tilting, compares, nature, prefixing, exerting, haredi,
# Nearest to taking: ellice, involve, lied, toga, anguished, avis, covertly, grandparent,
# Nearest to frac: rangle, linde, decryption, omega, tallulah, laurentiis, undefined, spruce,
# Nearest to joseph: iverson, bac, mosaics, benn, wikimedia, rer, starfighter, phylogenetically,
# Nearest to mathematics: thesis, declarative, theoretical, consulship, rejuvenation, tate, liffey, norton,
# Nearest to report: reliance, rodan, backplanes, govt, adapt, june, subsidizes, hexagon,
# Nearest to square: lira, serra, ravine, sliced, infty, pittsfield, comprised, reached,
# Nearest to mainly: installation, con, promulgates, landforms, afrikaners, aleksandra, montag, uncommon,
# Epoch 2/10 Iteration: 21100 Avg. Training loss: 4.3186 0.1829 sec/batch
# Epoch 2/10 Iteration: 21200 Avg. Training loss: 4.2731 0.1827 sec/batch
# Epoch 2/10 Iteration: 21300 Avg. Training loss: 4.2892 0.1830 sec/batch
# Epoch 2/10 Iteration: 21400 Avg. Training loss: 4.2821 0.1801 sec/batch
# Epoch 2/10 Iteration: 21500 Avg. Training loss: 4.3113 0.1822 sec/batch
# Epoch 2/10 Iteration: 21600 Avg. Training loss: 3.9405 0.1800 sec/batch
# Epoch 2/10 Iteration: 21700 Avg. Training loss: 4.2241 0.1800 sec/batch
# Epoch 2/10 Iteration: 21800 Avg. Training loss: 4.0901 0.1806 sec/batch
# Epoch 2/10 Iteration: 21900 Avg. Training loss: 4.2715 0.1801 sec/batch
# Epoch 2/10 Iteration: 22000 Avg. Training loss: 4.3180 0.1805 sec/batch
# Nearest to seven: til, harman, marc, controversy, margin, berger, resistance, lumpur,
# Nearest to with: between, intercepts, flybys, neurologists, kostas, swings, corresponded, feelin,
# Nearest to that: worldly, because, which, stripper, but, said, nondisjunction, supposing,
# Nearest to at: near, hyi, bmj, stylists, college, cleanly, enrolled, professor,
# Nearest to be: taca, nebulae, bjelke, menial, representationalism, deficiencies, constancy, expect,
# Nearest to american: compostela, essequibo, templates, taj, magneto, chet, arif, rhyming,
# Nearest to over: ago, pebble, greystone, erbia, previous, years, hermaphrodite, gained,
# Nearest to world: bushmen, cold, liberec, kau, cherokees, reassigned, antiprotons, pestis,
# Nearest to experience: practical, positing, compares, tilting, nature, zut, confess, exerting,
# Nearest to taking: ellice, anguished, lied, toga, avis, beauharnais, grandparent, petronius,
# Nearest to frac: decryption, linde, rangle, omega, tallulah, undefined, laurentiis, spruce,
# Nearest to joseph: iverson, bac, task, pressuring, mosaics, benn, wikimedia, archduke,
# Nearest to mathematics: thesis, declarative, consulship, theoretical, rejuvenation, liffey, norton, priori,
# Nearest to report: reliance, rodan, backplanes, adapt, reports, govt, june, hexagon,
# Nearest to square: lira, serra, ravine, sliced, comprised, pittsfield, infty, reached,
# Nearest to mainly: installation, con, promulgates, landforms, montag, afrikaners, uncommon, sores,
# Epoch 2/10 Iteration: 22100 Avg. Training loss: 4.3354 0.1822 sec/batch
# Epoch 2/10 Iteration: 22200 Avg. Training loss: 4.2996 0.1800 sec/batch
# Epoch 2/10 Iteration: 22300 Avg. Training loss: 4.4115 0.1798 sec/batch
# Epoch 2/10 Iteration: 22400 Avg. Training loss: 4.3844 0.1846 sec/batch
# Epoch 2/10 Iteration: 22500 Avg. Training loss: 4.3656 0.1804 sec/batch
# Epoch 2/10 Iteration: 22600 Avg. Training loss: 4.3325 0.1806 sec/batch
# Epoch 2/10 Iteration: 22700 Avg. Training loss: 4.1477 0.1799 sec/batch
# Epoch 2/10 Iteration: 22800 Avg. Training loss: 4.3184 0.1814 sec/batch
# Epoch 2/10 Iteration: 22900 Avg. Training loss: 4.3359 0.1799 sec/batch
# Epoch 2/10 Iteration: 23000 Avg. Training loss: 4.2843 0.1800 sec/batch
# Nearest to seven: til, harman, margin, marc, racquets, neutralisation, four, controversy,
# Nearest to with: between, neurologists, microprocessors, seasonings, flybys, intercepts, feelin, swings,
# Nearest to that: because, which, worldly, nondisjunction, supposing, but, hafiz, navigational,
# Nearest to at: near, bmj, hyi, cleanly, stylists, anchoring, sardar, grooming,
# Nearest to be: nebulae, bjelke, representationalism, constancy, indexes, taca, inhalants, plenty,
# Nearest to american: compostela, essequibo, magneto, templates, taj, rhyming, chet, nonaligned,
# Nearest to over: ago, pebble, greystone, erbia, hermaphrodite, years, previous, beers,
# Nearest to world: bushmen, cold, liberec, kau, cherokees, reassigned, antiprotons, sidewalk,
# Nearest to experience: practical, positing, compares, tilting, nature, prefixing, confess, zut,
# Nearest to taking: ellice, anguished, involve, avis, toga, grandparent, lied, covertly,
# Nearest to frac: rangle, linde, decryption, undefined, omega, tallulah, laurentiis, theta,
# Nearest to joseph: iverson, bac, pressuring, mosaics, task, benn, archduke, taxi,
# Nearest to mathematics: thesis, theoretical, declarative, consulship, priori, rejuvenation, liffey, norton,
# Nearest to report: reliance, rodan, backplanes, reports, govt, hexagon, adapt, agents,
# Nearest to square: lira, ravine, serra, sliced, comprised, pittsfield, infty, reached,
# Nearest to mainly: installation, con, promulgates, landforms, montag, energetically, unabated, afrikaners,
# Epoch 2/10 Iteration: 23100 Avg. Training loss: 4.3169 0.1832 sec/batch
# Epoch 2/10 Iteration: 23200 Avg. Training loss: 4.3447 0.1806 sec/batch
# Epoch 2/10 Iteration: 23300 Avg. Training loss: 4.3102 0.1808 sec/batch
# Epoch 2/10 Iteration: 23400 Avg. Training loss: 4.3430 0.1810 sec/batch
# Epoch 2/10 Iteration: 23500 Avg. Training loss: 4.1443 0.1810 sec/batch
# Epoch 2/10 Iteration: 23600 Avg. Training loss: 4.1519 0.1804 sec/batch
# Epoch 2/10 Iteration: 23700 Avg. Training loss: 4.3129 0.1893 sec/batch
# Epoch 2/10 Iteration: 23800 Avg. Training loss: 4.2015 0.2026 sec/batch
# Epoch 2/10 Iteration: 23900 Avg. Training loss: 4.2442 0.2007 sec/batch
# Epoch 2/10 Iteration: 24000 Avg. Training loss: 4.3282 0.1940 sec/batch
# Nearest to seven: til, marc, margin, harman, four, berger, unranked, bazin,
# Nearest to with: between, neurologists, intercepts, swings, microprocessors, seasonings, torsion, chained,
# Nearest to that: worldly, because, which, supposing, nondisjunction, but, stripper, hafiz,
# Nearest to at: near, bmj, hyi, cleanly, grooming, stylists, anchoring, enrolled,
# Nearest to be: nebulae, bjelke, representationalism, taca, plenty, constancy, inhalants, delambre,
# Nearest to american: compostela, essequibo, taj, templates, magneto, chet, arif, nonaligned,
# Nearest to over: pebble, ago, hermaphrodite, previous, erbia, years, gained, hump,
# Nearest to world: bushmen, cold, kau, liberec, cherokees, antiprotons, contented, reassigned,
# Nearest to experience: practical, positing, compares, tilting, prefixing, nature, exerting, zut,
# Nearest to taking: ellice, anguished, involve, avis, covertly, grandparent, eightfold, lied,
# Nearest to frac: rangle, linde, decryption, omega, tallulah, undefined, laurentiis, qquad,
# Nearest to joseph: iverson, bac, pressuring, benn, mosaics, rer, mosquitia, wikimedia,
# Nearest to mathematics: thesis, theoretical, declarative, norton, priori, liffey, rejuvenation, astrophysics,
# Nearest to report: rodan, reliance, backplanes, reports, interview, adapt, govt, june,
# Nearest to square: lira, ravine, serra, sliced, comprised, pittsfield, infty, reached,
# Nearest to mainly: installation, con, promulgates, energetically, landforms, montag, unabated, sores,
# Epoch 2/10 Iteration: 24100 Avg. Training loss: 4.2956 0.2186 sec/batch
# Epoch 2/10 Iteration: 24200 Avg. Training loss: 4.2377 0.2013 sec/batch
# Epoch 2/10 Iteration: 24300 Avg. Training loss: 4.2381 0.2015 sec/batch
# Epoch 2/10 Iteration: 24400 Avg. Training loss: 4.3079 0.2116 sec/batch
# Epoch 2/10 Iteration: 24500 Avg. Training loss: 4.3665 0.2093 sec/batch
# Epoch 3/10 Iteration: 24600 Avg. Training loss: 4.3415 0.0371 sec/batch
# Epoch 3/10 Iteration: 24700 Avg. Training loss: 4.3116 0.1994 sec/batch
# Epoch 3/10 Iteration: 24800 Avg. Training loss: 4.2495 0.2037 sec/batch
# Epoch 3/10 Iteration: 24900 Avg. Training loss: 4.3080 0.1984 sec/batch
# Epoch 3/10 Iteration: 25000 Avg. Training loss: 4.2264 0.2069 sec/batch
# Nearest to seven: til, harman, marc, four, margin, april, racquets, berger,
# Nearest to with: between, neurologists, microprocessors, swings, intercepts, torsion, chained, kostas,
# Nearest to that: because, which, worldly, supposing, but, stripper, nondisjunction, mediating,
# Nearest to at: near, bmj, hyi, stylists, grooming, cleanly, anchoring, college,
# Nearest to be: nebulae, bjelke, representationalism, taca, encyclopedic, constancy, aquilonia, delambre,
# Nearest to american: compostela, essequibo, taj, nonaligned, magneto, templates, chet, rhyming,
# Nearest to over: pebble, ago, hermaphrodite, previous, erbia, gained, years, greystone,
# Nearest to world: bushmen, kau, liberec, cold, cherokees, pestis, antiprotons, amusements,
# Nearest to experience: positing, practical, compares, tilting, deuterostomes, nature, exerting, animators,
# Nearest to taking: ellice, anguished, avis, involve, grandparent, lied, gurps, covertly,
# Nearest to frac: rangle, linde, decryption, tallulah, omega, undefined, laurentiis, qquad,
# Nearest to joseph: iverson, bac, pressuring, rer, benn, mosquitia, mosaics, wikimedia,
# Nearest to mathematics: thesis, declarative, theoretical, norton, liffey, priori, astrophysics, rejuvenation,
# Nearest to report: rodan, backplanes, reliance, reports, interview, adapt, hexagon, subsidizes,
# Nearest to square: lira, ravine, serra, sliced, pittsfield, comprised, reached, infty,
# Nearest to mainly: installation, promulgates, con, landforms, montag, unabated, sores, uncommon,
# Epoch 3/10 Iteration: 25100 Avg. Training loss: 4.2838 0.2109 sec/batch
# Epoch 3/10 Iteration: 25200 Avg. Training loss: 4.2760 0.2048 sec/batch
# Epoch 3/10 Iteration: 25300 Avg. Training loss: 4.1936 0.2056 sec/batch
# Epoch 3/10 Iteration: 25400 Avg. Training loss: 4.1973 0.2052 sec/batch
# Epoch 3/10 Iteration: 25500 Avg. Training loss: 4.2842 0.2203 sec/batch
# Epoch 3/10 Iteration: 25600 Avg. Training loss: 4.2680 0.2022 sec/batch
# Epoch 3/10 Iteration: 25700 Avg. Training loss: 4.2579 0.2053 sec/batch
# Epoch 3/10 Iteration: 25800 Avg. Training loss: 4.2671 0.2572 sec/batch
# Epoch 3/10 Iteration: 25900 Avg. Training loss: 4.3086 0.2162 sec/batch
# Epoch 3/10 Iteration: 26000 Avg. Training loss: 4.2657 0.1994 sec/batch
# Nearest to seven: til, harman, four, margin, march, racquets, humphry, april,
# Nearest to with: between, neurologists, thicknesses, swings, intercepts, microprocessors, torsion, feelin,
# Nearest to that: because, which, worldly, stripper, but, nondisjunction, admissible, supposing,
# Nearest to at: near, bmj, stylists, hyi, cleanly, grooming, palace, huangdi,
# Nearest to be: nebulae, bjelke, representationalism, aquilonia, constancy, taca, deficiencies, plenty,
# Nearest to american: compostela, essequibo, templates, taj, magneto, nonaligned, lauder, rhyming,
# Nearest to over: pebble, ago, hermaphrodite, previous, gained, hump, erbia, years,
# Nearest to world: cold, liberec, kau, bushmen, cherokees, antiprotons, amusements, inject,
# Nearest to experience: positing, practical, compares, tilting, nature, deuterostomes, exerting, harmony,
# Nearest to taking: ellice, anguished, avis, involve, sapiens, lied, covertly, fuhito,
# Nearest to frac: rangle, linde, decryption, omega, tallulah, laurentiis, undefined, qquad,
# Nearest to joseph: iverson, bac, rer, benn, mosquitia, pressuring, taxi, wikimedia,
# Nearest to mathematics: thesis, declarative, theoretical, liffey, norton, priori, rejuvenation, heidegger,
# Nearest to report: rodan, backplanes, reliance, reports, interview, june, tutorials, subsidizes,
# Nearest to square: lira, ravine, serra, pittsfield, sliced, comprised, infty, reached,
# Nearest to mainly: installation, con, promulgates, landforms, sores, montag, uncommon, ensures,
# Epoch 3/10 Iteration: 26100 Avg. Training loss: 4.3142 0.2079 sec/batch
# Epoch 3/10 Iteration: 26200 Avg. Training loss: 4.2601 0.2032 sec/batch
# Epoch 3/10 Iteration: 26300 Avg. Training loss: 4.3009 0.2020 sec/batch
# Epoch 3/10 Iteration: 26400 Avg. Training loss: 4.1292 0.2097 sec/batch
# Epoch 3/10 Iteration: 26500 Avg. Training loss: 4.3107 0.2036 sec/batch
# Epoch 3/10 Iteration: 26600 Avg. Training loss: 4.2871 0.2043 sec/batch
# Epoch 3/10 Iteration: 26700 Avg. Training loss: 4.3041 0.1980 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-6d252857543a> in <module>
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# D:\Anaconda3\envs\myenv\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])print()

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
