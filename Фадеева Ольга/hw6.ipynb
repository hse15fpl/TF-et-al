# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# D:\Programs\Anaconda3 5.2.0\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [02:04, 251kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

import random
from collections import Counter

threshold = 0.0001
w_count = Counter(int_words)
total_words = len(int_words)
word_freq = {word: count/total_words for word, count in w_count.items()}
p_drop = {word: 1 - np.sqrt(threshold/word_freq[word]) for word in w_count}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]
print(len(train_words))

#train_words = # The final subsampled word list
# Out:
# 8388620

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    
    R = np.random.randint(1, window_size+1)
    
    if idx - R >0:
        left = idx - R
    else:
        left = 0
        
    right = idx + R
    target_words = set(words[left:idx] + words[idx+1:right+1])
    list_tw = list(target_words)
    
    return list_tw

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-34-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 6.4132 0.5840 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 6.3995 0.4761 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 6.3010 0.4794 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 6.2713 0.4799 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 6.1632 0.4664 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 6.0685 0.4621 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 6.0436 0.4620 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.7924 0.4603 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.6325 0.4717 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.5137 0.4615 sec/batch
# Nearest to and: or, other, forty, sacking, taking, mill, object, batu,
# Nearest to six: represented, unknown, polar, property, created, boeing, rebels, pacifistic,
# Nearest to nine: king, shockley, kary, half, dinger, painting, liftoff, games,
# Nearest to his: victims, muttiah, nva, beauty, advantages, russian, beer, opposition,
# Nearest to would: from, countries, developed, ajaigarh, hall, band, disjointed, kyi,
# Nearest to or: and, literally, crowns, lud, federation, sehul, loyalties, elisabetta,
# Nearest to in: adamson, celebrated, release, neutralize, delusions, mouth, championship, vasopressin,
# Nearest to as: julian, taken, snippets, cruzeiro, produce, subject, rossum, hala,
# Nearest to hold: learning, insomnia, more, another, are, carried, nothing, bala,
# Nearest to applications: smaller, intended, palestinians, qui, commonality, csm, lmp, salinger,
# Nearest to governor: ancestor, thereof, inoue, avanti, cases, hanoi, football, compass,
# Nearest to san: millionaire, laborious, douglas, judaism, organisations, lmann, eg, organization,
# Nearest to lived: cromwell, another, seabird, kab, leavitt, squeaky, advertisers, caches,
# Nearest to engine: masoch, innuendo, commencement, reduction, maceo, bon, specific, magnolias,
# Nearest to troops: crokinole, ce, events, investigating, oneself, hydrozoa, neurological, disproven,
# Nearest to notes: eisa, fringing, aired, confederacy, militarized, bassist, blitzkrieg, itself,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.3813 0.4754 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3162 0.4704 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2356 0.4726 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1892 0.4610 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.0911 0.4619 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.0287 0.4554 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0001 0.4615 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0157 0.4622 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9732 0.4620 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9412 0.4586 sec/batch
# Nearest to and: forty, sacking, or, hooked, other, taking, halloween, millet,
# Nearest to six: represented, unknown, professionals, classification, speaks, cutaway, disks, rebels,
# Nearest to nine: king, strange, shockley, painting, twin, kary, constellation, absorbed,
# Nearest to his: nva, victims, opposition, muttiah, beer, advantages, beauty, russian,
# Nearest to would: from, niche, countries, conservatives, drop, dennis, superiority, ajaigarh,
# Nearest to or: literally, crowns, and, lud, phantoms, federation, elisabetta, sehul,
# Nearest to in: adamson, celebrated, neutralize, release, offering, geezer, memory, branches,
# Nearest to as: julian, snippets, taken, cruzeiro, newcomers, shop, cylinders, currency,
# Nearest to hold: learning, insomnia, evolving, segregated, another, carried, nothing, qualify,
# Nearest to applications: smaller, intended, palestinians, contamination, places, investment, explaining, s,
# Nearest to governor: ancestor, sitcom, thereof, avanti, hanoi, inoue, football, birmingham,
# Nearest to san: millionaire, judaism, organisations, douglas, organization, eg, lmann, itself,
# Nearest to lived: cromwell, stations, fairly, fifteenth, seabird, another, squeaky, transmitted,
# Nearest to engine: reduction, masoch, specific, commencement, meanwhile, journey, maceo, negro,
# Nearest to troops: ce, investigating, oneself, events, crokinole, stretched, disproven, dioceses,
# Nearest to notes: aired, meets, cattle, bassist, fringing, eisa, confederacy, itself,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.8702 0.4635 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8991 0.4555 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8478 0.4589 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8788 0.4633 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8351 0.4563 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8704 0.4535 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8345 0.4570 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8111 0.4637 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7539 0.4558 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7833 0.4574 sec/batch
# Nearest to and: sacking, finch, hooked, forty, millet, volunteer, or, presses,
# Nearest to six: three, two, represented, counsellor, nine, augusto, cutaway, five,
# Nearest to nine: king, one, painting, twin, six, shockley, kary, strange,
# Nearest to his: victims, nva, opposition, russian, muttiah, beer, johann, shocked,
# Nearest to would: niche, bulbs, buffers, drop, conservatives, from, carrey, disjointed,
# Nearest to or: literally, crowns, and, phantoms, lud, ingrained, elisabetta, cuba,
# Nearest to in: adamson, celebrated, neutralize, offering, assertion, geezer, climactic, catheters,
# Nearest to as: julian, cruzeiro, newcomers, snippets, taken, cylinders, altruism, renal,
# Nearest to hold: learning, insomnia, segregated, carrying, evolving, qualify, fundamentalism, another,
# Nearest to applications: smaller, intended, palestinians, contamination, explaining, investment, qui, ssi,
# Nearest to governor: ancestor, sitcom, hanoi, football, avanti, thereof, inoue, birmingham,
# Nearest to san: millionaire, geographers, judaism, eg, organisations, laborious, douglas, organization,
# Nearest to lived: cromwell, seabird, caches, contests, fifteenth, advertisers, leavitt, stations,
# Nearest to engine: commencement, reduction, apocalyptic, maceo, masoch, innuendo, specific, atoll,
# Nearest to troops: investigating, crokinole, ce, oneself, events, neurological, dorset, disproven,
# Nearest to notes: fringing, aired, cattle, eisa, bassist, meets, militarized, confederacy,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7979 0.4759 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7808 0.4551 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7702 0.4570 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7535 0.4578 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7745 0.4775 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7201 0.4778 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7152 0.4569 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6750 0.4627 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7178 0.4564 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6892 0.4556 sec/batch
# Nearest to and: sacking, serge, millet, westview, presses, prix, volunteer, forty,
# Nearest to six: two, three, five, counsellor, nine, ondes, augusto, cutaway,
# Nearest to nine: king, one, shockley, six, kary, painting, coleridge, twin,
# Nearest to his: victims, nva, johann, russian, opposition, mubarak, william, ecozone,
# Nearest to would: disjointed, bulbs, niche, buffers, drop, carrey, legalization, prohibiting,
# Nearest to or: literally, crowns, and, jura, elisabetta, cdots, ingrained, sehul,
# Nearest to in: adamson, neutralize, celebrated, revamping, climactic, shower, offering, levon,
# Nearest to as: altruism, cruzeiro, julian, snippets, newcomers, wash, cylinders, taken,
# Nearest to hold: segregated, insomnia, learning, carrying, another, qualify, nothing, evolving,
# Nearest to applications: smaller, intended, palestinians, contamination, ssi, explaining, qui, onboard,
# Nearest to governor: ancestor, sitcom, hanoi, avanti, football, seventeen, birmingham, tonnes,
# Nearest to san: millionaire, geographers, laborious, douglas, organisations, organization, judaism, eg,
# Nearest to lived: cromwell, seabird, caches, fifteenth, leavitt, contests, curse, gigantes,
# Nearest to engine: engines, reduction, atoll, specific, bon, commencement, apocalyptic, innuendo,
# Nearest to troops: crokinole, investigating, ce, army, dorset, events, hauling, oneself,
# Nearest to notes: eisa, fringing, cattle, bassist, homicide, militarized, aired, lifestyles,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6878 0.4641 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6517 0.4561 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6705 0.4722 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6609 0.4821 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6009 0.4538 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6676 0.4593 sec/batch
# Epoch 1/10 Iteration: 4700 Avg. Training loss: 4.6304 0.4580 sec/batch
# Epoch 1/10 Iteration: 4800 Avg. Training loss: 4.5858 0.4724 sec/batch
# Epoch 1/10 Iteration: 4900 Avg. Training loss: 4.6302 0.4639 sec/batch
# Epoch 1/10 Iteration: 5000 Avg. Training loss: 4.6404 0.4598 sec/batch
# Nearest to and: sacking, westview, millet, prix, monsieur, volunteer, presses, destruction,
# Nearest to six: two, three, five, pacifistic, counsellor, ondes, nine, daly,
# Nearest to nine: one, coleridge, shockley, kary, six, jonathan, king, painting,
# Nearest to his: victims, nva, corsairs, johann, opposition, ecozone, dermot, shocked,
# Nearest to would: disjointed, bulbs, legalization, niche, buffers, drop, carrey, aurochs,
# Nearest to or: literally, crowns, elisabetta, cdots, and, jura, phantoms, hellfire,
# Nearest to in: adamson, celebrated, geezer, climactic, neutralize, ducal, revamping, levon,
# Nearest to as: altruism, cruzeiro, snippets, julian, newcomers, cylinders, hyperplasia, wash,
# Nearest to hold: segregated, carrying, another, insomnia, evolving, nothing, qualify, learning,
# Nearest to applications: smaller, intended, palestinians, ssi, contamination, explaining, onboard, sequential,
# Nearest to governor: avanti, hanoi, sitcom, ancestor, seventeen, chairman, football, sardinian,
# Nearest to san: geographers, millionaire, laborious, douglas, francisco, organization, sunt, eg,
# Nearest to lived: seabird, cromwell, caches, fifteenth, leavitt, curse, gigantes, squeaky,
# Nearest to engine: engines, atoll, reduction, commencement, oscilloscopes, specific, innuendo, apocalyptic,
# Nearest to troops: army, crokinole, ce, dorset, investigating, hauling, dioceses, dow,
# Nearest to notes: eisa, fringing, cattle, lifestyles, bassist, arne, homicide, imaginings,
# Epoch 1/10 Iteration: 5100 Avg. Training loss: 4.6443 0.4642 sec/batch
# Epoch 1/10 Iteration: 5200 Avg. Training loss: 4.6317 0.4699 sec/batch
# Epoch 1/10 Iteration: 5300 Avg. Training loss: 4.5643 0.4720 sec/batch
# Epoch 1/10 Iteration: 5400 Avg. Training loss: 4.6166 0.4756 sec/batch
# Epoch 1/10 Iteration: 5500 Avg. Training loss: 4.5903 0.4772 sec/batch
# Epoch 1/10 Iteration: 5600 Avg. Training loss: 4.6182 0.4818 sec/batch
# Epoch 1/10 Iteration: 5700 Avg. Training loss: 4.6103 0.4671 sec/batch
# Epoch 1/10 Iteration: 5800 Avg. Training loss: 4.5858 0.4601 sec/batch
# Epoch 1/10 Iteration: 5900 Avg. Training loss: 4.4959 0.4715 sec/batch
# Epoch 1/10 Iteration: 6000 Avg. Training loss: 4.5509 0.4643 sec/batch
# Nearest to and: millet, other, westview, sacking, quotas, solidifying, destruction, formality,
# Nearest to six: two, three, five, one, pacifistic, nine, counsellor, ondes,
# Nearest to nine: one, coleridge, shockley, six, kary, liftoff, driver, jonathan,
# Nearest to his: victims, nva, johann, corsairs, daughter, william, whom, shocked,
# Nearest to would: disjointed, niche, legalization, buffers, bulbs, carrey, prohibiting, anticipation,
# Nearest to or: literally, crowns, elisabetta, cdots, and, jura, hellfire, embodying,
# Nearest to in: adamson, neutralize, levon, revamping, celebrated, catechumens, forgets, sides,
# Nearest to as: cruzeiro, snippets, altruism, newcomers, cylinders, wash, stoner, taken,
# Nearest to hold: segregated, insomnia, evolving, carrying, nothing, another, carried, fundamentalism,
# Nearest to applications: smaller, intended, ssi, contamination, networking, palestinians, networks, onboard,
# Nearest to governor: avanti, hanoi, sitcom, ancestor, chairman, sardinian, seventeen, football,
# Nearest to san: geographers, millionaire, laborious, francisco, douglas, sunt, judaism, lmann,
# Nearest to lived: leavitt, fifteenth, cromwell, seabird, curse, caches, gigantes, imperialists,
# Nearest to engine: engines, atoll, reduction, oscilloscopes, commencement, innuendo, bon, specific,
# Nearest to troops: army, crokinole, hauling, dorset, ce, saladin, dioceses, investigating,
# Nearest to notes: lifestyles, eisa, fringing, homicide, imaginings, cattle, bassist, diez,
# Epoch 1/10 Iteration: 6100 Avg. Training loss: 4.5484 0.4719 sec/batch
# Epoch 1/10 Iteration: 6200 Avg. Training loss: 4.5246 0.4678 sec/batch
# Epoch 1/10 Iteration: 6300 Avg. Training loss: 4.5643 0.4701 sec/batch
# Epoch 1/10 Iteration: 6400 Avg. Training loss: 4.4597 0.4776 sec/batch
# Epoch 1/10 Iteration: 6500 Avg. Training loss: 4.4817 0.4739 sec/batch
# Epoch 1/10 Iteration: 6600 Avg. Training loss: 4.5212 0.4866 sec/batch
# Epoch 1/10 Iteration: 6700 Avg. Training loss: 4.5790 0.4823 sec/batch
# Epoch 1/10 Iteration: 6800 Avg. Training loss: 4.5225 0.4612 sec/batch
# Epoch 1/10 Iteration: 6900 Avg. Training loss: 4.6261 0.4841 sec/batch
# Epoch 1/10 Iteration: 7000 Avg. Training loss: 4.5398 0.4899 sec/batch
# Nearest to and: millet, other, westview, sacking, also, validated, or, destruction,
# Nearest to six: three, five, two, one, nine, pacifistic, counsellor, four,
# Nearest to nine: one, coleridge, shockley, six, liftoff, driver, dancer, kary,
# Nearest to his: victims, nva, shocked, time, whom, corsairs, johann, horoscopes,
# Nearest to would: legalization, niche, prohibiting, anticipation, disjointed, buffers, carrey, bulbs,
# Nearest to or: literally, elisabetta, and, hellfire, crowns, embodying, jura, sehul,
# Nearest to in: adamson, revamping, ducal, sides, celebrated, submissive, neutralize, shower,
# Nearest to as: cruzeiro, altruism, snippets, newcomers, bazin, latifah, wash, taken,
# Nearest to hold: nothing, segregated, evolving, carrying, insomnia, carried, karamazov, another,
# Nearest to applications: smaller, intended, networking, ssi, extensions, networks, headers, onboard,
# Nearest to governor: avanti, hanoi, ancestor, sitcom, seventeen, sardinian, inoue, hindenburg,
# Nearest to san: geographers, millionaire, francisco, laborious, douglas, pat, lmann, crumb,
# Nearest to lived: leavitt, curse, fifteenth, seabird, cromwell, buried, gigantes, caches,
# Nearest to engine: engines, reduction, atoll, oscilloscopes, kam, specific, commencement, innuendo,
# Nearest to troops: army, crokinole, saladin, hauling, dorset, drachma, cushitic, loyalists,
# Nearest to notes: eisa, lifestyles, homicide, diez, fringing, bassist, arne, imaginings,
# Epoch 1/10 Iteration: 7100 Avg. Training loss: 4.4131 0.4928 sec/batch
# Epoch 1/10 Iteration: 7200 Avg. Training loss: 4.5368 0.4974 sec/batch
# Epoch 1/10 Iteration: 7300 Avg. Training loss: 4.5136 0.4721 sec/batch
# Epoch 1/10 Iteration: 7400 Avg. Training loss: 4.5208 0.4756 sec/batch
# Epoch 1/10 Iteration: 7500 Avg. Training loss: 4.5313 0.4645 sec/batch
# Epoch 1/10 Iteration: 7600 Avg. Training loss: 4.5032 0.4606 sec/batch
# Epoch 1/10 Iteration: 7700 Avg. Training loss: 4.3167 0.4583 sec/batch
# Epoch 1/10 Iteration: 7800 Avg. Training loss: 4.5064 0.4573 sec/batch
# Epoch 1/10 Iteration: 7900 Avg. Training loss: 4.4592 0.4603 sec/batch
# Epoch 1/10 Iteration: 8000 Avg. Training loss: 4.4653 0.4662 sec/batch
# Nearest to and: millet, other, vocalists, contiguous, monsieur, horsepower, also, thurman,
# Nearest to six: five, two, three, one, nine, four, pacifistic, ondes,
# Nearest to nine: one, six, two, coleridge, driver, shockley, liftoff, dancer,
# Nearest to his: victims, nva, whom, shocked, corsairs, johann, horoscopes, daughter,
# Nearest to would: niche, aurochs, legalization, bulbs, buffers, carrey, anticipation, disjointed,
# Nearest to or: literally, cdots, elisabetta, hellfire, and, sehul, bains, embodying,
# Nearest to in: adamson, neutralize, authorised, catechumens, sides, observer, revamping, catheters,
# Nearest to as: cruzeiro, altruism, snippets, newcomers, wash, bazin, cylinders, connotation,
# Nearest to hold: evolving, nothing, carried, segregated, carrying, insomnia, rioted, another,
# Nearest to applications: smaller, intended, networking, extensions, ssi, pediatric, contamination, ttl,
# Nearest to governor: avanti, hanoi, ancestor, seventeen, sardinian, industrialist, sitcom, inoue,
# Nearest to san: geographers, francisco, millionaire, laborious, pat, crumb, lmann, douglas,
# Nearest to lived: leavitt, curse, gigantes, seabird, caches, buried, cromwell, fifteenth,
# Nearest to engine: engines, oscilloscopes, reduction, kam, atoll, commencement, portable, innuendo,
# Nearest to troops: army, crokinole, saladin, dorset, hauling, cushitic, loyalists, dioceses,
# Nearest to notes: eisa, homicide, fringing, diez, lifestyles, spiritual, bassist, imaginings,
# Epoch 1/10 Iteration: 8100 Avg. Training loss: 4.4763 0.4746 sec/batch
# Epoch 1/10 Iteration: 8200 Avg. Training loss: 4.4807 0.4606 sec/batch
# Epoch 1/10 Iteration: 8300 Avg. Training loss: 4.4781 0.4683 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.5099 0.0567 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4308 0.4796 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.4631 0.4856 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3828 0.4592 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.4129 0.4912 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.3907 0.5067 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3976 0.4802 sec/batch
# Nearest to and: millet, vocalists, exonerated, sacking, other, vulgate, crowe, karma,
# Nearest to six: five, two, three, one, four, nine, akademie, pacifistic,
# Nearest to nine: one, six, two, dancer, driver, shockley, althea, eight,
# Nearest to his: victims, whom, shocked, nva, time, daughter, corsairs, moved,
# Nearest to would: aurochs, drop, bulbs, legalization, anticipation, disjointed, buffers, niche,
# Nearest to or: literally, elisabetta, and, infect, cdots, sehul, comparable, bains,
# Nearest to in: adamson, ducal, celebrated, authorised, sides, catechumens, observer, submissive,
# Nearest to as: cruzeiro, altruism, snippets, wash, connotation, newcomers, cylinders, schama,
# Nearest to hold: evolving, nothing, segregated, rioted, carried, parentage, happen, mitzvah,
# Nearest to applications: networking, intended, extensions, smaller, pediatric, ssi, ttl, mozilla,
# Nearest to governor: avanti, hanoi, ancestor, seventeen, sardinian, sitcom, hindenburg, vaclav,
# Nearest to san: geographers, francisco, millionaire, laborious, crumb, lmann, pat, douglas,
# Nearest to lived: buried, leavitt, seabird, curse, gigantes, cromwell, fifteenth, caches,
# Nearest to engine: engines, oscilloscopes, kam, commencement, engineers, sleeves, portable, atoll,
# Nearest to troops: army, crokinole, saladin, loyalists, forces, dorset, war, hauling,
# Nearest to notes: eisa, lifestyles, diez, handbook, homicide, bassist, arne, fringing,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.4148 0.4910 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3870 0.4789 sec/batch
# Epoch 2/10 Iteration: 9300 Avg. Training loss: 4.4068 0.4558 sec/batch
# Epoch 2/10 Iteration: 9400 Avg. Training loss: 4.4075 0.4540 sec/batch
# Epoch 2/10 Iteration: 9500 Avg. Training loss: 4.3747 0.4607 sec/batch
# Epoch 2/10 Iteration: 9600 Avg. Training loss: 4.2678 0.4843 sec/batch
# Epoch 2/10 Iteration: 9700 Avg. Training loss: 4.4282 0.4633 sec/batch
# Epoch 2/10 Iteration: 9800 Avg. Training loss: 4.4503 0.4835 sec/batch
# Epoch 2/10 Iteration: 9900 Avg. Training loss: 4.4185 0.4644 sec/batch
# Epoch 2/10 Iteration: 10000 Avg. Training loss: 4.4347 0.4598 sec/batch
# Nearest to and: vocalists, millet, other, crowe, horsepower, marley, or, vulgate,
# Nearest to six: five, three, two, one, four, nine, ondes, pacifistic,
# Nearest to nine: one, six, two, driver, althea, shockley, liftoff, coleridge,
# Nearest to his: shocked, whom, nva, victims, time, corsairs, moved, stowe,
# Nearest to would: aurochs, niche, bulbs, drop, parked, disjointed, antihydrogen, anticipation,
# Nearest to or: literally, comparable, and, elisabetta, falciparum, synthetically, sehul, jura,
# Nearest to in: adamson, submissive, geezer, celebrated, observer, lilith, ducal, sides,
# Nearest to as: cruzeiro, altruism, snippets, sonet, bazin, wash, cylinders, supported,
# Nearest to hold: evolving, carried, rioted, segregated, nothing, parentage, carrying, happen,
# Nearest to applications: networking, intended, smaller, extensions, ssi, contamination, ttl, mozilla,
# Nearest to governor: avanti, hanoi, seventeen, ancestor, liberal, vaclav, sardinian, hindenburg,
# Nearest to san: francisco, geographers, millionaire, laborious, lmann, crumb, los, pat,
# Nearest to lived: buried, leavitt, curse, seabird, gigantes, fifteenth, caches, cromwell,
# Nearest to engine: engines, oscilloscopes, kam, portable, sleeves, engineers, reduction, booker,
# Nearest to troops: army, crokinole, loyalists, forces, saladin, war, corona, hauling,
# Nearest to notes: eisa, diez, handbook, lifestyles, homicide, bassist, stags, fringing,
# Epoch 2/10 Iteration: 10100 Avg. Training loss: 4.3992 0.4726 sec/batch
# Epoch 2/10 Iteration: 10200 Avg. Training loss: 4.4006 0.4622 sec/batch
# Epoch 2/10 Iteration: 10300 Avg. Training loss: 4.3729 0.4571 sec/batch
# Epoch 2/10 Iteration: 10400 Avg. Training loss: 4.3403 0.4531 sec/batch
# Epoch 2/10 Iteration: 10500 Avg. Training loss: 4.2475 0.4597 sec/batch
# Epoch 2/10 Iteration: 10600 Avg. Training loss: 4.3437 0.4588 sec/batch
# Epoch 2/10 Iteration: 10700 Avg. Training loss: 4.3416 0.4557 sec/batch
# Epoch 2/10 Iteration: 10800 Avg. Training loss: 4.3437 0.4637 sec/batch
# Epoch 2/10 Iteration: 10900 Avg. Training loss: 4.3298 0.4532 sec/batch
# Epoch 2/10 Iteration: 11000 Avg. Training loss: 4.3818 0.4545 sec/batch
# Nearest to and: other, millet, vocalists, karma, various, or, also, assignments,
# Nearest to six: five, three, two, one, four, nine, zero, ondes,
# Nearest to nine: one, six, two, liftoff, five, eight, driver, coleridge,
# Nearest to his: whom, shocked, nva, victims, corsairs, screenplay, moved, stowe,
# Nearest to would: aurochs, niche, disjointed, antihydrogen, bulbs, legalization, parked, carrey,
# Nearest to or: literally, and, comparable, falciparum, unconscious, sehul, synthetically, embodying,
# Nearest to in: adamson, observer, neutralize, geezer, lilith, bluerhinos, forgets, celebrated,
# Nearest to as: cruzeiro, altruism, snippets, sonet, wash, rectangle, cylinders, bazin,
# Nearest to hold: evolving, rioted, qualify, lexicography, nothing, carrying, segregated, parentage,
# Nearest to applications: networking, intended, ssi, contamination, smaller, ttl, pediatric, extensions,
# Nearest to governor: avanti, chief, vaclav, hanoi, liberal, seventeen, hindenburg, lieutenant,
# Nearest to san: francisco, geographers, los, millionaire, laborious, crumb, bowling, lmann,
# Nearest to lived: leavitt, buried, seabird, curse, gigantes, fifteenth, caches, cromwell,
# Nearest to engine: engines, oscilloscopes, kam, sleeves, portable, reduction, engineers, atoll,
# Nearest to troops: army, crokinole, forces, loyalists, saladin, battlefield, hauling, corona,
# Nearest to notes: diez, handbook, eisa, homicide, stags, lifestyles, spectroscopy, fringing,
# Epoch 2/10 Iteration: 11100 Avg. Training loss: 4.3755 0.4612 sec/batch
# Epoch 2/10 Iteration: 11200 Avg. Training loss: 4.3467 0.4807 sec/batch
# Epoch 2/10 Iteration: 11300 Avg. Training loss: 4.3418 0.4556 sec/batch
# Epoch 2/10 Iteration: 11400 Avg. Training loss: 4.4001 0.4549 sec/batch
# Epoch 2/10 Iteration: 11500 Avg. Training loss: 4.3187 0.4545 sec/batch
# Epoch 2/10 Iteration: 11600 Avg. Training loss: 4.3750 0.4578 sec/batch
# Epoch 2/10 Iteration: 11700 Avg. Training loss: 4.3558 0.4544 sec/batch
# Epoch 2/10 Iteration: 11800 Avg. Training loss: 4.3873 0.4635 sec/batch
# Epoch 2/10 Iteration: 11900 Avg. Training loss: 4.3818 0.4536 sec/batch
# Epoch 2/10 Iteration: 12000 Avg. Training loss: 4.3370 0.4565 sec/batch
# Nearest to and: vocalists, other, millet, of, crowe, marley, also, various,
# Nearest to six: five, three, two, four, one, nine, ondes, zero,
# Nearest to nine: one, six, two, five, eight, althea, four, coleridge,
# Nearest to his: whom, shocked, screenplay, victims, moved, stowe, time, nva,
# Nearest to would: disjointed, aurochs, antihydrogen, niche, bulbs, anticipation, buffers, legalization,
# Nearest to or: literally, and, embodying, falciparum, comparable, unconscious, crowns, sehul,
# Nearest to in: observer, geezer, adamson, forgets, ducal, is, hemi, mulattos,
# Nearest to as: cruzeiro, altruism, snippets, sonet, mcghee, rectangle, cylinders, wash,
# Nearest to hold: evolving, rioted, carrying, qualify, parentage, segregated, karamazov, nothing,
# Nearest to applications: networking, intended, smaller, ssi, ttl, iban, loom, contamination,
# Nearest to governor: avanti, chief, hindenburg, vaclav, hanoi, lieutenant, seventeen, appointed,
# Nearest to san: francisco, geographers, los, laborious, millionaire, lmann, crumb, eg,
# Nearest to lived: leavitt, buried, seabird, gigantes, curse, fifteenth, caches, rolf,
# Nearest to engine: engines, oscilloscopes, kam, portable, sleeves, faster, reduction, engineers,
# Nearest to troops: army, crokinole, loyalists, forces, saladin, rebellion, battlefield, hauling,
# Nearest to notes: handbook, eisa, diez, stags, bassist, homicide, l, introductory,
# Epoch 2/10 Iteration: 12100 Avg. Training loss: 4.3173 0.4599 sec/batch
# Epoch 2/10 Iteration: 12200 Avg. Training loss: 4.3172 0.4625 sec/batch
# Epoch 2/10 Iteration: 12300 Avg. Training loss: 4.3495 0.4559 sec/batch
# Epoch 2/10 Iteration: 12400 Avg. Training loss: 4.3313 0.4552 sec/batch
# Epoch 2/10 Iteration: 12500 Avg. Training loss: 4.3722 0.4542 sec/batch
# Epoch 2/10 Iteration: 12600 Avg. Training loss: 4.3015 0.4547 sec/batch
# Epoch 2/10 Iteration: 12700 Avg. Training loss: 4.3494 0.4575 sec/batch
# Epoch 2/10 Iteration: 12800 Avg. Training loss: 4.3399 0.4559 sec/batch
# Epoch 2/10 Iteration: 12900 Avg. Training loss: 4.3089 0.4534 sec/batch
# Epoch 2/10 Iteration: 13000 Avg. Training loss: 4.3286 0.4546 sec/batch
# Nearest to and: other, vocalists, millet, crowe, of, various, vulgate, karma,
# Nearest to six: five, three, two, one, four, nine, zero, scudetto,
# Nearest to nine: one, six, two, five, eight, four, shockley, althea,
# Nearest to his: whom, moved, shocked, screenplay, daughter, mannerisms, beckhams, gifted,
# Nearest to would: anticipation, disjointed, aurochs, niche, buffers, carrey, antihydrogen, parked,
# Nearest to or: literally, and, comparable, sehul, embodying, falciparum, hyperplasia, synthetically,
# Nearest to in: observer, geezer, revamping, adamson, ducal, is, forgets, of,
# Nearest to as: cruzeiro, snippets, altruism, mcghee, torture, cylinders, fundamentalism, rectangle,
# Nearest to hold: evolving, carrying, segregated, rioted, happen, rabbis, carried, lexicography,
# Nearest to applications: networking, intended, smaller, contamination, ssi, extensions, sequential, iban,
# Nearest to governor: avanti, chief, vaclav, hindenburg, lieutenant, seventeen, hanoi, szlachta,
# Nearest to san: francisco, geographers, los, laborious, millionaire, lmann, eg, usk,
# Nearest to lived: leavitt, buried, seabird, gigantes, curse, fifteenth, caches, rolf,
# Nearest to engine: engines, oscilloscopes, kam, sleeves, portable, hitting, submersible, flukes,
# Nearest to troops: army, crokinole, loyalists, forces, saladin, corona, battlefield, attrition,
# Nearest to notes: handbook, eisa, bassist, diez, stags, l, homicide, fringing,
# Epoch 2/10 Iteration: 13100 Avg. Training loss: 4.3254 0.4599 sec/batch
# Epoch 2/10 Iteration: 13200 Avg. Training loss: 4.2394 0.4532 sec/batch
# Epoch 2/10 Iteration: 13300 Avg. Training loss: 4.3438 0.4580 sec/batch
# Epoch 2/10 Iteration: 13400 Avg. Training loss: 4.3358 0.4673 sec/batch
# Epoch 2/10 Iteration: 13500 Avg. Training loss: 4.3849 0.4678 sec/batch
# Epoch 2/10 Iteration: 13600 Avg. Training loss: 4.3337 0.4547 sec/batch
# Epoch 2/10 Iteration: 13700 Avg. Training loss: 4.2819 0.4543 sec/batch
# Epoch 2/10 Iteration: 13800 Avg. Training loss: 4.3538 0.4540 sec/batch
# Epoch 2/10 Iteration: 13900 Avg. Training loss: 4.3240 0.4556 sec/batch
# Epoch 2/10 Iteration: 14000 Avg. Training loss: 4.3542 0.4626 sec/batch
# Nearest to and: millet, other, of, various, vocalists, karma, sacking, crowe,
# Nearest to six: five, three, two, one, four, nine, zero, isaacson,
# Nearest to nine: one, two, six, eight, five, four, shockley, zero,
# Nearest to his: whom, he, moved, daughter, gifted, time, shocked, beckhams,
# Nearest to would: disjointed, anticipation, aurochs, parked, legalization, niche, buffers, carrey,
# Nearest to or: literally, and, comparable, sehul, crowns, falciparum, hellfire, hyperplasia,
# Nearest to in: of, ducal, the, observer, geezer, was, furnished, is,
# Nearest to as: cruzeiro, snippets, altruism, tarifit, newcomers, mcghee, fundamentalism, supported,
# Nearest to hold: carrying, evolving, are, segregated, happen, petomane, rioted, carried,
# Nearest to applications: networking, intended, loom, iban, contamination, pediatric, ssi, identifier,
# Nearest to governor: avanti, lieutenant, chief, hindenburg, vaclav, hanoi, appointed, seventeen,
# Nearest to san: francisco, geographers, los, laborious, usk, lmann, eg, millionaire,
# Nearest to lived: buried, seabird, leavitt, gigantes, curse, fifteenth, after, consorts,
# Nearest to engine: engines, oscilloscopes, kam, portable, flukes, submersible, sleeves, hitting,
# Nearest to troops: army, crokinole, loyalists, attrition, saladin, forces, starvation, battlefield,
# Nearest to notes: handbook, eisa, diez, stags, bassist, homicide, lifestyles, introductory,
# Epoch 2/10 Iteration: 14100 Avg. Training loss: 4.3490 0.4668 sec/batch
# Epoch 2/10 Iteration: 14200 Avg. Training loss: 4.3258 0.4540 sec/batch
# Epoch 2/10 Iteration: 14300 Avg. Training loss: 4.2367 0.4531 sec/batch
# Epoch 2/10 Iteration: 14400 Avg. Training loss: 4.2806 0.4533 sec/batch
# Epoch 2/10 Iteration: 14500 Avg. Training loss: 4.3048 0.4531 sec/batch
# Epoch 2/10 Iteration: 14600 Avg. Training loss: 4.2547 0.4541 sec/batch
# Epoch 2/10 Iteration: 14700 Avg. Training loss: 4.3548 0.4696 sec/batch
# Epoch 2/10 Iteration: 14800 Avg. Training loss: 4.2159 0.4680 sec/batch
# Epoch 2/10 Iteration: 14900 Avg. Training loss: 4.2310 0.4570 sec/batch
# Epoch 2/10 Iteration: 15000 Avg. Training loss: 4.3489 0.4548 sec/batch
# Nearest to and: of, other, millet, crowe, vocalists, also, with, various,
# Nearest to six: five, three, one, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, althea,
# Nearest to his: moved, he, time, whom, gifted, beckhams, mannerisms, screenplay,
# Nearest to would: disjointed, anticipation, legalization, adoptive, parked, prohibiting, carrey, niche,
# Nearest to or: literally, and, sehul, comparable, crowns, embodying, elisabetta, hellfire,
# Nearest to in: the, of, ducal, was, geezer, is, observer, satsuki,
# Nearest to as: cruzeiro, snippets, altruism, supported, mcghee, taken, torture, tarifit,
# Nearest to hold: carrying, evolving, rioted, petomane, parentage, segregated, lexicography, carried,
# Nearest to applications: networking, ttl, loom, intended, pediatric, contamination, iban, smaller,
# Nearest to governor: avanti, lieutenant, chief, hindenburg, vaclav, hanoi, seventeen, officer,
# Nearest to san: francisco, geographers, los, lmann, laborious, usk, pat, millionaire,
# Nearest to lived: buried, leavitt, seabird, gigantes, curse, fifteenth, after, moved,
# Nearest to engine: engines, oscilloscopes, powered, piston, flukes, submersible, portable, canopies,
# Nearest to troops: army, crokinole, loyalists, forces, saladin, attrition, corona, marines,
# Nearest to notes: handbook, eisa, diez, homicide, bassist, hartman, stags, introductory,
# Epoch 2/10 Iteration: 15100 Avg. Training loss: 4.3512 0.4636 sec/batch
# Epoch 2/10 Iteration: 15200 Avg. Training loss: 4.3328 0.4576 sec/batch
# Epoch 2/10 Iteration: 15300 Avg. Training loss: 4.3905 0.4552 sec/batch
# Epoch 2/10 Iteration: 15400 Avg. Training loss: 4.3605 0.4590 sec/batch
# Epoch 2/10 Iteration: 15500 Avg. Training loss: 4.2016 0.4533 sec/batch
# Epoch 2/10 Iteration: 15600 Avg. Training loss: 4.3241 0.4522 sec/batch
# Epoch 2/10 Iteration: 15700 Avg. Training loss: 4.2923 0.4516 sec/batch
# Epoch 2/10 Iteration: 15800 Avg. Training loss: 4.2984 0.4508 sec/batch
# Epoch 2/10 Iteration: 15900 Avg. Training loss: 4.3212 0.4527 sec/batch
# Epoch 2/10 Iteration: 16000 Avg. Training loss: 4.2626 0.4566 sec/batch
# Nearest to and: other, of, millet, also, with, various, or, vocalists,
# Nearest to six: five, three, two, one, four, nine, zero, ondes,
# Nearest to nine: one, two, six, five, eight, four, zero, althea,
# Nearest to his: he, moved, whom, gifted, time, beckhams, shocked, mannerisms,
# Nearest to would: parked, disjointed, anticipation, buffers, niche, could, carrey, legalization,
# Nearest to or: literally, and, hyperplasia, comparable, istat, sehul, are, called,
# Nearest to in: is, the, observer, of, geezer, minarets, mulattos, ducal,
# Nearest to as: cruzeiro, snippets, cylinders, supported, tarifit, manifolds, vernacular, altruism,
# Nearest to hold: carrying, evolving, rioted, petomane, segregated, carried, qualify, add,
# Nearest to applications: networking, loom, intended, ttl, iban, pediatric, onboard, ssi,
# Nearest to governor: avanti, lieutenant, chief, vaclav, appointed, hanoi, hindenburg, szlachta,
# Nearest to san: francisco, geographers, los, lmann, usk, laborious, pat, millionaire,
# Nearest to lived: leavitt, buried, gigantes, seabird, curse, sac, anthropoid, fifteenth,
# Nearest to engine: engines, oscilloscopes, powered, flukes, kam, piston, submersible, tripled,
# Nearest to troops: army, crokinole, loyalists, saladin, forces, attrition, corona, starvation,
# Nearest to notes: handbook, eisa, diez, homicide, introductory, hartman, stags, bassist,
# Epoch 2/10 Iteration: 16100 Avg. Training loss: 4.1066 0.4604 sec/batch
# Epoch 2/10 Iteration: 16200 Avg. Training loss: 4.3274 0.4590 sec/batch
# Epoch 2/10 Iteration: 16300 Avg. Training loss: 4.2225 0.4565 sec/batch
# Epoch 2/10 Iteration: 16400 Avg. Training loss: 4.2942 0.4550 sec/batch
# Epoch 2/10 Iteration: 16500 Avg. Training loss: 4.2689 0.4559 sec/batch
# Epoch 2/10 Iteration: 16600 Avg. Training loss: 4.2949 0.4533 sec/batch
# Epoch 2/10 Iteration: 16700 Avg. Training loss: 4.2880 0.4582 sec/batch
# Epoch 3/10 Iteration: 16800 Avg. Training loss: 4.3300 0.1119 sec/batch
# Epoch 3/10 Iteration: 16900 Avg. Training loss: 4.2614 0.4645 sec/batch
# Epoch 3/10 Iteration: 17000 Avg. Training loss: 4.2981 0.4671 sec/batch
# Nearest to and: other, of, with, millet, also, vocalists, various, karma,
# Nearest to six: five, three, one, two, four, nine, zero, pacifistic,
# Nearest to nine: one, two, six, eight, five, four, zero, shockley,
# Nearest to his: he, whom, moved, time, gifted, shocked, beckhams, screenplay,
# Nearest to would: anticipation, could, disjointed, parked, buffers, niche, tremendous, carrey,
# Nearest to or: literally, and, hyperplasia, falciparum, sehul, istat, comparable, synthetically,
# Nearest to in: the, is, of, observer, geezer, was, submissive, mulattos,
# Nearest to as: cruzeiro, supported, cylinders, tarifit, being, snippets, fundamentalism, and,
# Nearest to hold: carrying, evolving, rioted, petomane, carried, segregated, mitzvah, misgivings,
# Nearest to applications: networking, loom, ttl, intended, iban, linebarger, pediatric, extensions,
# Nearest to governor: avanti, lieutenant, chief, vaclav, appointed, hindenburg, szlachta, seventeen,
# Nearest to san: francisco, los, geographers, lmann, usk, laborious, pat, mounds,
# Nearest to lived: leavitt, buried, seabird, gigantes, curse, sac, anthropoid, rolf,
# Nearest to engine: engines, powered, oscilloscopes, submersible, piston, flukes, kam, canopies,
# Nearest to troops: army, crokinole, loyalists, forces, saladin, corona, attrition, fredericksburg,
# Nearest to notes: handbook, eisa, diez, introductory, homicide, fringing, hartman, stags,
# Epoch 3/10 Iteration: 17100 Avg. Training loss: 4.2312 0.4635 sec/batch
# Epoch 3/10 Iteration: 17200 Avg. Training loss: 4.2816 0.4567 sec/batch
# Epoch 3/10 Iteration: 17300 Avg. Training loss: 4.2304 0.4677 sec/batch
# Epoch 3/10 Iteration: 17400 Avg. Training loss: 4.2679 0.4614 sec/batch
# Epoch 3/10 Iteration: 17500 Avg. Training loss: 4.2759 0.4622 sec/batch
# Epoch 3/10 Iteration: 17600 Avg. Training loss: 4.2125 0.4536 sec/batch
# Epoch 3/10 Iteration: 17700 Avg. Training loss: 4.2553 0.4547 sec/batch
# Epoch 3/10 Iteration: 17800 Avg. Training loss: 4.2424 0.4545 sec/batch
# Epoch 3/10 Iteration: 17900 Avg. Training loss: 4.2481 0.4582 sec/batch
# Epoch 3/10 Iteration: 18000 Avg. Training loss: 4.1383 0.4639 sec/batch
# Nearest to and: of, other, with, millet, also, various, or, in,
# Nearest to six: five, three, one, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, unpaved,
# Nearest to his: he, moved, whom, gifted, beckhams, time, spent, mannerisms,
# Nearest to would: parked, anticipation, disjointed, could, niche, buffers, tremendous, drop,
# Nearest to or: literally, and, hyperplasia, sehul, comparable, falciparum, istat, pla,
# Nearest to in: the, is, of, was, and, from, observer, geezer,
# Nearest to as: cruzeiro, cylinders, tarifit, supported, snippets, and, being, blume,
# Nearest to hold: rioted, carrying, evolving, petomane, carried, misgivings, segregated, qualify,
# Nearest to applications: networking, loom, ttl, iban, intended, linebarger, extensions, ssi,
# Nearest to governor: avanti, lieutenant, appointed, chief, vaclav, legislature, enumerated, hindenburg,
# Nearest to san: francisco, los, geographers, usk, lmann, diego, laborious, organisations,
# Nearest to lived: seabird, leavitt, buried, gigantes, after, sac, anthropoid, curse,
# Nearest to engine: engines, powered, oscilloscopes, submersible, piston, flukes, kam, tripled,
# Nearest to troops: army, crokinole, forces, corona, loyalists, attrition, saladin, brigades,
# Nearest to notes: handbook, eisa, diez, introductory, hartman, stags, homicide, l,
# Epoch 3/10 Iteration: 18100 Avg. Training loss: 4.2590 0.4664 sec/batch
# Epoch 3/10 Iteration: 18200 Avg. Training loss: 4.3160 0.4720 sec/batch
# Epoch 3/10 Iteration: 18300 Avg. Training loss: 4.2911 0.4854 sec/batch
# Epoch 3/10 Iteration: 18400 Avg. Training loss: 4.2845 0.4611 sec/batch
# Epoch 3/10 Iteration: 18500 Avg. Training loss: 4.2958 0.4639 sec/batch
# Epoch 3/10 Iteration: 18600 Avg. Training loss: 4.2719 0.4669 sec/batch
# Epoch 3/10 Iteration: 18700 Avg. Training loss: 4.2220 0.4544 sec/batch
# Epoch 3/10 Iteration: 18800 Avg. Training loss: 4.1699 0.4597 sec/batch
# Epoch 3/10 Iteration: 18900 Avg. Training loss: 4.1461 0.4531 sec/batch
# Epoch 3/10 Iteration: 19000 Avg. Training loss: 4.2332 0.4823 sec/batch
# Nearest to and: of, other, with, millet, also, for, various, in,
# Nearest to six: five, three, one, two, four, nine, zero, eight,
# Nearest to nine: one, six, two, eight, five, four, zero, three,
# Nearest to his: he, gifted, whom, moved, time, mannerisms, spent, beckhams,
# Nearest to would: could, anticipation, niche, parked, disjointed, tremendous, buffers, starting,
# Nearest to or: literally, and, comparable, hyperplasia, falciparum, sehul, istat, are,
# Nearest to in: the, is, of, for, and, from, observer, was,
# Nearest to as: cruzeiro, and, snippets, supported, cylinders, tarifit, fundamentalism, mcghee,
# Nearest to hold: carrying, rioted, evolving, qualify, petomane, segregated, or, reggaeton,
# Nearest to applications: networking, loom, contamination, pediatric, ssi, iban, ttl, linebarger,
# Nearest to governor: lieutenant, avanti, appointed, chief, enumerated, seashore, vaclav, legislature,
# Nearest to san: francisco, los, geographers, usk, lmann, diego, laborious, mounds,
# Nearest to lived: seabird, leavitt, gigantes, buried, after, sac, anthropoid, crested,
# Nearest to engine: engines, oscilloscopes, powered, submersible, piston, kam, flukes, canopies,
# Nearest to troops: army, crokinole, forces, attrition, loyalists, saladin, corona, battlefield,
# Nearest to notes: handbook, eisa, diez, introductory, hartman, stags, acadia, homicide,
# Epoch 3/10 Iteration: 19100 Avg. Training loss: 4.1873 0.4721 sec/batch
# Epoch 3/10 Iteration: 19200 Avg. Training loss: 4.2208 0.4535 sec/batch
# Epoch 3/10 Iteration: 19300 Avg. Training loss: 4.1983 0.4557 sec/batch
# Epoch 3/10 Iteration: 19400 Avg. Training loss: 4.2629 0.4537 sec/batch
# Epoch 3/10 Iteration: 19500 Avg. Training loss: 4.2528 0.4568 sec/batch
# Epoch 3/10 Iteration: 19600 Avg. Training loss: 4.2485 0.8970 sec/batch
# Epoch 3/10 Iteration: 19700 Avg. Training loss: 4.2201 0.5475 sec/batch
# Epoch 3/10 Iteration: 19800 Avg. Training loss: 4.2905 0.4603 sec/batch
# Epoch 3/10 Iteration: 19900 Avg. Training loss: 4.1697 0.4581 sec/batch
# Epoch 3/10 Iteration: 20000 Avg. Training loss: 4.2215 0.4623 sec/batch
# Nearest to and: of, other, with, or, vocalists, various, millet, a,
# Nearest to six: five, one, three, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, three,
# Nearest to his: he, time, whom, gifted, screenplay, mannerisms, spent, moved,
# Nearest to would: could, niche, anticipation, parked, disjointed, starting, buffers, answer,
# Nearest to or: literally, and, falciparum, called, istat, hyperplasia, are, special,
# Nearest to in: the, is, of, was, for, a, and, hemi,
# Nearest to as: snippets, cylinders, and, cruzeiro, mcghee, being, blume, body,
# Nearest to hold: carrying, evolving, rioted, or, qualify, petomane, add, reggaeton,
# Nearest to applications: loom, networking, ttl, ssi, contamination, smaller, iban, nistru,
# Nearest to governor: lieutenant, avanti, chief, appointed, vaclav, seashore, hindenburg, legislature,
# Nearest to san: francisco, los, geographers, usk, diego, lmann, laborious, encounters,
# Nearest to lived: leavitt, seabird, gigantes, buried, pears, anthropoid, after, ramesh,
# Nearest to engine: engines, piston, oscilloscopes, powered, flukes, submersible, kam, designs,
# Nearest to troops: army, crokinole, attrition, forces, battlefield, loyalists, saladin, corona,
# Nearest to notes: handbook, eisa, diez, stags, hartman, fringing, introductory, l,
# Epoch 3/10 Iteration: 20100 Avg. Training loss: 4.2480 0.4575 sec/batch
# Epoch 3/10 Iteration: 20200 Avg. Training loss: 4.2519 0.4524 sec/batch
# Epoch 3/10 Iteration: 20300 Avg. Training loss: 4.2832 0.4560 sec/batch
# Epoch 3/10 Iteration: 20400 Avg. Training loss: 4.2329 0.4536 sec/batch
# Epoch 3/10 Iteration: 20500 Avg. Training loss: 4.1928 0.4725 sec/batch
# Epoch 3/10 Iteration: 20600 Avg. Training loss: 4.1759 0.4613 sec/batch
# Epoch 3/10 Iteration: 20700 Avg. Training loss: 4.2384 0.4524 sec/batch
# Epoch 3/10 Iteration: 20800 Avg. Training loss: 4.2402 0.4526 sec/batch
# Epoch 3/10 Iteration: 20900 Avg. Training loss: 4.2560 0.4517 sec/batch
# Epoch 3/10 Iteration: 21000 Avg. Training loss: 4.2078 0.4543 sec/batch
# Nearest to and: of, other, with, various, in, vocalists, millet, also,
# Nearest to six: five, three, one, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, three,
# Nearest to his: he, whom, gifted, screenplay, moved, mannerisms, time, spent,
# Nearest to would: anticipation, disjointed, could, parked, niche, albinus, adoptive, carrey,
# Nearest to or: literally, and, hyperplasia, istat, hold, comparable, falciparum, called,
# Nearest to in: the, of, is, was, and, a, for, from,
# Nearest to as: and, snippets, mcghee, known, fundamentalism, cruzeiro, supported, being,
# Nearest to hold: carrying, rioted, or, evolving, qualify, petomane, add, lexicography,
# Nearest to applications: loom, networking, ttl, contamination, linebarger, ssi, iban, nistru,
# Nearest to governor: lieutenant, chief, appointed, avanti, majlis, hindenburg, seashore, legislature,
# Nearest to san: francisco, los, geographers, lmann, usk, diego, laborious, encounters,
# Nearest to lived: seabird, leavitt, gigantes, buried, after, consorts, pears, anthropoid,
# Nearest to engine: engines, piston, oscilloscopes, powered, submersible, flukes, kam, canopies,
# Nearest to troops: army, crokinole, attrition, forces, loyalists, battlefield, saladin, corona,
# Nearest to notes: handbook, eisa, diez, hartman, fringing, stags, homicide, introductory,
# Epoch 3/10 Iteration: 21100 Avg. Training loss: 4.2123 0.4610 sec/batch
# Epoch 3/10 Iteration: 21200 Avg. Training loss: 4.2532 0.4532 sec/batch
# Epoch 3/10 Iteration: 21300 Avg. Training loss: 4.1602 0.4533 sec/batch
# Epoch 3/10 Iteration: 21400 Avg. Training loss: 4.2512 0.4553 sec/batch
# Epoch 3/10 Iteration: 21500 Avg. Training loss: 4.2138 0.4579 sec/batch
# Epoch 3/10 Iteration: 21600 Avg. Training loss: 4.1231 0.4538 sec/batch
# Epoch 3/10 Iteration: 21700 Avg. Training loss: 4.2478 0.4510 sec/batch
# Epoch 3/10 Iteration: 21800 Avg. Training loss: 4.2322 0.4538 sec/batch
# Epoch 3/10 Iteration: 21900 Avg. Training loss: 4.2548 0.4539 sec/batch
# Epoch 3/10 Iteration: 22000 Avg. Training loss: 4.2369 0.4528 sec/batch
# Nearest to and: of, other, with, in, various, millet, as, vocalists,
# Nearest to six: five, one, three, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, three,
# Nearest to his: he, whom, gifted, mannerisms, moved, spent, time, screenplay,
# Nearest to would: could, anticipation, disjointed, parked, impeach, albinus, niche, make,
# Nearest to or: literally, and, hyperplasia, istat, special, hold, falciparum, comparable,
# Nearest to in: the, of, is, and, was, a, from, for,
# Nearest to as: and, known, snippets, being, the, mcghee, in, vernacular,
# Nearest to hold: carrying, petomane, add, evolving, segregated, rioted, lexicography, or,
# Nearest to applications: loom, networking, contamination, ttl, iban, nistru, linebarger, ssi,
# Nearest to governor: lieutenant, chief, appointed, avanti, enumerated, vaclav, majlis, officer,
# Nearest to san: francisco, los, usk, geographers, lmann, laborious, diego, organisations,
# Nearest to lived: seabird, leavitt, gigantes, buried, after, anthropoid, pears, drover,
# Nearest to engine: engines, piston, powered, oscilloscopes, submersible, flukes, kam, stu,
# Nearest to troops: army, crokinole, attrition, forces, loyalists, saladin, starvation, soldiers,
# Nearest to notes: handbook, eisa, hartman, diez, fringing, stags, introductory, curiosities,
# Epoch 3/10 Iteration: 22100 Avg. Training loss: 4.2176 0.4590 sec/batch
# Epoch 3/10 Iteration: 22200 Avg. Training loss: 4.2464 0.4551 sec/batch
# Epoch 3/10 Iteration: 22300 Avg. Training loss: 4.2099 0.4542 sec/batch
# Epoch 3/10 Iteration: 22400 Avg. Training loss: 4.2395 0.4599 sec/batch
# Epoch 3/10 Iteration: 22500 Avg. Training loss: 4.2379 0.4543 sec/batch
# Epoch 3/10 Iteration: 22600 Avg. Training loss: 4.2473 0.4538 sec/batch
# Epoch 3/10 Iteration: 22700 Avg. Training loss: 4.1478 0.4588 sec/batch
# Epoch 3/10 Iteration: 22800 Avg. Training loss: 4.1924 0.4535 sec/batch
# Epoch 3/10 Iteration: 22900 Avg. Training loss: 4.2191 0.4543 sec/batch
# Epoch 3/10 Iteration: 23000 Avg. Training loss: 4.1769 0.4609 sec/batch
# Nearest to and: of, other, with, in, for, various, also, as,
# Nearest to six: five, three, one, two, four, nine, zero, eight,
# Nearest to nine: one, two, six, eight, five, four, zero, three,
# Nearest to his: he, moved, spent, gifted, whom, died, screenplay, mannerisms,
# Nearest to would: could, anticipation, niche, buffers, parked, make, that, bulbs,
# Nearest to or: literally, and, hyperplasia, are, loaded, special, may, impedance,
# Nearest to in: the, of, is, and, for, was, a, from,
# Nearest to as: and, snippets, being, the, supported, also, known, in,
# ...
# Epoch 10/10 Iteration: 75500 Avg. Training loss: 4.1481 0.0369 sec/batch
# Epoch 10/10 Iteration: 75600 Avg. Training loss: 4.0864 0.4582 sec/batch
# Epoch 10/10 Iteration: 75700 Avg. Training loss: 4.0827 0.4568 sec/batch
# Epoch 10/10 Iteration: 75800 Avg. Training loss: 4.0258 0.4591 sec/batch
# Epoch 10/10 Iteration: 75900 Avg. Training loss: 4.0636 0.4568 sec/batch
# Epoch 10/10 Iteration: 76000 Avg. Training loss: 4.0451 0.4588 sec/batch
# Nearest to and: of, in, other, with, the, as, including, also,
# Nearest to six: five, one, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, two, three, four, five, seven,
# Nearest to his: he, him, himself, was, died, death, of, moved,
# Nearest to would: could, might, did, able, likely, to, that, if,
# Nearest to or: either, may, other, are, usually, often, any, a,
# Nearest to in: the, of, and, a, is, which, was, also,
# Nearest to as: known, well, and, in, also, such, the, called,
# Nearest to hold: held, holds, add, allowed, jeans, theological, accept, goa,
# Nearest to applications: koffice, energetic, lengthy, flatwater, kandinsky, iban, orioles, globes,
# Nearest to governor: lieutenant, industrialist, isma, ceremonial, commanding, totaled, appointed, feroz,
# Nearest to san: francisco, diego, california, lmann, constants, los, encounters, organisations,
# Nearest to lived: moved, short, lives, after, until, early, allotted, pio,
# Nearest to engine: engines, glider, aptly, cylinder, afghanistan, goddard, youngest, gasoline,
# Nearest to troops: forces, army, soldiers, armies, marines, wresting, tecumseh, brigade,
# Nearest to notes: note, scales, islamism, curiosities, hartman, simplifies, nge, tonic,
# Epoch 10/10 Iteration: 76100 Avg. Training loss: 4.0656 0.4608 sec/batch
# Epoch 10/10 Iteration: 76200 Avg. Training loss: 4.0976 0.4587 sec/batch
# Epoch 10/10 Iteration: 76300 Avg. Training loss: 4.0492 0.4558 sec/batch
# Epoch 10/10 Iteration: 76400 Avg. Training loss: 4.0882 0.4566 sec/batch
# Epoch 10/10 Iteration: 76500 Avg. Training loss: 4.0671 0.4560 sec/batch
# Epoch 10/10 Iteration: 76600 Avg. Training loss: 4.0748 0.4663 sec/batch
# Epoch 10/10 Iteration: 76700 Avg. Training loss: 3.9619 0.4542 sec/batch
# Epoch 10/10 Iteration: 76800 Avg. Training loss: 4.0725 0.4563 sec/batch
# Epoch 10/10 Iteration: 76900 Avg. Training loss: 4.1031 0.4577 sec/batch
# Epoch 10/10 Iteration: 77000 Avg. Training loss: 4.0841 0.4573 sec/batch
# Nearest to and: of, other, in, with, including, both, as, such,
# Nearest to six: five, one, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, two, three, five, four, seven,
# Nearest to his: he, him, himself, career, spent, death, moved, died,
# Nearest to would: could, might, did, able, to, likely, if, that,
# Nearest to or: either, may, any, usually, are, other, often, and,
# Nearest to in: the, and, of, which, a, is, also, as,
# Nearest to as: known, well, and, in, such, also, the, often,
# Nearest to hold: held, holds, add, allowed, accept, jeans, take, hand,
# Nearest to applications: koffice, flatwater, energetic, lengthy, mozilla, orioles, retainer, globes,
# Nearest to governor: lieutenant, appointed, industrialist, ceremonial, isma, totaled, feroz, tar,
# Nearest to san: francisco, diego, california, lmann, constants, los, encounters, organisations,
# Nearest to lived: moved, short, lives, until, pio, decays, allotted, buried,
# Nearest to engine: engines, glider, aptly, gasoline, afghanistan, goddard, mpg, canopies,
# Nearest to troops: forces, army, soldiers, armies, marines, wresting, brigade, tecumseh,
# Nearest to notes: note, curiosities, islamism, hartman, scales, nge, simplifies, rhodesian,
# Epoch 10/10 Iteration: 77100 Avg. Training loss: 4.0997 0.4665 sec/batch
# Epoch 10/10 Iteration: 77200 Avg. Training loss: 4.0824 0.4546 sec/batch
# Epoch 10/10 Iteration: 77300 Avg. Training loss: 4.1154 0.4567 sec/batch
# Epoch 10/10 Iteration: 77400 Avg. Training loss: 4.0739 0.4538 sec/batch
# Epoch 10/10 Iteration: 77500 Avg. Training loss: 4.0040 0.4555 sec/batch
# Epoch 10/10 Iteration: 77600 Avg. Training loss: 3.9421 0.4587 sec/batch
# Epoch 10/10 Iteration: 77700 Avg. Training loss: 4.0394 0.4539 sec/batch
# Epoch 10/10 Iteration: 77800 Avg. Training loss: 4.0441 0.4554 sec/batch
# Epoch 10/10 Iteration: 77900 Avg. Training loss: 4.0485 0.4535 sec/batch
# Epoch 10/10 Iteration: 78000 Avg. Training loss: 3.9968 0.4516 sec/batch
# Nearest to and: of, in, other, with, including, the, such, as,
# Nearest to six: five, one, three, four, two, eight, nine, zero,
# Nearest to nine: one, eight, six, five, three, four, two, seven,
# Nearest to his: he, himself, him, career, spent, died, moved, considerable,
# Nearest to would: could, might, did, able, to, likely, possible, that,
# Nearest to or: either, may, any, usually, other, are, a, often,
# Nearest to in: the, of, and, is, which, a, also, as,
# Nearest to as: well, known, and, in, such, also, the, often,
# Nearest to hold: held, holds, allowed, add, hand, take, accept, eeeeee,
# Nearest to applications: koffice, lengthy, flatwater, energetic, kandinsky, retainer, silicon, neri,
# Nearest to governor: lieutenant, isma, appointed, feroz, industrialist, totaled, commanding, ceremonial,
# Nearest to san: francisco, diego, california, constants, lmann, los, encounters, atherton,
# Nearest to lived: short, moved, lives, until, pio, buried, allotted, briefly,
# Nearest to engine: engines, glider, aptly, afghanistan, labours, ramjet, goddard, canopies,
# Nearest to troops: army, forces, soldiers, armies, marines, wresting, brigade, starvation,
# Nearest to notes: note, simplifies, curiosities, islamism, scales, hartman, tonic, nebuchadnezzar,
# Epoch 10/10 Iteration: 78100 Avg. Training loss: 4.0663 0.4623 sec/batch
# Epoch 10/10 Iteration: 78200 Avg. Training loss: 4.0801 0.4589 sec/batch
# Epoch 10/10 Iteration: 78300 Avg. Training loss: 4.0789 0.4558 sec/batch
# Epoch 10/10 Iteration: 78400 Avg. Training loss: 4.0533 0.4575 sec/batch
# Epoch 10/10 Iteration: 78500 Avg. Training loss: 4.0982 0.4545 sec/batch
# Epoch 10/10 Iteration: 78600 Avg. Training loss: 4.0229 0.4558 sec/batch
# Epoch 10/10 Iteration: 78700 Avg. Training loss: 4.0747 0.4529 sec/batch
# Epoch 10/10 Iteration: 78800 Avg. Training loss: 4.0418 0.4580 sec/batch
# Epoch 10/10 Iteration: 78900 Avg. Training loss: 4.1212 0.4663 sec/batch
# Epoch 10/10 Iteration: 79000 Avg. Training loss: 4.1209 0.4595 sec/batch
# Nearest to and: of, in, with, other, the, as, including, both,
# Nearest to six: five, one, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, five, two, four, seven, three,
# Nearest to his: he, himself, him, career, spent, after, own, died,
# Nearest to would: could, might, did, able, likely, not, to, allow,
# Nearest to or: either, may, any, usually, a, other, are, often,
# Nearest to in: the, and, of, a, which, also, as, is,
# Nearest to as: well, known, and, in, such, also, the, often,
# Nearest to hold: held, holds, add, allowed, hand, accept, jeans, take,
# Nearest to applications: koffice, lengthy, flatwater, energetic, widespread, globes, retainer, mozilla,
# Nearest to governor: lieutenant, feroz, industrialist, isma, commanding, totaled, ceremonial, appointed,
# Nearest to san: francisco, diego, california, los, constants, lmann, encounters, atherton,
# Nearest to lived: short, moved, lives, until, pio, life, briefly, allotted,
# Nearest to engine: engines, glider, pump, afghanistan, aptly, labours, gasoline, cylinder,
# Nearest to troops: army, forces, soldiers, armies, marines, brigade, tecumseh, wresting,
# Nearest to notes: note, hartman, curiosities, simplifies, islamism, nebuchadnezzar, nge, rhodesian,
# Epoch 10/10 Iteration: 79100 Avg. Training loss: 4.0977 0.4716 sec/batch
# Epoch 10/10 Iteration: 79200 Avg. Training loss: 4.0232 0.4560 sec/batch
# Epoch 10/10 Iteration: 79300 Avg. Training loss: 4.0159 0.4534 sec/batch
# Epoch 10/10 Iteration: 79400 Avg. Training loss: 4.1026 0.4568 sec/batch
# Epoch 10/10 Iteration: 79500 Avg. Training loss: 4.0564 0.4640 sec/batch
# Epoch 10/10 Iteration: 79600 Avg. Training loss: 4.0917 0.4632 sec/batch
# Epoch 10/10 Iteration: 79700 Avg. Training loss: 4.0264 0.4633 sec/batch
# Epoch 10/10 Iteration: 79800 Avg. Training loss: 4.0557 0.4622 sec/batch
# Epoch 10/10 Iteration: 79900 Avg. Training loss: 4.1052 0.4644 sec/batch
# Epoch 10/10 Iteration: 80000 Avg. Training loss: 4.0011 0.4531 sec/batch
# Nearest to and: of, other, with, in, including, also, both, as,
# Nearest to six: five, one, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, seven, five, four, two, three,
# Nearest to his: he, himself, him, career, died, moved, death, spent,
# Nearest to would: could, might, did, able, to, allow, if, possible,
# Nearest to or: either, any, may, usually, other, a, often, are,
# Nearest to in: the, of, and, which, a, first, also, as,
# Nearest to as: well, known, such, and, in, often, also, sometimes,
# Nearest to hold: held, holds, add, allowed, hand, take, accept, jeans,
# Nearest to applications: koffice, flatwater, lengthy, energetic, retainer, globes, mozilla, iban,
# Nearest to governor: lieutenant, industrialist, feroz, isma, ceremonial, commanding, totaled, tar,
# Nearest to san: francisco, diego, california, lmann, los, constants, encounters, signifies,
# Nearest to lived: short, moved, lives, life, pio, until, after, briefly,
# Nearest to engine: engines, glider, pump, aptly, labours, afghanistan, ramjet, cylinder,
# Nearest to troops: army, forces, soldiers, armies, marines, brigade, tecumseh, attacked,
# Nearest to notes: note, curiosities, simplifies, hartman, nge, islamism, shillings, nebuchadnezzar,
# Epoch 10/10 Iteration: 80100 Avg. Training loss: 4.1251 0.4633 sec/batch
# Epoch 10/10 Iteration: 80200 Avg. Training loss: 4.0688 0.4664 sec/batch
# Epoch 10/10 Iteration: 80300 Avg. Training loss: 3.9761 0.4543 sec/batch
# Epoch 10/10 Iteration: 80400 Avg. Training loss: 4.0967 0.4557 sec/batch
# Epoch 10/10 Iteration: 80500 Avg. Training loss: 4.0799 0.4564 sec/batch
# Epoch 10/10 Iteration: 80600 Avg. Training loss: 4.1052 0.4544 sec/batch
# Epoch 10/10 Iteration: 80700 Avg. Training loss: 4.0935 0.4648 sec/batch
# Epoch 10/10 Iteration: 80800 Avg. Training loss: 4.0323 0.4675 sec/batch
# Epoch 10/10 Iteration: 80900 Avg. Training loss: 4.0966 0.4634 sec/batch
# Epoch 10/10 Iteration: 81000 Avg. Training loss: 4.0805 0.4554 sec/batch
# Nearest to and: of, in, other, including, with, as, the, such,
# Nearest to six: one, five, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, two, seven, three, four, five,
# Nearest to his: he, himself, him, career, died, spent, death, moved,
# Nearest to would: could, might, did, to, able, that, likely, possible,
# Nearest to or: either, may, usually, any, a, other, are, often,
# Nearest to in: the, of, and, which, a, was, also, as,
# Nearest to as: well, and, known, such, often, also, in, the,
# Nearest to hold: held, holds, add, hand, allowed, take, accept, jeans,
# Nearest to applications: koffice, flatwater, lengthy, globes, energetic, mozilla, widespread, retainer,
# Nearest to governor: lieutenant, ceremonial, feroz, industrialist, isma, appointed, commanding, synod,
# Nearest to san: francisco, diego, california, lmann, constants, los, encounters, mounds,
# Nearest to lived: short, moved, lives, life, allotted, pio, after, briefly,
# Nearest to engine: engines, glider, pump, labours, afghanistan, aptly, ramjet, youngest,
# Nearest to troops: army, forces, soldiers, armies, marines, brigade, attacked, starvation,
# Nearest to notes: note, curiosities, simplifies, nge, nebuchadnezzar, hartman, shillings, islamism,
# Epoch 10/10 Iteration: 81100 Avg. Training loss: 4.1188 0.4682 sec/batch
# Epoch 10/10 Iteration: 81200 Avg. Training loss: 4.0751 0.4581 sec/batch
# Epoch 10/10 Iteration: 81300 Avg. Training loss: 4.0612 0.4537 sec/batch
# Epoch 10/10 Iteration: 81400 Avg. Training loss: 4.0000 0.4527 sec/batch
# Epoch 10/10 Iteration: 81500 Avg. Training loss: 4.0321 0.4682 sec/batch
# Epoch 10/10 Iteration: 81600 Avg. Training loss: 4.0337 0.4535 sec/batch
# Epoch 10/10 Iteration: 81700 Avg. Training loss: 4.0283 0.4565 sec/batch
# Epoch 10/10 Iteration: 81800 Avg. Training loss: 4.1036 0.4548 sec/batch
# Epoch 10/10 Iteration: 81900 Avg. Training loss: 3.9279 0.4978 sec/batch
# Epoch 10/10 Iteration: 82000 Avg. Training loss: 4.0036 0.4570 sec/batch
# Nearest to and: of, in, other, with, as, including, the, both,
# Nearest to six: five, one, three, four, two, eight, nine, seven,
# Nearest to nine: one, eight, six, two, four, five, three, seven,
# Nearest to his: he, himself, him, career, moved, died, spent, death,
# Nearest to would: could, might, did, to, likely, able, that, if,
# Nearest to or: either, may, usually, any, other, are, often, specific,
# Nearest to in: the, of, and, a, which, also, is, was,
# Nearest to as: well, and, known, in, such, also, often, the,
# Nearest to hold: held, holds, add, allowed, hand, accept, take, jeans,
# Nearest to applications: koffice, flatwater, globes, lengthy, mozilla, widespread, energetic, networking,
# Nearest to governor: lieutenant, ceremonial, industrialist, feroz, commanding, synod, appointed, isma,
# Nearest to san: francisco, diego, california, lmann, constants, los, encounters, marino,
# Nearest to lived: short, moved, lives, after, life, until, buried, briefly,
# Nearest to engine: engines, glider, labours, pump, afghanistan, ramjet, cylinder, canopies,
# Nearest to troops: army, forces, soldiers, armies, marines, brigade, tecumseh, attacked,
# Nearest to notes: note, curiosities, simplifies, islamism, hartman, nebuchadnezzar, nge, sixth,
# Epoch 10/10 Iteration: 82100 Avg. Training loss: 4.1144 0.4648 sec/batch
# Epoch 10/10 Iteration: 82200 Avg. Training loss: 4.1436 0.4595 sec/batch
# Epoch 10/10 Iteration: 82300 Avg. Training loss: 4.1215 0.4541 sec/batch
# Epoch 10/10 Iteration: 82400 Avg. Training loss: 4.1550 0.4572 sec/batch
# Epoch 10/10 Iteration: 82500 Avg. Training loss: 4.1184 0.4542 sec/batch
# Epoch 10/10 Iteration: 82600 Avg. Training loss: 3.9733 0.4525 sec/batch
# Epoch 10/10 Iteration: 82700 Avg. Training loss: 4.0905 0.4517 sec/batch
# Epoch 10/10 Iteration: 82800 Avg. Training loss: 4.0401 0.4630 sec/batch
# Epoch 10/10 Iteration: 82900 Avg. Training loss: 4.0499 0.4535 sec/batch
# Epoch 10/10 Iteration: 83000 Avg. Training loss: 4.1176 0.4583 sec/batch
# Nearest to and: of, other, in, including, as, such, with, also,
# Nearest to six: five, three, one, four, two, eight, nine, seven,
# Nearest to nine: one, eight, two, six, seven, three, four, five,
# Nearest to his: he, himself, him, career, moved, died, spent, death,
# Nearest to would: could, might, did, to, able, likely, if, that,
# Nearest to or: either, usually, may, any, a, other, are, often,
# Nearest to in: the, and, of, which, a, also, as, is,
# Nearest to as: well, and, known, such, in, often, also, sometimes,
# Nearest to hold: held, holds, add, hand, take, accept, allowed, jeans,
# Nearest to applications: koffice, flatwater, energetic, lengthy, retainer, mozilla, globes, widespread,
# Nearest to governor: lieutenant, ceremonial, isma, feroz, commanding, industrialist, totaled, millimeters,
# Nearest to san: francisco, diego, california, lmann, constants, los, signifies, angeles,
# Nearest to lived: moved, short, lives, allotted, life, briefly, buried, pio,
# Nearest to engine: engines, glider, pump, labours, afghanistan, ramjet, mpg, cylinder,
# Nearest to troops: forces, army, soldiers, armies, brigade, marines, attacked, starvation,
# Nearest to notes: note, islamism, curiosities, simplifies, hartman, sixth, nge, rhodesian,
# Epoch 10/10 Iteration: 83100 Avg. Training loss: 4.0116 0.4670 sec/batch
# Epoch 10/10 Iteration: 83200 Avg. Training loss: 3.8475 0.4580 sec/batch
# Epoch 10/10 Iteration: 83300 Avg. Training loss: 4.1044 0.4590 sec/batch
# Epoch 10/10 Iteration: 83400 Avg. Training loss: 4.0198 0.4576 sec/batch
# Epoch 10/10 Iteration: 83500 Avg. Training loss: 4.0731 0.4605 sec/batch
# Epoch 10/10 Iteration: 83600 Avg. Training loss: 4.0757 0.4534 sec/batch
# Epoch 10/10 Iteration: 83700 Avg. Training loss: 4.0483 0.4556 sec/batch
# Epoch 10/10 Iteration: 83800 Avg. Training loss: 4.0891 0.4531 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
