# %%
import pandas as pd
df = pd.read_csv('matches.csv', sep=',')

# %%
scored = {}
missed = {}
won = {}
lost = {}
draw = {}
for match, score in enumerate(df['score1']):
    if df['team1'][match] == 'A':
        if scored.get('A', 0)==0:
            scored['A']=score
        else:
            scored["A"]+=score

            
    if df['team1'][match] == 'B':
        if scored.get('B', 0)==0:
            scored['B']=score
        else:
            scored["B"]+=score

            
    if df['team1'][match] == 'C':
        if scored.get('C', 0)==0:
            scored['C']=score
        else:
            scored["C"]+=score

            
    if df['team1'][match] == 'D':
        if scored.get('D', 0)==0:
            scored['D']=score
        else:
            scored["D"]+=score


    if df['team1'][match] == 'E':
        if scored.get('E', 0)==0:
            scored['E']=score
        else:
            scored["E"]+=score


    if df['team1'][match] == 'F':
        if scored.get('F', 0)==0:
            scored['F']=score
        else:
            scored["F"]+=score

            
    if df['team1'][match] == 'G':
        if scored.get('G', 0)==0:
            scored['G']=score
        else:
            scored["G"]+=score

            
    if df['team1'][match] == 'H':
        if scored.get('H', 0)==0:
            scored['H']=score
        else:
            scored["H"]+=score

            
            
for match, score in enumerate(df['score2']):
    if df['team2'][match] == 'A':
        if scored.get('A', 0)==0:
            scored['A']=score
        else:
            scored["B"]+=score
            
    if df['team2'][match] == 'B':
        if scored.get('B', 0)==0:
            scored['B']=score
        else:
            scored["B"]+=score
        
    if df['team2'][match] == 'C':
        if scored.get('C', 0)==0:
            scored['C']=score
        else:
            scored["C"]+=score
            
    if df['team2'][match] == 'D':
        if scored.get('D', 0)==0:
            scored['D']=score
        else:
            scored["D"]+=score
            
    if df['team2'][match] == 'E':
        if scored.get('E', 0)==0:
            scored['E']=score
        else:
            scored["E"]+=score
            
    if df['team2'][match] == 'F':
        if scored.get('F', 0)==0:
            scored['F']=score
        else:
            scored["F"]+=score

    if df['team2'][match] == 'G':
        if scored.get('G', 0)==0:
            scored['G']=score
        else:
            scored["G"]+=score
            
    if df['team2'][match] == 'H':
        if scored.get('H', 0)==0:
            scored['H']=score
        else:
            scored["H"]+=score
            
            
for match, score in enumerate(df['score2']):
    if df['team1'][match] == 'A':
        if missed.get('A', 0)==0:
            missed['A']=score
        else:
            missed["A"]+=score
            
    if df['team1'][match] == 'B':
        if missed.get('B', 0)==0:
            missed['B']=score
        else:
            missed["B"]+=score
            
    if df['team1'][match] == 'C':
        if missed.get('C', 0)==0:
            missed['C']=score
        else:
            missed["C"]+=score
            
    if df['team1'][match] == 'D':
        if missed.get('D', 0)==0:
            missed['D']=score
        else:
            missed["D"]+=score
            
    if df['team1'][match] == 'E':
        if missed.get('E', 0)==0:
            missed['E']=score
        else:
            missed["E"]+=score
            
    if df['team1'][match] == 'F':
        if missed.get('F', 0)==0:
            missed['F']=score
        else:
            missed["F"]+=score
            
    if df['team1'][match] == 'G':
        if missed.get('G', 0)==0:
            missed['G']=score
        else:
            missed["G"]+=score
            
    if df['team1'][match] == 'H':
        if missed.get('H', 0)==0:
            missed['H']=score
        else:
            missed["H"]+=score
            

for match, score in enumerate(df['score1']):
    if df['team2'][match] == 'A':
        if missed.get('A', 0)==0:
            missed['A']=score
        else:
            missed["A"]+=score
            
    if df['team2'][match] == 'B':
        if missed.get('B', 0)==0:
            missed['B']=score
        else:
            missed["B"]+=score
            
    if df['team2'][match] == 'C':
        if missed.get('C', 0)==0:
            missed['C']=score
        else:
            missed["C"]+=score
            
    if df['team2'][match] == 'D':
        if missed.get('D', 0)==0:
            missed['D']=score
        else:
            missed["D"]+=score
            
    if df['team2'][match] == 'E':
        if missed.get('E', 0)==0:
            missed['E']=score
        else:
            missed["E"]+=score
            
    if df['team2'][match] == 'F':
        if missed.get('F', 0)==0:
            missed['F']=score
        else:
            missed["F"]+=score
            
    if df['team2'][match] == 'G':
        if missed.get('G', 0)==0:
            missed['G']=score
        else:
            missed["G"]+=score
            
    if df['team2'][match] == 'H':
        if missed.get('H', 0)==0:
            missed['H']=score
        else:
            missed["H"]+=score
            
for match, team in enumerate(df['team1']):
    if df['score1'][match] > df['score2'][match]:
        if won.get(team, 0)==0:
            won[team]=1
        else:
            won[team]+=1
for match, team in enumerate(df['team2']):
    if df['score2'][match] > df['score1'][match]:
        if won.get(team, 0)==0:
            won[team]=1
        else:
            won[team]+=1
            
for match, team in enumerate(df['team1']):
    if df['score1'][match] < df['score2'][match]:
        if lost.get(team, 0)==0:
            lost[team]=1
        else:
            lost[team]+=1
for match, team in enumerate(df['team2']):
    if df['score2'][match] < df['score1'][match]:
        if lost.get(team, 0)==0:
            lost[team]=1
        else:
            lost[team]+=1
            
for match, team in enumerate(df['team1']):
    if df['score1'][match] == df['score2'][match]:
        if draw.get(team, 0)==0:
            draw[team]=1
        else:
            draw[team]+=1
for match, team in enumerate(df['team2']):
    if df['score2'][match] == df['score1'][match]:
        if draw.get(team, 0)==0:
            draw[team]=1
        else:
            draw[team]+=1

# %%
teams = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']

# %%
data_table = [[d.get(team, 0) for team in teams] for d in [scored, missed, won, lost, draw]]

# %%
l = ["scored", "missed", "won", "lost", "draw"]
for i in range(len(data_table)):
    data_table[i].insert(0, l[i])

# %%
teams.insert(0, 'names')

# %%
table = pd.DataFrame(data=data_table, columns=teams)

# %%
print(table)
# Out:
#     names   A   B   C   D   E   F   G   H
# 0  scored  14  16  16  11  21  16  18  20
# 1  missed  11  15  20  21  14  18  17  16
# 2     won   4   3   2   0   5   3   2   3
# 3    lost   1   3   3   6   1   3   3   2
# 4    draw   2   1   2   1   1   1   2   2
