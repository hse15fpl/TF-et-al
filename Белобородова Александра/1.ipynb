# %% [markdown]
# 6.Заданы координаты точек на плоскости (могут присутствовать совпадающие точки). Реализовать сортировку точек по их удалению от центра множества и определить, представляют ли они вершины правильного многоугольника (в этом случае вывести количество его вершин).

# %%
#функция расстояния
from math import sqrt
def dist(a, b):
    d = sqrt((a[0]-b[0])**2+(a[1]-b[1])**2)
    return round(d, 2)

# %%
def clean(p):
    #убрали имеющиеся повторы, чтоб не мешали 
    new_p = list(set(p))
    print('повторяющихся точек: ', len(p)-len(new_p))
    return new_p
    
def sort(p):
   #поиск центра
    x,y=zip(*p)
    center=(sum(x)/len(x), sum(y)/len(y)) 
    #что здесь подразумевается под центром? 
    #пробовала также формулу "разность между большим и меньшим х, у, деленная на два", но это не работает для треугольника
    print('центр: ', center)
    distances = {}
    for i in p:
        distances[i] = dist(i,center)
    #print(distances)
    sorted_distances = sorted(distances, key=distances.get, reverse=False)
    print('Точки в порядке удаления от цетра:', sorted_distances, '(если равноудалены, сортируются по х,у)')
    return distances

# %%
def polygon(p,distances):
    
    if len(set(distances.values()))>1:
        print('НЕ все точки равноудалены от цетра - не является правильным многоугольником')
    else:
        print('ВСЕ точки равноудалены от цетра')
        all_dist = [set([dist(i, b) for b in p if b!=i]) for i in p] #расстояния каждой точки до всех точек с исключением повторов
        #print(all_dist)
        if all(all_dist[i] == all_dist[i+1] for i in range(len(all_dist)-1)):
            print('Точки {0} являются вершинами правильного {1}-угольника'.format(p, len(p)))

# %%
#тесты:
points = ([(6, 2), (2, 2), (2, 6), (6, 6)], [(1, 2.46), (-1, 2.46), (2, 0.73), (-2, 0.73), (-1, -1), (1, -1)], [(0, 0), (1, 0), (-0.31, 0.95), (0.5, 1.54), (1.31, 0.95)], [(0, 0), (0.5, sqrt(3)/2), (1, 0)], [(5, 1), (4, 3), (5, 1), (2, 2), (3, 0), (2, 2)])

# %%
i = 1
for p in points:
    print('\n\tИтерация', i)
    p = clean(p)
    distances = sort(p)
    polygon(p,distances)
    i+=1
# Out:
# 	Итерация 1
# повторяющихся точек:  0
# центр:  (4.0, 4.0)
# Точки в порядке удаления от цетра: [(6, 6), (2, 6), (6, 2), (2, 2)] (если равноудалены, сортируются по х,у)
# ВСЕ точки равноудалены от цетра
# Точки [(6, 6), (2, 6), (6, 2), (2, 2)] являются вершинами правильного 4-угольника
#
# 	Итерация 2
# повторяющихся точек:  0
# центр:  (0.0, 0.7300000000000001)
# Точки в порядке удаления от цетра: [(1, 2.46), (-2, 0.73), (-1, 2.46), (2, 0.73), (-1, -1), (1, -1)] (если равноудалены, сортируются по х,у)
# ВСЕ точки равноудалены от цетра
# Точки [(1, 2.46), (-2, 0.73), (-1, 2.46), (2, 0.73), (-1, -1), (1, -1)] являются вершинами правильного 6-угольника
#
# 	Итерация 3
# повторяющихся точек:  0
# центр:  (0.5, 0.6880000000000001)
# Точки в порядке удаления от цетра: [(0.5, 1.54), (-0.31, 0.95), (0, 0), (1.31, 0.95), (1, 0)] (если равноудалены, сортируются по х,у)
# ВСЕ точки равноудалены от цетра
# Точки [(0.5, 1.54), (-0.31, 0.95), (0, 0), (1.31, 0.95), (1, 0)] являются вершинами правильного 5-угольника
#
# 	Итерация 4
# повторяющихся точек:  0
# центр:  (0.5, 0.28867513459481287)
# Точки в порядке удаления от цетра: [(1, 0), (0, 0), (0.5, 0.8660254037844386)] (если равноудалены, сортируются по х,у)
# ВСЕ точки равноудалены от цетра
# Точки [(1, 0), (0, 0), (0.5, 0.8660254037844386)] являются вершинами правильного 3-угольника
#
# 	Итерация 5
# повторяющихся точек:  2
# центр:  (3.5, 1.5)
# Точки в порядке удаления от цетра: [(3, 0), (5, 1), (4, 3), (2, 2)] (если равноудалены, сортируются по х,у)
# ВСЕ точки равноудалены от цетра
# Точки [(3, 0), (5, 1), (4, 3), (2, 2)] являются вершинами правильного 4-угольника

# %%
#для самостоятельных тестов: 
n = 2
while n<3:
    n = int(input('Количество точек (НЕ менее трёх): '))
p = []
for i in range(n):
    x = float(input('Введите координату x '))
    y = float(input('Введите координату y '))
    print('Точка {0} c координатами ({1},{2})'.format(i, x, y))
    p.append((x,y))
print(p)
