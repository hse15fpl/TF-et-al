# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:36, 325kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 0.00001
word_counts = Counter(int_words)
total_count = len(int_words)
freq = {word: count/total_count for word, count in word_counts.items()}
probs = {word: 1 - np.sqrt(threshold / freq[word]) for word in word_counts}

train_words = [word for word in int_words if probs[word] < random.random()]

# %%
len(train_words)
# Out:
# 4628413

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    randn = np.random.randint(1,window_size+1)
    left = idx-randn if idx > randn else 0
    right = idx+randn
    window = list(set(words[left:idx]+words[idx+1:right+1]))
    return window

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()

with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200  # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_weight = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_biases = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_weight, softmax_biases, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-23-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6593 0.7143 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6022 0.6681 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5004 0.6609 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6090 0.6592 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4792 0.6660 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5123 0.6501 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5663 0.6483 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5238 0.6631 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4814 0.6413 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4314 0.6450 sec/batch
# Nearest to than: robbers, modulated, tsuba, backbench, rewrite, lemmink, nongovernmental, nida,
# Nearest to zero: totem, ceasing, out, capac, grid, patches, ram, irritating,
# Nearest to is: ella, haihowak, manifest, noncombatant, ceramics, rivalled, brandished, conceptual,
# Nearest to people: programme, graecia, ripening, backbone, apology, hoya, instant, addison,
# Nearest to war: ix, heroquest, sprayed, entries, biafra, let, efron, kyiv,
# Nearest to all: operating, mastery, chievo, grenoble, bint, veselin, ugle, damascus,
# Nearest to it: chalcedonians, gogh, submit, sfp, linkages, revoking, magnetosphere, fricke,
# Nearest to often: moderate, fg, angular, bessel, degeneration, fluoresce, mozilla, kabyle,
# Nearest to nobel: agglomerations, rhotic, disciple, underrepresented, earnhardt, able, autobiographies, fears,
# Nearest to square: heh, wootz, jenna, buddies, beating, mumonkan, cimmeria, gilboa,
# Nearest to something: fielded, reprocessing, revert, resonates, cons, belonged, anorexia, mozart,
# Nearest to pope: irregularity, twelve, venezuelan, yb, tollens, nativist, carmel, romeo,
# Nearest to smith: tempting, despot, sebald, cooperate, arm, ross, superimposed, molluscs,
# Nearest to road: lapse, meadows, lfar, quickness, carrero, daredevil, autocephaly, resumed,
# Nearest to running: ronin, radically, skilled, embrace, stormed, liquified, cantata, lingvo,
# Nearest to rise: patrol, jonesboro, mahogany, fords, trust, achromatism, ton, travail,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4803 0.6509 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4055 0.6579 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3293 0.6959 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2501 0.6581 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1982 0.7059 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1751 0.6467 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0922 0.7040 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0781 0.6532 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0179 0.6368 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9768 0.6404 sec/batch
# Nearest to than: click, backbench, robbers, relative, convictions, considerably, plates, national,
# Nearest to zero: totem, out, having, settled, patches, ceasing, ram, grid,
# Nearest to is: manifest, composed, conceptual, locked, ceramics, ella, haihowak, diagram,
# Nearest to people: programme, graecia, specially, backbone, addison, tenth, instant, patterning,
# Nearest to war: entries, let, ix, heroquest, biafra, sprayed, resources, cy,
# Nearest to all: operating, mastery, chievo, damascus, nowadays, offer, prison, share,
# Nearest to it: chalcedonians, submit, gogh, often, single, purchase, together, householder,
# Nearest to often: moderate, angular, fg, degeneration, notes, action, bessel, it,
# Nearest to nobel: disciple, able, agglomerations, rhotic, earnhardt, underrepresented, fears, autobiographies,
# Nearest to square: heh, beating, establishments, lighting, lived, wootz, expert, one,
# Nearest to something: fielded, cons, increasingly, revert, anorexia, mozart, pregnancy, industrialisation,
# Nearest to pope: irregularity, twelve, venezuelan, carmel, yb, romeo, nativist, tollens,
# Nearest to smith: tempting, despot, arm, cooperate, border, provide, ross, rapidly,
# Nearest to road: lapse, contained, meadows, daredevil, resumed, fifteen, dietary, refusal,
# Nearest to running: embrace, inspired, ronin, radically, skilled, un, stormed, liquified,
# Nearest to rise: patrol, mahogany, trust, jonesboro, formal, fords, show, warship,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9196 0.6460 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9230 0.6600 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8594 0.7237 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8424 0.6884 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8282 0.6326 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8082 0.6353 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8044 0.6321 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7834 0.6709 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7913 0.7041 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7856 0.7741 sec/batch
# Nearest to than: backbench, robbers, modulated, rewrite, click, purchasing, considerably, relative,
# Nearest to zero: patches, settled, totem, grid, brief, ceasing, satisfied, slain,
# Nearest to is: manifest, conceptual, binary, composed, alternating, ceramics, locked, industrialised,
# Nearest to people: programme, graecia, apology, backbone, instant, tenth, addison, staffed,
# Nearest to war: entries, ix, let, heroquest, biafra, motor, sprayed, cy,
# Nearest to all: operating, mastery, grenoble, damascus, chievo, illuminated, prison, offer,
# Nearest to it: chalcedonians, submit, gogh, magnetosphere, householder, single, tenets, stanislaw,
# Nearest to often: moderate, angular, fg, bessel, degeneration, hoped, action, notes,
# Nearest to nobel: able, disciple, agglomerations, underrepresented, earnhardt, rhotic, d, retiring,
# Nearest to square: heh, beating, enemy, lighting, keen, expert, establishments, wootz,
# Nearest to something: revert, wa, increasingly, fielded, cons, anorexia, mozart, orator,
# Nearest to pope: irregularity, twelve, carmel, debatable, knowledge, submissions, venezuelan, romeo,
# Nearest to smith: tempting, arm, despot, siege, ross, sebald, speculate, feeder,
# Nearest to road: lapse, resumed, dietary, astronomer, autocephaly, daredevil, meadows, contained,
# Nearest to running: embrace, radically, skilled, ronin, inspired, profound, liquified, stormed,
# Nearest to rise: patrol, mahogany, trust, ton, fords, warship, jonesboro, disadvantaged,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7901 0.8574 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7293 0.7022 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7266 0.7564 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7030 0.7145 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7272 0.6889 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6886 0.7006 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6978 0.6927 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7285 0.6511 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6987 0.6653 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6694 0.6897 sec/batch
# Nearest to than: backbench, rewrite, modulated, robbers, click, shrines, hateful, purchasing,
# Nearest to zero: patches, settled, seven, ceasing, two, four, patterson, totem,
# Nearest to is: manifest, binary, conceptual, industrialised, torque, alternating, ceramics, composed,
# Nearest to people: programme, graecia, apology, staffed, addison, tenth, backbone, hyphen,
# Nearest to war: biafra, ix, hedge, cy, entries, heroquest, motor, let,
# Nearest to all: operating, mastery, grenoble, karakoram, broadcasted, illuminated, kiss, chievo,
# Nearest to it: chalcedonians, plaintiff, tenets, linkages, sfp, submit, magnetosphere, gogh,
# Nearest to often: moderate, angular, bessel, fg, modernize, degeneration, action, writ,
# Nearest to nobel: agglomerations, george, d, disciple, underrepresented, able, earnhardt, abbas,
# Nearest to square: heh, buddies, wootz, enemy, beating, jenna, keen, lighting,
# Nearest to something: revert, cons, wa, fielded, increasingly, anorexia, orator, mozart,
# Nearest to pope: irregularity, twelve, submissions, carmel, sleeker, venezuelan, debatable, mathematics,
# Nearest to smith: tempting, arm, feeder, despot, palaces, ross, speculate, siege,
# Nearest to road: lapse, autocephaly, resumed, dietary, lizzy, mdma, aide, daredevil,
# Nearest to running: ronin, radically, embrace, skilled, inspired, enforce, stormed, loch,
# Nearest to rise: patrol, mahogany, ton, jonesboro, disadvantaged, warship, trust, fords,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6744 0.6667 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6592 0.7739 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6296 0.6635 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6335 0.6424 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6451 0.6826 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6331 0.6531 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6033 0.4706 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5754 0.7261 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5094 0.6900 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5113 0.6482 sec/batch
# Nearest to than: modulated, rewrite, backbench, relative, purchasing, hateful, robbers, click,
# Nearest to zero: two, seven, four, patches, jeanne, patterson, six, migrant,
# Nearest to is: manifest, torque, binary, conceptual, alternating, composed, ceramics, noncombatant,
# Nearest to people: programme, graecia, apology, staffed, hoya, backbone, bruises, hyphen,
# Nearest to war: ix, biafra, cy, hedge, efron, heroquest, colloquialism, disrupts,
# Nearest to all: operating, mastery, broadcasted, karakoram, grenoble, illuminated, consenting, uruguayan,
# Nearest to it: chalcedonians, plaintiff, involve, tenets, sfp, be, inciting, rahim,
# Nearest to often: moderate, angular, fg, modernize, bessel, degeneration, action, wrong,
# Nearest to nobel: d, george, american, physicist, agglomerations, six, two, disciple,
# Nearest to square: heh, buddies, beating, enemy, wootz, culprits, ledge, lighting,
# Nearest to something: revert, cons, wa, fielded, resonates, increasingly, anorexia, question,
# Nearest to pope: irregularity, twelve, saxony, nativist, venezuelan, penrose, steven, mileva,
# Nearest to smith: tempting, feeder, ross, palaces, meighen, arm, coronary, fta,
# Nearest to road: autocephaly, lapse, lizzy, mdma, daredevil, resumed, aide, gasp,
# Nearest to running: ronin, radically, embrace, skilled, inspired, loch, orgy, safest,
# Nearest to rise: patrol, mahogany, jonesboro, ton, disadvantaged, warship, ruptured, corporations,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4840 0.6531 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4770 0.6332 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4598 0.6554 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5145 0.6878 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4673 0.6459 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4873 0.6422 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4793 0.6496 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3795 0.6766 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4573 0.6946 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4202 0.6680 sec/batch
# Nearest to than: modulated, rewrite, backbench, purchasing, relative, hateful, considerably, click,
# Nearest to zero: two, four, seven, migrant, patches, reserves, jeanne, hurdle,
# Nearest to is: binary, manifest, torque, alternating, rough, membranes, conceptual, ceramics,
# Nearest to people: programme, graecia, apology, staffed, hoya, bruises, interdependent, materialise,
# Nearest to war: biafra, colloquialism, efron, ix, cy, army, hedge, armed,
# Nearest to all: broadcasted, mastery, operating, illuminated, if, grenoble, karakoram, consenting,
# Nearest to it: chalcedonians, involve, sfp, rahim, bioethics, be, treat, plaintiff,
# Nearest to often: moderate, angular, fg, bessel, degeneration, action, wrong, modernize,
# Nearest to nobel: d, george, agglomerations, physicist, economist, disciple, musician, underrepresented,
# Nearest to square: heh, one, jong, beating, buddies, culprits, gilboa, ledge,
# Nearest to something: question, increasingly, resonates, revert, install, reprocessing, wa, cons,
# Nearest to pope: irregularity, twelve, saxony, mileva, steven, nativist, oes, penrose,
# Nearest to smith: tempting, feeder, ross, cruelly, meighen, repose, fta, york,
# Nearest to road: autocephaly, lapse, mdma, unmatched, lizzy, resumed, skyline, jungian,
# Nearest to running: ronin, skilled, radically, embrace, orgy, inspired, loch, parlance,
# Nearest to rise: patrol, mahogany, jonesboro, trust, ton, warship, startling, disadvantaged,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4451 0.6657 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4199 0.6530 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4124 0.6456 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4070 0.6353 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4335 0.6349 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4205 0.6381 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3947 0.6475 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3406 0.6430 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4106 0.6381 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3530 0.6384 sec/batch
# Nearest to than: rewrite, robbers, backbench, modulated, purchasing, relative, hateful, ellipsoids,
# Nearest to zero: two, four, seven, three, migrant, six, five, patches,
# Nearest to is: alternating, torque, manifest, binary, conceptual, solver, ceramics, rough,
# Nearest to people: programme, graecia, apology, staffed, hoya, zafy, citing, maggiore,
# Nearest to war: army, efron, armed, colloquialism, caecilius, romulus, biafra, troops,
# Nearest to all: mastery, broadcasted, illuminated, consenting, grenoble, karakoram, if, operating,
# Nearest to it: chalcedonians, be, involve, sfp, plaintiff, automatically, whether, bioethics,
# Nearest to often: moderate, fg, angular, degeneration, bessel, action, wrong, icosahedral,
# Nearest to nobel: d, george, agglomerations, physicist, economist, prize, disciple, american,
# Nearest to square: heh, one, ledge, jong, gilboa, establishments, climb, sergeant,
# Nearest to something: question, resonates, revert, install, amnesia, bentham, reprocessing, knew,
# Nearest to pope: irregularity, twelve, nativist, saxony, mileva, oes, penrose, carmel,
# Nearest to smith: ross, tempting, cruelly, repose, feeder, fta, midyear, meighen,
# Nearest to road: autocephaly, mdma, unmatched, skyline, lapse, resumed, lizzy, longitudes,
# Nearest to running: ronin, skilled, orgy, radically, embrace, intensities, loch, inspired,
# Nearest to rise: patrol, jonesboro, mahogany, startling, warship, trust, disadvantaged, ruptured,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3753 0.6381 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4107 0.6363 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3284 0.6371 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3651 0.6408 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3758 0.6348 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3742 0.6394 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4068 0.6357 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4009 0.6399 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3059 0.6364 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3383 0.6335 sec/batch
# Nearest to than: rewrite, modulated, relative, backbench, robbers, ellipsoids, hateful, purchasing,
# Nearest to zero: four, two, seven, five, three, six, migrant, unpaved,
# Nearest to is: torque, alternating, manifest, binary, mandinka, conceptual, defecate, solver,
# Nearest to people: programme, graecia, staffed, apology, maggiore, citing, hoya, chameleon,
# Nearest to war: army, armed, efron, troops, forces, allies, romulus, caecilius,
# Nearest to all: mastery, karakoram, grenoble, consenting, illuminated, if, broadcasted, galerius,
# Nearest to it: chalcedonians, plaintiff, involve, automatically, be, inciting, embellishments, odoacer,
# Nearest to often: moderate, bessel, degeneration, action, fg, modernize, wrong, angular,
# Nearest to nobel: d, george, prize, economist, physicist, agglomerations, hardcover, underrepresented,
# Nearest to square: one, heh, jong, climb, gilboa, ledge, establishments, wootz,
# Nearest to something: question, resonates, revert, install, amnesia, cubicle, knew, analyze,
# Nearest to pope: irregularity, twelve, nativist, saxony, mileva, josephine, carmel, constantine,
# Nearest to smith: ross, cruelly, tempting, midyear, repose, publication, feeder, browning,
# Nearest to road: autocephaly, unmatched, mdma, resumed, skyline, lizzy, lapse, longitudes,
# Nearest to running: ronin, skilled, orgy, radically, loch, embrace, liquidity, parlance,
# Nearest to rise: patrol, mahogany, jonesboro, johore, warship, ruptured, disadvantaged, startling,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3318 0.6419 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2925 0.6377 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4029 0.6385 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3853 0.6348 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4057 0.6629 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2870 0.6582 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3275 0.6526 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3595 0.6403 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2082 0.6506 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3010 0.6370 sec/batch
# Nearest to than: robbers, rewrite, backbench, purchasing, relative, ellipsoids, hotham, hateful,
# Nearest to zero: two, four, migrant, five, seven, six, three, rate,
# Nearest to is: alternating, torque, manifest, binary, defecate, mandinka, solver, haihowak,
# Nearest to people: programme, graecia, staffed, apology, zafy, hoya, maggiore, systemic,
# Nearest to war: army, armed, forces, troops, efron, allies, romulus, hispanica,
# Nearest to all: grenoble, karakoram, consenting, mastery, galerius, operating, bint, illuminated,
# Nearest to it: chalcedonians, embellishments, odoacer, be, involve, snags, sfp, plaintiff,
# Nearest to often: moderate, action, angular, bessel, degeneration, wrong, fg, icosahedral,
# Nearest to nobel: d, prize, physicist, george, economist, american, agglomerations, hardcover,
# Nearest to square: heh, jong, climb, gilboa, one, wootz, ledge, establishments,
# Nearest to something: resonates, question, amnesia, knew, cubicle, bentham, try, cryonics,
# Nearest to pope: irregularity, nativist, antipope, saxony, constantine, josephine, jacobite, carmel,
# Nearest to smith: ross, tempting, repose, cruelly, midyear, publication, syncopation, feeder,
# Nearest to road: autocephaly, unmatched, mdma, skyline, resumed, lizzy, lapse, peugeot,
# Nearest to running: ronin, skilled, orgy, loch, radically, embrace, mcmanus, liquidity,
# Nearest to rise: patrol, jonesboro, mahogany, continued, johore, disadvantaged, ruptured, startling,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3138 0.6683 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2996 0.6381 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3503 0.3007 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2521 0.6495 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2207 0.6429 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2367 0.6428 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2439 0.6367 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2090 0.6402 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2244 0.6391 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2132 0.6393 sec/batch
# Nearest to than: purchasing, robbers, modulated, relative, hotham, ellipsoids, rewrite, backbench,
# Nearest to zero: two, four, migrant, five, three, six, seven, rate,
# Nearest to is: torque, alternating, manifest, binary, haihowak, solver, mandinka, defecate,
# Nearest to people: programme, graecia, staffed, zafy, maggiore, apology, quintessential, hoya,
# Nearest to war: army, armed, forces, efron, troops, romulus, caecilius, hispanica,
# Nearest to all: galerius, karakoram, grenoble, consenting, if, mastery, illuminated, bint,
# Nearest to it: chalcedonians, odoacer, embellishments, sfp, wangfujing, be, residing, columbians,
# Nearest to often: moderate, degeneration, action, almond, fg, bessel, icosahedral, braking,
# Nearest to nobel: d, prize, physicist, economist, agglomerations, george, hardcover, underrepresented,
# Nearest to square: climb, gilboa, jong, one, heh, downtown, establishments, maxis,
# Nearest to something: resonates, question, knew, bentham, amnesia, cubicle, try, analyze,
# Nearest to pope: antipope, saxony, nativist, constantine, irregularity, ami, mileva, josephine,
# Nearest to smith: ross, tempting, repose, midyear, cruelly, publication, feeder, browning,
# Nearest to road: unmatched, autocephaly, skyline, mdma, resumed, lizzy, peugeot, crawl,
# Nearest to running: ronin, skilled, orgy, anchoring, loch, embrace, parlance, mcmanus,
# Nearest to rise: patrol, jonesboro, mahogany, continued, johore, disadvantaged, achromatism, ruptured,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2442 0.6424 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2308 0.6393 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2328 0.6450 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1422 0.6441 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1650 0.6372 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1502 0.6411 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1884 0.6358 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1861 0.6632 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2157 0.6575 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1786 0.6539 sec/batch
# Nearest to than: hotham, ellipsoids, robbers, relative, modulated, purchasing, rewrite, hateful,
# Nearest to zero: two, four, migrant, five, three, six, seven, est,
# Nearest to is: alternating, torque, binary, manifest, defecate, solver, mandinka, haihowak,
# Nearest to people: programme, staffed, graecia, zafy, maggiore, apology, quintessential, sterile,
# Nearest to war: army, armed, forces, efron, romulus, hispanica, caecilius, troops,
# Nearest to all: karakoram, consenting, galerius, if, bint, grenoble, kiss, illuminated,
# Nearest to it: chalcedonians, embellishments, odoacer, be, sfp, betterment, undigested, saves,
# Nearest to often: moderate, action, bessel, almond, icosahedral, braking, needs, fg,
# Nearest to nobel: prize, d, physicist, agglomerations, economist, george, underrepresented, hardcover,
# Nearest to square: climb, jong, gilboa, one, downtown, intersect, heh, establishments,
# Nearest to something: resonates, question, knew, bentham, cubicle, analyze, try, anorexia,
# Nearest to pope: antipope, constantine, irregularity, nativist, saxony, twelve, mileva, jacobite,
# Nearest to smith: tempting, publication, repose, ross, cruelly, midyear, rea, zoran,
# Nearest to road: unmatched, skyline, resumed, autocephaly, mdma, crawl, lizzy, upscale,
# Nearest to running: ronin, orgy, skilled, loch, anchoring, embrace, parlance, pennant,
# Nearest to rise: jonesboro, patrol, mahogany, startling, johore, disadvantaged, ruptured, achromatism,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1558 0.6632 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2026 0.6327 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1804 0.6384 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1283 0.6316 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1986 0.6359 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1740 0.6410 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2087 0.6435 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1756 0.6307 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1261 0.6369 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1762 0.6352 sec/batch
# Nearest to than: hotham, robbers, ellipsoids, relative, purchasing, modulated, rewrite, hateful,
# Nearest to zero: two, four, migrant, three, five, seven, six, one,
# Nearest to is: alternating, defecate, torque, solver, manifest, ordinal, haihowak, binary,
# Nearest to people: programme, zafy, staffed, graecia, maggiore, quintessential, sterile, internet,
# Nearest to war: armed, army, romulus, forces, efron, hispanica, caecilius, kyiv,
# Nearest to all: karakoram, consenting, if, galerius, bint, kiss, illuminated, steal,
# Nearest to it: chalcedonians, odoacer, embellishments, be, whether, saves, wangfujing, betterment,
# Nearest to often: moderate, action, almond, icosahedral, bessel, fg, needs, degeneration,
# Nearest to nobel: prize, d, physicist, agglomerations, economist, cyclotron, tanner, underrepresented,
# Nearest to square: climb, gilboa, intersect, jong, one, downtown, heh, corners,
# Nearest to something: resonates, question, knew, bentham, amnesia, misdiagnosed, cubicle, anorexia,
# Nearest to pope: antipope, constantine, irregularity, nativist, jacobite, stuarts, apologetics, mileva,
# Nearest to smith: tempting, repose, publication, ross, cruelly, rea, syncopation, midyear,
# Nearest to road: unmatched, skyline, mdma, autocephaly, resumed, crawl, highway, lizzy,
# Nearest to running: orgy, ronin, embrace, skilled, loch, anchoring, mcmanus, pennant,
# Nearest to rise: jonesboro, mahogany, patrol, startling, disadvantaged, ruptured, johore, iyoas,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1963 0.6392 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1766 0.6384 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1829 0.6328 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1857 0.6368 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1343 0.6394 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1458 0.6332 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1651 0.6343 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1161 0.6425 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1848 0.6421 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2116 0.6407 sec/batch
# Nearest to than: hotham, ellipsoids, robbers, purchasing, hateful, relative, backbench, nida,
# Nearest to zero: two, four, three, five, seven, migrant, six, one,
# Nearest to is: alternating, solver, torque, manifest, haihowak, defecate, mandinka, ordinal,
# Nearest to people: programme, maggiore, staffed, zafy, graecia, hoya, apology, internet,
# Nearest to war: armed, army, forces, troops, romulus, hispanica, kyiv, weapons,
# Nearest to all: karakoram, kiss, galerius, bint, consenting, if, consequential, steal,
# Nearest to it: chalcedonians, odoacer, embellishments, revoking, tenets, be, refuting, jahwist,
# Nearest to often: moderate, action, almond, modernize, cherubim, jeux, needs, bessel,
# Nearest to nobel: prize, d, physicist, economist, agglomerations, george, american, physiology,
# Nearest to square: gilboa, climb, jong, intersect, downtown, wootz, maxis, coney,
# Nearest to something: resonates, knew, question, bentham, amnesia, anorexia, misdiagnosed, cubicle,
# Nearest to pope: antipope, constantine, irregularity, nativist, saxony, stuarts, jacobite, carmel,
# Nearest to smith: tempting, publication, ross, repose, rea, cruelly, midyear, leonard,
# Nearest to road: skyline, mdma, autocephaly, resumed, unmatched, crawl, lizzy, highway,
# Nearest to running: orgy, ronin, embrace, mcmanus, loch, skilled, anchoring, liquidity,
# Nearest to rise: jonesboro, mahogany, johore, patrol, startling, continued, much, disadvantaged,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2267 0.6703 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1462 0.6397 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1428 0.6315 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1355 0.6325 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0312 0.6353 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1283 0.6381 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1596 0.6380 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1507 0.6356 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1673 0.1053 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1417 0.6339 sec/batch
# Nearest to than: hotham, ellipsoids, purchasing, robbers, relative, nida, rewrite, billing,
# Nearest to zero: two, four, five, three, six, seven, migrant, one,
# Nearest to is: alternating, solver, torque, bromine, haihowak, manifest, defecate, there,
# Nearest to people: programme, zafy, maggiore, staffed, internet, aids, quintessential, graecia,
# Nearest to war: armed, army, romulus, hispanica, forces, tactics, weapons, kyiv,
# Nearest to all: karakoram, galerius, kiss, denotes, bint, if, operating, points,
# Nearest to it: odoacer, chalcedonians, embellishments, columbians, shockley, sfp, be, pulsar,
# Nearest to often: moderate, needs, action, almond, modernize, fg, nihilism, icosahedral,
# Nearest to nobel: prize, physicist, d, economist, agglomerations, cyclotron, earnhardt, american,
# Nearest to square: gilboa, intersect, jong, climb, downtown, maxis, coney, miles,
# Nearest to something: resonates, question, knew, anorexia, cubicle, bentham, yourself, amnesia,
# Nearest to pope: antipope, constantine, irregularity, stuarts, nativist, papal, saxony, republika,
# Nearest to smith: tempting, publication, rea, repose, ross, leonard, midyear, cruelly,
# Nearest to road: skyline, mdma, highway, unmatched, autocephaly, resumed, crawl, lizzy,
# Nearest to running: ronin, orgy, embrace, skilled, loch, liquidity, mcmanus, anchoring,
# Nearest to rise: jonesboro, mahogany, startling, patrol, johore, continued, much, iyoas,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.1006 0.6497 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0721 0.6375 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0931 0.6378 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0469 0.6361 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0911 0.6443 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0421 0.6352 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0963 0.6357 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1017 0.6340 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1260 0.6367 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0321 0.6345 sec/batch
# Nearest to than: hotham, purchasing, ellipsoids, relative, robbers, considerably, billing, above,
# Nearest to zero: two, four, three, five, migrant, six, seven, one,
# Nearest to is: alternating, torque, solver, manifest, there, defecate, bromine, are,
# Nearest to people: programme, zafy, maggiore, staffed, aids, internet, quintessential, hispanic,
# Nearest to war: armed, army, weapons, tactics, romulus, forces, hispanica, efron,
# Nearest to all: galerius, karakoram, kiss, bint, if, xliv, denotes, operating,
# Nearest to it: chalcedonians, the, odoacer, columbians, quick, be, pulsar, sfp,
# Nearest to often: moderate, needs, dissociates, almond, fg, action, braking, preferring,
# Nearest to nobel: prize, physicist, d, agglomerations, economist, cyclotron, earnhardt, nostromo,
# Nearest to square: gilboa, intersect, climb, downtown, jong, miles, corners, heh,
# Nearest to something: resonates, question, knew, bentham, yourself, anorexia, cubicle, try,
# Nearest to pope: antipope, constantine, irregularity, papal, stuarts, saxony, nativist, mileva,
# Nearest to smith: tempting, rea, repose, ross, feeder, publication, midyear, leonard,
# Nearest to road: skyline, mdma, highway, autocephaly, unmatched, resumed, crawl, upscale,
# Nearest to running: orgy, embrace, ronin, anchoring, loch, skilled, liquidity, mcmanus,
# Nearest to rise: jonesboro, mahogany, patrol, johore, startling, continued, much, iyoas,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0403 0.6428 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0104 0.6328 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0239 0.6336 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0758 0.6343 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0873 0.6354 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0819 0.6457 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0577 0.6346 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1162 0.6368 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0665 0.6368 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0396 0.6391 sec/batch
# Nearest to than: hotham, purchasing, ellipsoids, robbers, relative, conversely, cassava, considerably,
# Nearest to zero: two, four, three, five, six, seven, one, migrant,
# Nearest to is: alternating, torque, solver, there, a, are, bromine, defecate,
# Nearest to people: zafy, programme, maggiore, aids, staffed, hispanic, internet, quintessential,
# Nearest to war: armed, army, romulus, weapons, hispanica, uniformed, tactics, telecoms,
# Nearest to all: kiss, karakoram, galerius, bint, if, enumerated, denotes, consenting,
# Nearest to it: be, chalcedonians, the, sfp, whether, saves, pulsar, embellishments,
# Nearest to often: moderate, needs, almond, bessel, fg, icosahedral, anacharsis, conservatism,
# Nearest to nobel: prize, physicist, agglomerations, d, economist, cyclotron, underrepresented, earnhardt,
# Nearest to square: gilboa, intersect, climb, jong, ledge, downtown, residents, heh,
# Nearest to something: question, knew, resonates, bentham, anorexia, imagine, know, cubicle,
# Nearest to pope: antipope, constantine, irregularity, nativist, mileva, stuarts, saxony, avignon,
# Nearest to smith: tempting, rea, ross, publication, repose, feeder, leonard, midyear,
# Nearest to road: skyline, mdma, highway, unmatched, crawl, upscale, autocephaly, route,
# Nearest to running: embrace, orgy, ronin, loch, anchoring, skilled, mcmanus, enforce,
# Nearest to rise: jonesboro, mahogany, startling, patrol, johore, continued, much, iyoas,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0803 0.6405 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0944 0.6385 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0789 0.6364 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0781 0.6355 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0613 0.6356 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0230 0.6387 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0706 0.6362 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0422 0.6380 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0969 0.6419 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0874 0.6347 sec/batch
# Nearest to than: hotham, purchasing, ellipsoids, robbers, considerably, lemmink, grape, hateful,
# Nearest to zero: two, four, three, five, seven, six, one, migrant,
# Nearest to is: alternating, manifest, servicio, are, there, solver, torque, haihowak,
# Nearest to people: zafy, programme, staffed, maggiore, aids, hispanic, internet, eradicate,
# Nearest to war: armed, army, romulus, tactics, hispanica, forces, saladin, achieve,
# Nearest to all: galerius, kiss, bint, karakoram, denotes, consequential, enumerated, if,
# Nearest to it: chalcedonians, odoacer, be, jahwist, proximate, sfp, columbians, the,
# Nearest to often: moderate, almond, anacharsis, needs, iroquois, conservatism, dissociates, nihilism,
# Nearest to nobel: prize, physicist, agglomerations, cyclotron, d, economist, underrepresented, earnhardt,
# Nearest to square: gilboa, intersect, climb, jong, downtown, heh, wootz, corners,
# Nearest to something: question, resonates, knew, anorexia, bentham, cubicle, know, wa,
# Nearest to pope: antipope, constantine, irregularity, nativist, mileva, stuarts, papal, ami,
# Nearest to smith: tempting, rea, ross, publication, repose, leonard, feeder, syncopation,
# Nearest to road: mdma, highway, skyline, crawl, unmatched, upscale, autocephaly, route,
# Nearest to running: embrace, enforce, ronin, loch, orgy, anchoring, skilled, liquidity,
# Nearest to rise: jonesboro, mahogany, johore, startling, continued, much, iyoas, disadvantaged,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0456 0.6401 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0002 0.6349 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0358 0.6362 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0379 0.6381 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0808 0.6407 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1463 0.6379 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1256 0.6350 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0369 0.6347 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0488 0.6336 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0337 0.6322 sec/batch
# Nearest to than: hotham, purchasing, ellipsoids, robbers, grape, considerably, hateful, conversely,
# Nearest to zero: two, four, three, five, seven, six, one, migrant,
# Nearest to is: alternating, are, the, mandinka, there, solver, torque, bromine,
# Nearest to people: zafy, maggiore, staffed, programme, aids, eradicate, hispanic, internet,
# Nearest to war: armed, romulus, hispanica, army, tactics, weapons, urals, forces,
# Nearest to all: kiss, galerius, bint, denotes, enumerated, karakoram, if, vanuatu,
# Nearest to it: chalcedonians, be, odoacer, columbians, sfp, jahwist, proximate, whether,
# Nearest to often: almond, moderate, needs, preferring, iroquois, creativity, dissociates, anacharsis,
# Nearest to nobel: prize, physicist, cyclotron, economist, agglomerations, d, physiology, underrepresented,
# Nearest to square: gilboa, intersect, one, climb, jong, ledge, corners, wootz,
# Nearest to something: question, knew, resonates, know, anorexia, imagine, orator, cubicle,
# Nearest to pope: antipope, constantine, irregularity, nativist, mileva, calendarists, stuarts, arles,
# Nearest to smith: tempting, rea, ross, repose, publication, feeder, leonard, browning,
# Nearest to road: mdma, highway, skyline, crawl, upscale, autocephaly, unmatched, lapse,
# Nearest to running: embrace, loch, orgy, anchoring, ronin, mcmanus, enforce, skilled,
# Nearest to rise: jonesboro, mahogany, johore, startling, continued, iyoas, much, luigi,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9708 0.6438 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0186 0.6362 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0228 0.6375 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0183 0.6347 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0631 0.6357 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0532 0.5614 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0051 0.6381 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9751 0.6409 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0129 0.6389 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9895 0.6478 sec/batch
# Nearest to than: purchasing, hotham, considerably, ellipsoids, grape, hateful, billing, robbers,
# Nearest to zero: two, four, three, five, six, seven, one, migrant,
# Nearest to is: alternating, that, are, there, mandinka, the, manifest, servicio,
# Nearest to people: zafy, staffed, maggiore, programme, aids, hispanic, internet, eradicate,
# Nearest to war: hispanica, armed, army, uniformed, romulus, urals, efron, weapons,
# Nearest to all: galerius, kiss, denotes, bint, enumerated, consequential, operating, karakoram,
# Nearest to it: chalcedonians, odoacer, columbians, jahwist, the, accelerating, refuting, be,
# Nearest to often: almond, moderate, needs, preferring, anacharsis, dissociates, conservatism, iroquois,
# Nearest to nobel: prize, physicist, cyclotron, d, economist, agglomerations, physiology, english,
# Nearest to square: gilboa, intersect, ledge, downtown, one, heh, climb, corners,
# Nearest to something: resonates, question, knew, orator, know, imagine, wa, anorexia,
# Nearest to pope: antipope, constantine, irregularity, nativist, stuarts, mileva, tius, dmg,
# Nearest to smith: tempting, rea, feeder, repose, leonard, ross, publication, coronary,
# Nearest to road: highway, mdma, skyline, lane, upscale, peugeot, crawl, pedestrians,
# Nearest to running: embrace, anchoring, loch, orgy, ronin, liquidity, inspired, devonian,
# Nearest to rise: jonesboro, mahogany, johore, startling, much, continued, iyoas, luigi,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9811 0.6393 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9737 0.6396 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0134 0.6343 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0468 0.6366 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0044 0.6334 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0058 0.6349 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8983 0.6366 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9391 0.6371 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9283 0.6323 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0032 0.6346 sec/batch
# Nearest to than: purchasing, hotham, ellipsoids, considerably, grape, relative, hateful, cassava,
# Nearest to zero: two, four, three, five, six, seven, one, migrant,
# Nearest to is: the, alternating, a, an, there, are, that, torque,
# Nearest to people: zafy, maggiore, aids, hispanic, staffed, internet, eradicate, programme,
# Nearest to war: weapons, uniformed, hispanica, armed, farthest, urals, efron, army,
# Nearest to all: kiss, denotes, galerius, enumerated, with, if, and, bint,
# Nearest to it: the, chalcedonians, be, proximate, refuting, jahwist, columbians, pulsar,
# Nearest to often: almond, needs, conservatism, moderate, wrong, preferring, anacharsis, iroquois,
# Nearest to nobel: prize, physicist, cyclotron, agglomerations, economist, underrepresented, kocher, d,
# Nearest to square: gilboa, intersect, one, ledge, corners, climb, heh, fincher,
# Nearest to something: knew, question, resonates, know, orator, cubicle, imagine, my,
# Nearest to pope: antipope, constantine, stuarts, nativist, irregularity, papal, avignon, matters,
# Nearest to smith: tempting, rea, repose, christ, feeder, leonard, publication, ross,
# Nearest to road: highway, skyline, mdma, pedestrians, lane, upscale, crawl, route,
# Nearest to running: anchoring, embrace, loch, orgy, skydiver, devonian, relegation, parlance,
# Nearest to rise: mahogany, jonesboro, startling, johore, much, iyoas, continued, luigi,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9858 0.6420 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0102 0.6351 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9468 0.6359 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0085 0.6312 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0230 0.6352 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9479 0.6353 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0122 0.6374 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9896 0.6326 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9838 0.6373 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0084 0.6313 sec/batch
# Nearest to than: hotham, ellipsoids, purchasing, considerably, hateful, higher, conversely, denounced,
# Nearest to zero: two, four, three, five, six, one, seven, eight,
# Nearest to is: the, an, there, a, alternating, that, are, manifest,
# Nearest to people: zafy, maggiore, hispanic, aids, americans, staffed, eradicate, internet,
# Nearest to war: uniformed, hispanica, hrerbunker, romulus, weapons, efron, telecoms, army,
# Nearest to all: galerius, kiss, with, and, denotes, other, enumerated, bint,
# Nearest to it: be, the, chalcedonians, whether, not, jahwist, nothing, refuting,
# Nearest to often: almond, needs, conservatism, preferring, anacharsis, moderate, nihilism, fg,
# Nearest to nobel: prize, physicist, cyclotron, d, kocher, agglomerations, economist, underrepresented,
# Nearest to square: gilboa, intersect, ledge, corners, one, heh, wootz, fincher,
# Nearest to something: question, knew, resonates, know, i, anorexia, orator, bentham,
# Nearest to pope: antipope, constantine, nativist, mccarty, matters, stuarts, avignon, irregularity,
# Nearest to smith: tempting, rea, leonard, feeder, repose, ross, publication, coronary,
# Nearest to road: highway, lane, skyline, mdma, route, pedestrians, crawl, upscale,
# Nearest to running: embrace, loch, anchoring, skydiver, orgy, enforce, liquidity, relegation,
# Nearest to rise: mahogany, jonesboro, startling, johore, much, hateful, manoeuvres, luigi,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0066 0.6431 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9623 0.6360 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9764 0.6354 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0061 0.6332 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0152 0.6381 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0133 0.6366 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9545 0.6356 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9454 0.6381 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9749 0.6309 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0186 0.6395 sec/batch
# Nearest to than: purchasing, hotham, ellipsoids, considerably, higher, above, conversely, hateful,
# Nearest to zero: two, four, three, five, one, six, seven, eight,
# Nearest to is: the, an, that, a, there, alternating, are, it,
# Nearest to people: zafy, maggiore, hispanic, aids, americans, staffed, internet, explorers,
# Nearest to war: hispanica, uniformed, venlo, efron, hrerbunker, romulus, weapons, army,
# Nearest to all: with, other, which, denotes, kiss, and, galerius, enumerated,
# Nearest to it: the, be, chalcedonians, proximate, is, whether, but, jahwist,
# Nearest to often: almond, needs, iroquois, conservatism, moderate, anacharsis, preferring, fg,
# Nearest to nobel: prize, physicist, cyclotron, d, kocher, economist, agglomerations, physiology,
# Nearest to square: gilboa, one, intersect, ledge, wootz, maxis, corners, heh,
# Nearest to something: question, resonates, knew, know, i, imagine, bentham, anorexia,
# Nearest to pope: antipope, constantine, matters, mccarty, papal, republika, calendarists, stuarts,
# Nearest to smith: rea, tempting, leonard, repose, feeder, ross, syncopation, publication,
# Nearest to road: highway, pedestrians, mdma, skyline, lane, route, crawl, upscale,
# Nearest to running: embrace, anchoring, loch, enforce, orgy, liquidity, skydiver, mcmanus,
# Nearest to rise: jonesboro, johore, mahogany, much, startling, iyoas, hateful, continued,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9826 0.6412 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0858 0.6383 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0105 0.6345 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 4.0509 0.6335 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9621 0.6350 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.9595 0.6327 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9863 0.6335 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8861 0.6382 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9876 0.6359 sec/batch
# Epoch 5/10 Iteration: 23000 Avg. Training loss: 3.9629 0.6379 sec/batch
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8414 0.6339 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8028 0.6344 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8318 0.6340 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9210 0.6372 sec/batch
# Nearest to than: less, higher, half, ever, considerably, conversely, purchasing, males,
# Nearest to zero: two, five, one, seven, three, four, six, nine,
# Nearest to is: the, a, an, and, of, that, are, it,
# Nearest to people: living, entertainers, zafy, hispanic, maggiore, births, aids, see,
# Nearest to war: romulus, uniformed, unawares, curtiss, hrerbunker, ishi, urals, hanko,
# Nearest to all: which, with, and, other, for, there, a, most,
# Nearest to it: the, that, is, but, be, by, a, its,
# Nearest to often: almond, uncommon, or, sometimes, engineers, remove, intoxicated, board,
# Nearest to nobel: prize, physicist, kocher, recipient, cyclotron, laureate, physiology, english,
# Nearest to square: one, tiananmen, gilboa, approximately, maxis, five, stroheim, jondo,
# Nearest to something: question, know, resonates, anorexia, i, cheese, imagine, stromateis,
# Nearest to pope: antipope, papal, calendarists, papacy, avignon, rooftop, mccarty, matters,
# Nearest to smith: tempting, feeder, spooner, bisects, leonard, symbiosis, latter, rea,
# Nearest to road: lane, highway, roads, pedestrians, route, freeway, lanes, qm,
# Nearest to running: sleeker, relegation, embrace, loch, distracted, marmite, anchoring, propylene,
# Nearest to rise: splash, manoeuvres, reinvent, johore, startling, mahogany, cournot, utopian,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8267 0.6391 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8365 0.6346 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8436 0.6325 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8611 0.6368 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8743 0.6314 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9089 0.6380 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8877 0.6356 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8536 0.6357 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8796 0.6365 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8375 0.6373 sec/batch
# Nearest to than: less, higher, above, purchasing, half, ever, considerably, zero,
# Nearest to zero: two, five, one, four, seven, three, nine, six,
# Nearest to is: the, a, an, and, of, are, that, as,
# Nearest to people: living, entertainers, zafy, maggiore, explorers, see, hispanic, politicians,
# Nearest to war: romulus, unawares, uniformed, hanko, hrerbunker, urals, propaganda, ishi,
# Nearest to all: which, with, other, and, the, most, there, for,
# Nearest to it: the, that, not, is, be, but, its, by,
# Nearest to often: almond, uncommon, engineers, intoxicated, iroquois, or, remove, sometimes,
# Nearest to nobel: prize, kocher, cyclotron, physiology, recipient, physicist, cfaf, laureate,
# Nearest to square: one, tiananmen, gilboa, maxis, approximately, stroheim, kurtosis, five,
# Nearest to something: question, i, know, cheese, resonates, anorexia, passers, stromateis,
# Nearest to pope: antipope, papal, calendarists, rooftop, matters, avignon, papacy, mccarty,
# Nearest to smith: tempting, spooner, symbiosis, leonard, feeder, jacobson, bisects, latter,
# Nearest to road: lane, highway, roads, pedestrians, route, qm, freeway, lanes,
# Nearest to running: sleeker, relegation, embrace, loch, distracted, marmite, anchoring, peotone,
# Nearest to rise: splash, johore, reinvent, manoeuvres, startling, mahogany, cournot, utopian,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8785 0.6409 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8688 0.6328 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8362 0.6349 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8298 0.6314 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8697 0.6386 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8316 0.6388 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9568 0.6379 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8841 0.6343 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9499 0.6347 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8222 0.6342 sec/batch
# Nearest to than: less, higher, half, zero, more, above, hotham, males,
# Nearest to zero: two, five, one, four, seven, three, six, nine,
# Nearest to is: the, an, a, of, and, are, as, it,
# Nearest to people: living, entertainers, zafy, see, births, americans, politicians, worst,
# Nearest to war: united, unawares, hanko, uniformed, romulus, hrerbunker, urals, venlo,
# Nearest to all: which, and, other, with, for, most, there, days,
# Nearest to it: the, that, is, be, not, its, but, by,
# Nearest to often: uncommon, intoxicated, almond, engineers, or, remove, iroquois, preferring,
# Nearest to nobel: prize, kocher, recipient, physiology, cyclotron, physicist, cfaf, westbrook,
# Nearest to square: one, tiananmen, gilboa, approximately, maxis, kurtosis, datasheet, coney,
# Nearest to something: question, i, know, cheese, anorexia, resonates, stromateis, imagine,
# Nearest to pope: antipope, papal, calendarists, avignon, rooftop, papacy, mccarty, favorable,
# Nearest to smith: tempting, symbiosis, spooner, bisects, feeder, leonard, jacobson, rea,
# Nearest to road: lane, highway, roads, pedestrians, qm, route, freeway, lanes,
# Nearest to running: relegation, sleeker, distracted, embrace, loch, marmite, peotone, anchoring,
# Nearest to rise: johore, splash, reinvent, manoeuvres, cournot, moralistic, trakai, startling,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7937 0.6367 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8764 0.6330 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7891 0.6371 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8626 0.6348 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8675 0.6365 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8316 0.6357 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9246 0.3050 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8290 0.6365 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8331 0.6354 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8347 0.6383 sec/batch
# Nearest to than: less, higher, males, hotham, more, half, about, considerably,
# Nearest to zero: two, five, four, one, seven, three, six, nine,
# Nearest to is: the, a, an, and, of, as, it, are,
# Nearest to people: living, entertainers, maggiore, births, hispanic, zafy, aids, worst,
# Nearest to war: united, unawares, hrerbunker, uniformed, hanko, romulus, urals, ishi,
# Nearest to all: which, and, other, with, for, most, there, days,
# Nearest to it: the, that, is, but, be, not, by, a,
# Nearest to often: uncommon, almond, engineers, intoxicated, iroquois, remove, or, needs,
# Nearest to nobel: prize, recipient, kocher, physicist, physiology, cyclotron, laureate, english,
# Nearest to square: tiananmen, one, gilboa, approximately, maxis, kurtosis, datasheet, jondo,
# Nearest to something: question, resonates, know, i, cheese, stromateis, anorexia, imagine,
# Nearest to pope: antipope, papal, calendarists, mccarty, rooftop, avignon, papacy, castiglione,
# Nearest to smith: tempting, spooner, symbiosis, bisects, jacobson, rea, leonard, feeder,
# Nearest to road: lane, roads, highway, pedestrians, qm, route, lanes, freeway,
# Nearest to running: relegation, sleeker, marmite, loch, anchoring, distracted, embrace, radically,
# Nearest to rise: johore, splash, reinvent, manoeuvres, moralistic, startling, rising, cournot,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8384 0.6386 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8241 0.6368 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8251 0.6338 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8034 0.6372 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8480 0.6341 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8338 0.6345 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8655 0.6339 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7840 0.6375 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7919 0.6344 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8061 0.6360 sec/batch
# Nearest to than: less, higher, half, more, about, zero, males, in,
# Nearest to zero: two, five, four, three, one, seven, six, nine,
# Nearest to is: the, a, an, of, and, are, as, it,
# Nearest to people: living, entertainers, births, see, zafy, aids, worst, hispanic,
# Nearest to war: unawares, hrerbunker, united, romulus, uniformed, urals, hanko, ishi,
# Nearest to all: which, and, other, for, with, there, a, most,
# Nearest to it: the, that, is, be, but, not, a, has,
# Nearest to often: uncommon, or, almond, needs, remove, engineers, fellatio, sometimes,
# Nearest to nobel: prize, recipient, kocher, cyclotron, physiology, physicist, laureate, cfaf,
# Nearest to square: one, tiananmen, approximately, gilboa, maxis, five, datasheet, coney,
# Nearest to something: question, know, i, resonates, proof, stromateis, primacy, cheese,
# Nearest to pope: antipope, papal, calendarists, rooftop, mccarty, avignon, papacy, yb,
# Nearest to smith: tempting, spooner, symbiosis, bisects, latter, leonard, jacobson, feeder,
# Nearest to road: lane, roads, pedestrians, highway, qm, freeway, lanes, route,
# Nearest to running: sleeker, relegation, marmite, loch, anchoring, embrace, distracted, propylene,
# Nearest to rise: reinvent, johore, splash, manoeuvres, startling, moralistic, cournot, jonesboro,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7717 0.6350 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8252 0.6358 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8528 0.6392 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8467 0.6330 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8042 0.6342 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8670 0.6338 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8364 0.6371 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8576 0.6327 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8478 0.6355 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8516 0.6332 sec/batch
# Nearest to than: less, higher, half, more, about, males, hotham, above,
# Nearest to zero: two, five, one, four, seven, three, nine, six,
# Nearest to is: the, an, a, of, and, as, it, are,
# Nearest to people: living, entertainers, births, hispanic, zafy, politicians, maggiore, see,
# Nearest to war: united, hrerbunker, unawares, uniformed, romulus, hanko, urals, tente,
# Nearest to all: which, and, with, other, there, for, given, most,
# Nearest to it: the, that, is, be, not, but, by, a,
# Nearest to often: uncommon, or, almond, engineers, remove, jolly, ports, sometimes,
# Nearest to nobel: prize, recipient, kocher, physicist, physiology, laureate, cyclotron, cfaf,
# Nearest to square: one, tiananmen, approximately, gilboa, five, kurtosis, maxis, datasheet,
# Nearest to something: question, anorexia, know, resonates, i, stromateis, imagine, deadline,
# Nearest to pope: antipope, papal, calendarists, rooftop, papacy, avignon, mccarty, yb,
# Nearest to smith: tempting, spooner, bisects, symbiosis, jacobson, leonard, feeder, hume,
# Nearest to road: lane, roads, highway, pedestrians, route, freeway, qm, lanes,
# Nearest to running: relegation, sleeker, embrace, loch, marmite, peotone, distracted, anchoring,
# Nearest to rise: reinvent, splash, manoeuvres, johore, cournot, startling, moralistic, utopian,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8597 0.6422 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8392 0.6311 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7982 0.6379 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8299 0.6328 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8842 0.6347 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8508 0.6390 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8355 0.6353 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8390 0.6332 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8196 0.6376 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7995 0.6347 sec/batch
# Nearest to than: less, higher, more, half, about, in, zero, even,
# Nearest to zero: two, five, one, four, seven, three, six, nine,
# Nearest to is: the, a, an, of, and, as, are, it,
# Nearest to people: living, entertainers, births, politicians, explorers, hispanic, zafy, bolshevist,
# Nearest to war: united, hanko, hrerbunker, tente, romulus, urals, unawares, eutelsat,
# Nearest to all: which, other, with, and, most, for, there, these,
# Nearest to it: the, that, is, not, be, its, but, has,
# Nearest to often: uncommon, or, almond, remove, sometimes, english, intoxicated, generally,
# Nearest to nobel: prize, kocher, cyclotron, recipient, physiology, laureate, physicist, westbrook,
# Nearest to square: one, tiananmen, approximately, gilboa, five, kurtosis, maxis, coney,
# Nearest to something: question, know, i, resonates, anorexia, stromateis, passers, imagine,
# Nearest to pope: antipope, papal, calendarists, papacy, rooftop, avignon, yb, matters,
# Nearest to smith: spooner, tempting, bisects, jacobson, symbiosis, leonard, katarina, rea,
# Nearest to road: lane, roads, highway, pedestrians, route, freeway, qm, lanes,
# Nearest to running: relegation, distracted, peotone, marmite, sleeker, loch, embrace, anchoring,
# Nearest to rise: reinvent, johore, splash, cournot, manoeuvres, utopian, moralistic, prices,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8747 0.6392 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8062 0.6423 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9416 0.6383 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9313 0.6367 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8807 0.6310 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8548 0.6373 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7999 0.6315 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8157 0.6330 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7284 0.6336 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8579 0.6357 sec/batch
# Nearest to than: less, higher, more, half, about, males, above, even,
# Nearest to zero: two, five, four, seven, three, one, six, nine,
# Nearest to is: the, a, an, of, as, and, it, are,
# Nearest to people: living, entertainers, births, hispanic, worst, zafy, bolshevist, see,
# Nearest to war: united, hrerbunker, tente, unawares, hanko, urals, eutelsat, uniformed,
# Nearest to all: which, other, and, with, most, there, for, days,
# Nearest to it: the, that, is, but, not, be, a, have,
# Nearest to often: uncommon, or, almond, generally, sometimes, remove, intoxicated, needs,
# Nearest to nobel: prize, recipient, laureate, physiology, kocher, physicist, cyclotron, westbrook,
# Nearest to square: tiananmen, one, gilboa, approximately, kurtosis, maxis, datasheet, coney,
# Nearest to something: question, i, know, anorexia, resonates, imagine, headlines, stromateis,
# Nearest to pope: antipope, papal, calendarists, avignon, papacy, castiglione, mccarty, nuncio,
# Nearest to smith: spooner, bisects, tempting, symbiosis, jacobson, leonard, begotten, latter,
# Nearest to road: lane, roads, pedestrians, highway, qm, freeway, route, lanes,
# Nearest to running: relegation, peotone, distracted, sleeker, marmite, loch, embrace, propylene,
# Nearest to rise: reinvent, johore, splash, manoeuvres, cournot, utopian, moralistic, trakai,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8584 0.6383 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8360 0.6372 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
