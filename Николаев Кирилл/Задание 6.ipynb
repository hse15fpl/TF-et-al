# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:25, 366kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

def sub_sampling(int_words, threshold):
    word_counter = Counter(int_words)
    total = len(int_words)
    freq = {word: count/total for word, count in word_counter.items()}
    p_drop = {word:(1-np.sqrt(threshold/ freq[word])) for word in word_counter}
    trained_words = [word for word in int_words if p_drop[word]<np.random.random()]
    return trained_words

train_words = sub_sampling(int_words, threshold= 1e-5)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 150 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-17-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6112 0.4952 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5625 0.3657 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4232 0.3556 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5588 0.3545 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4822 0.3531 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4779 0.3515 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4512 0.3555 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4986 0.3524 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4334 0.3506 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3666 0.3528 sec/batch
# Nearest to can: lombard, kludge, cmb, capsized, containing, peyton, tyre, andreessen,
# Nearest to which: beauty, corrective, ciders, leader, definite, have, aldington, cortege,
# Nearest to their: debugger, microtubule, irrevocably, coherentism, danish, puranas, fifi, paraphernalia,
# Nearest to during: msson, santa, demerger, palo, forecast, kittyhawk, mat, kroeber,
# Nearest to from: cretian, woodson, mundane, sampled, avon, lawless, nihilo, alto,
# Nearest to also: pokemon, gsm, banishing, threshold, intolerant, disparaged, horadric, rique,
# Nearest to had: navel, blackball, saliva, electrode, fringed, lampoon, afloat, gaping,
# Nearest to use: lito, looting, mulder, stan, bronzino, anaesthetics, apsu, intermedia,
# Nearest to brother: delicately, succession, gearing, menza, freeways, haploid, aaa, finned,
# Nearest to existence: tenures, redwoods, reproduced, suvorov, supercharger, rig, popper, hyperbole,
# Nearest to dr: providence, lanchester, contradiction, hira, insertions, expressionists, spin, theoretician,
# Nearest to institute: decidable, laughlin, bau, univac, fam, treatise, latinized, gautama,
# Nearest to animals: curium, today, wives, hpv, semite, puisne, kangra, approximant,
# Nearest to scale: braintree, oat, disproving, alshehhi, astray, restriction, significance, logograms,
# Nearest to grand: lest, starfleet, kippur, semantics, vientiane, cleese, ertegun, bakassi,
# Nearest to accepted: lactic, blockading, prasad, bribery, falklands, physical, numerous, imminent,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4557 0.3592 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3242 0.3546 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3297 0.3550 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1984 0.3523 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1163 0.3670 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1395 0.3664 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0598 0.4128 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0525 0.4637 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9733 0.4591 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9418 0.5160 sec/batch
# Nearest to can: containing, accept, lombard, access, shooters, re, cmb, puranas,
# Nearest to which: beauty, definite, leader, have, corrective, ciders, there, prepared,
# Nearest to their: be, danish, debugger, microtubule, coherentism, simple, examples, controlling,
# Nearest to during: santa, msson, conventional, long, forecast, palo, score, effect,
# Nearest to from: mundane, sampled, attempt, avon, dropping, gene, nihilo, woodson,
# Nearest to also: threshold, gsm, proportions, pokemon, intolerant, recent, between, lawsuit,
# Nearest to had: navel, electrode, saliva, afloat, despite, superheroes, successful, blackball,
# Nearest to use: lito, stan, looting, profession, equipment, sturdy, like, context,
# Nearest to brother: succession, delicately, freeways, menza, haploid, conclusions, analects, broke,
# Nearest to existence: tenures, reproduced, redwoods, rig, hyperbole, even, assemble, ground,
# Nearest to dr: providence, spin, contradiction, monad, sideways, lanchester, maneuver, face,
# Nearest to institute: decidable, univac, treatise, emergency, latinized, ber, bau, adjustment,
# Nearest to animals: today, colonists, sticky, barnes, franchise, curium, wives, outgoing,
# Nearest to scale: disproving, significance, restriction, peninsula, astray, alshehhi, oat, braintree,
# Nearest to grand: semantics, lest, rotten, highest, symbol, interplanetary, cleese, vientiane,
# Nearest to accepted: lactic, physical, select, numerous, cards, imminent, blockading, lange,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9150 0.5323 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8675 0.5121 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8455 0.4853 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8542 0.4638 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.7705 0.5052 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8024 0.4247 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7713 0.3762 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7641 0.3884 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7567 0.4129 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7660 0.4242 sec/batch
# Nearest to can: lombard, containing, puranas, shooters, unrelated, cmb, access, awkward,
# Nearest to which: beauty, definite, corrective, ciders, have, leader, prepared, sleep,
# Nearest to their: debugger, microtubule, be, irrevocably, coherentism, puranas, danish, speaking,
# Nearest to during: forecast, santa, msson, palo, score, involving, consonants, conventional,
# Nearest to from: mundane, avon, sampled, dropping, woodson, wavelengths, constants, nihilo,
# Nearest to also: threshold, gsm, pokemon, disparaged, intolerant, formulae, banishing, weak,
# Nearest to had: navel, electrode, saliva, afloat, fringed, superheroes, blackball, polyrhythmic,
# Nearest to use: lito, looting, stan, profession, raw, operators, equipment, handel,
# Nearest to brother: succession, freeways, haploid, delicately, malmesbury, conclusions, dioxide, broke,
# Nearest to existence: reproduced, tenures, rig, redwoods, hyperbole, popper, undesired, confirm,
# Nearest to dr: providence, contradiction, spin, maneuver, lanchester, monad, physiologist, annihilated,
# Nearest to institute: univac, treatise, decidable, adjustment, emergency, ber, floors, latinized,
# Nearest to animals: colonists, today, outgoing, franchise, barnes, wives, participants, curium,
# Nearest to scale: disproving, restriction, significance, astray, alshehhi, peninsula, oat, arithmetic,
# Nearest to grand: semantics, cleese, rotten, lest, kippur, starfleet, highest, ibero,
# Nearest to accepted: lactic, physical, select, numerous, imminent, cards, blockading, settlement,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7417 0.4625 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7188 0.3980 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7002 0.4872 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7056 0.4067 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7135 0.4686 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7018 0.4737 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.6867 0.4087 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.6853 0.3550 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6811 0.3672 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6545 0.3801 sec/batch
# Nearest to can: puranas, lombard, containing, weaving, unrelated, awkward, want, cmb,
# Nearest to which: definite, beauty, corrective, ciders, have, numeral, prepared, sleep,
# Nearest to their: debugger, irrevocably, microtubule, be, coherentism, trash, puranas, blood,
# Nearest to during: forecast, msson, syria, palo, kroeber, santa, jameson, microelectronics,
# Nearest to from: avon, mundane, woodson, sampled, fibre, dropping, nihilo, trait,
# Nearest to also: threshold, banishing, pokemon, intolerant, gsm, disparaged, formulae, virginity,
# Nearest to had: navel, electrode, saliva, polyrhythmic, superheroes, afloat, fringed, lampoon,
# Nearest to use: looting, lito, venerable, verdict, raw, jurassic, punt, intermedia,
# Nearest to brother: succession, haploid, embroiled, freeways, malmesbury, swain, delicately, calories,
# Nearest to existence: reproduced, tenures, popper, hyperbole, characterizes, undesired, redwoods, suvorov,
# Nearest to dr: providence, lanchester, contradiction, physiologist, maneuver, monad, dredging, hahn,
# Nearest to institute: univac, adjustment, decidable, ber, emergency, treatise, laughlin, bau,
# Nearest to animals: colonists, outgoing, today, wives, puisne, barnes, franchise, sticky,
# Nearest to scale: disproving, restriction, astray, braintree, alshehhi, significance, arithmetic, insane,
# Nearest to grand: semantics, cleese, rotten, kippur, ibero, indications, starfleet, imitators,
# Nearest to accepted: lactic, imminent, physical, numerous, select, iix, blockading, bribery,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6740 0.3886 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6510 0.4116 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6244 0.3798 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6063 0.3784 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6224 0.3841 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6391 0.3871 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6165 0.2799 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5692 0.3802 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5368 0.3877 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5139 0.3803 sec/batch
# Nearest to can: puranas, containing, weaving, unrelated, lombard, access, minimize, exact,
# Nearest to which: beauty, definite, corrective, ciders, have, sleep, aldington, prepared,
# Nearest to their: debugger, microtubule, irrevocably, be, coherentism, blood, lyrically, puranas,
# Nearest to during: forecast, msson, syria, limburg, jameson, long, swans, kroeber,
# Nearest to from: avon, mundane, woodson, dropping, sampled, fibre, trait, heights,
# Nearest to also: threshold, banishing, intolerant, disparaged, gsm, pokemon, rique, unaired,
# Nearest to had: navel, superheroes, fringed, polyrhythmic, saliva, electrode, lampoon, afloat,
# Nearest to use: lito, looting, inverse, punt, unfaithful, arsenate, shortfall, raw,
# Nearest to brother: succession, haploid, embroiled, swain, freeways, elder, broke, delicately,
# Nearest to existence: reproduced, characterizes, tenures, hyperbole, popper, suvorov, proper, toponyms,
# Nearest to dr: providence, lanchester, physiologist, monad, contradiction, maneuver, hahn, dredging,
# Nearest to institute: adjustment, ber, decidable, laughlin, emergency, univac, sales, bau,
# Nearest to animals: puisne, colonists, outgoing, approximant, wives, semite, mozi, curium,
# Nearest to scale: disproving, restriction, oat, arithmetic, braintree, stabilize, alshehhi, significance,
# Nearest to grand: cleese, rotten, ibero, italiana, kippur, ertegun, indications, highest,
# Nearest to accepted: lactic, imminent, physical, blockading, numerous, astrophysics, select, iix,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5367 0.3907 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5387 0.3820 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4792 0.3823 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5031 0.4028 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4809 0.3880 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4808 0.3925 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4847 0.3875 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4294 0.3814 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4461 0.3874 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4565 0.3824 sec/batch
# Nearest to can: containing, problem, puranas, unrelated, minimize, be, utilized, linearity,
# Nearest to which: beauty, definite, corrective, xb, have, ciders, beano, deciding,
# Nearest to their: irrevocably, debugger, microtubule, be, coherentism, reborn, lyrically, ongoing,
# Nearest to during: forecast, syria, msson, limburg, jameson, booklet, delineates, renewing,
# Nearest to from: avon, mundane, woodson, nihilo, fibre, sampled, institutionalization, dropping,
# Nearest to also: banishing, threshold, rique, disparaged, gsm, intolerant, unaired, clocks,
# Nearest to had: navel, superheroes, fringed, polyrhythmic, lampoon, blackball, despite, successful,
# Nearest to use: lito, raw, like, context, inverse, looting, equipment, devices,
# Nearest to brother: succession, embroiled, elder, freeways, haploid, swain, broke, malmesbury,
# Nearest to existence: reproduced, characterizes, tenures, choose, even, popper, proper, toponyms,
# Nearest to dr: providence, lanchester, physiologist, monad, roadside, hahn, maneuver, dredging,
# Nearest to institute: ber, adjustment, laughlin, sales, decidable, gebhard, emergency, electress,
# Nearest to animals: puisne, garages, mozi, hpv, approximant, semite, curium, diabetes,
# Nearest to scale: restriction, disproving, oat, arithmetic, drowsiness, alshehhi, braintree, opposite,
# Nearest to grand: ibero, cleese, rotten, italiana, kippur, ertegun, hans, highest,
# Nearest to accepted: lactic, imminent, physical, astrophysics, numerous, select, hoc, blockading,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4392 0.3900 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4477 0.3942 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4412 0.3834 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.4008 0.3907 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4368 0.3853 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4482 0.3868 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.4096 0.3945 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3939 0.3892 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4198 0.3854 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3955 0.3865 sec/batch
# Nearest to can: containing, utilized, unrelated, linearity, problem, minimize, grams, weaving,
# Nearest to which: beauty, definite, corrective, ciders, xb, have, deciding, sleep,
# Nearest to their: irrevocably, microtubule, coherentism, be, debugger, reborn, blood, lyrically,
# Nearest to during: forecast, delineates, syria, long, limburg, kroeber, renewing, senka,
# Nearest to from: avon, fibre, mundane, sampled, woodson, heights, nihilo, wavelengths,
# Nearest to also: threshold, banishing, pokemon, intolerant, disparaged, unaired, virginity, rique,
# Nearest to had: superheroes, fringed, navel, polyrhythmic, successful, despite, blackball, willing,
# Nearest to use: raw, equipment, lito, rows, arsenate, approximation, inverse, assist,
# Nearest to brother: succession, embroiled, elder, broke, malmesbury, freeways, swain, haploid,
# Nearest to existence: characterizes, reproduced, tenures, choose, popper, reinstate, proper, toponyms,
# Nearest to dr: providence, lanchester, physiologist, hahn, roadside, monad, maneuver, hospitaller,
# Nearest to institute: ber, sales, adjustment, laughlin, emergency, gebhard, electress, homers,
# Nearest to animals: puisne, garages, curium, flagella, hpv, mozi, approximant, diabetes,
# Nearest to scale: drowsiness, restriction, disproving, arithmetic, braintree, opposite, oat, malaria,
# Nearest to grand: cleese, ibero, italiana, kippur, rotten, ertegun, reelection, highest,
# Nearest to accepted: lactic, imminent, physical, numerous, blockading, hoc, select, astrophysics,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3852 0.3941 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3874 0.3837 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3784 0.3832 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3598 0.3854 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4065 0.3822 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3953 0.3831 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3862 0.3900 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.4156 0.3838 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3334 0.3875 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3633 0.3809 sec/batch
# Nearest to can: containing, unrelated, linearity, utilized, disruptive, problem, grams, minimize,
# Nearest to which: beauty, definite, corrective, ciders, xb, deciding, have, aldington,
# Nearest to their: irrevocably, be, coherentism, blood, microtubule, ongoing, lyrically, reborn,
# Nearest to during: syria, delineates, forecast, affan, renewing, rte, increased, limburg,
# Nearest to from: fibre, avon, woodson, nihilo, pharaohs, heights, indo, the,
# Nearest to also: threshold, banishing, intolerant, pokemon, disparaged, rique, formulae, gsm,
# Nearest to had: fringed, navel, superheroes, successful, polyrhythmic, despite, lampoon, blackball,
# Nearest to use: raw, equipment, context, lito, rows, disadvantages, arsenate, assist,
# Nearest to brother: succession, elder, embroiled, malmesbury, broke, christina, swain, fates,
# Nearest to existence: characterizes, reproduced, popper, tenures, suvorov, choose, confirm, reinstate,
# Nearest to dr: hahn, providence, lanchester, roadside, physiologist, monad, maneuver, hira,
# Nearest to institute: ber, sales, laughlin, information, adjustment, homers, gebhard, emergency,
# Nearest to animals: diabetes, puisne, garages, curium, flagella, preparation, approximant, mozi,
# Nearest to scale: drowsiness, alshehhi, circulation, disproving, restriction, opposite, braintree, malaria,
# Nearest to grand: cleese, kippur, ibero, rotten, italiana, ertegun, reelection, erected,
# Nearest to accepted: imminent, lactic, physical, numerous, hoc, settlement, thermostat, entire,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3552 0.3955 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3005 0.4016 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3845 0.3887 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3671 0.3804 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3826 0.3849 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3088 0.3836 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3266 0.3816 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3611 0.3863 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2495 0.3967 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.3061 0.3946 sec/batch
# Nearest to can: linearity, disruptive, minimize, problem, unrelated, containing, utilized, grams,
# Nearest to which: beauty, definite, ciders, corrective, deciding, almohads, xb, have,
# Nearest to their: irrevocably, coherentism, lyrically, blood, be, microtubule, restrict, hypothermia,
# Nearest to during: syria, affan, rte, delineates, forecast, long, limburg, increased,
# Nearest to from: fibre, woodson, avon, spatially, dubliners, barcode, cretian, nihilo,
# Nearest to also: threshold, banishing, intolerant, rique, disparaged, pokemon, unaired, virginity,
# Nearest to had: fringed, superheroes, navel, successful, lampoon, blackball, saliva, despite,
# Nearest to use: equipment, raw, arsenate, rows, disadvantages, lito, context, reciprocals,
# Nearest to brother: succession, elder, embroiled, fates, malmesbury, christina, swain, pastoral,
# Nearest to existence: characterizes, reproduced, tenures, popper, proper, toponyms, paltrow, suvorov,
# Nearest to dr: hahn, providence, lanchester, physiologist, roadside, hospitaller, kestrel, monad,
# Nearest to institute: information, ber, sales, homers, gebhard, lorre, business, adjustment,
# Nearest to animals: diabetes, curium, flagella, mozi, puisne, nests, squid, junk,
# Nearest to scale: alshehhi, braintree, restriction, circulation, drowsiness, opposite, stabilize, disproving,
# Nearest to grand: ibero, cleese, ertegun, italiana, kippur, reelection, corby, rotten,
# Nearest to accepted: imminent, lactic, physical, numerous, settlement, enough, thermostat, hoc,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3078 0.4009 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3094 0.3842 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3433 0.1766 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.3028 0.3841 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2397 0.3918 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2617 0.3936 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2382 0.4035 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2600 0.3991 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2637 0.3867 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.2226 0.3845 sec/batch
# Nearest to can: linearity, utilized, disruptive, unrelated, grams, minimize, monitor, purposefully,
# Nearest to which: beauty, ciders, definite, corrective, xb, deciding, almohads, aldington,
# Nearest to their: irrevocably, be, coherentism, blood, hypothermia, microtubule, lyrically, reborn,
# Nearest to during: affan, syria, delineates, rte, long, demerger, increased, forecast,
# Nearest to from: fibre, the, spatially, woodson, dubliners, cretian, heights, avon,
# Nearest to also: rique, threshold, banishing, heterotic, intolerant, whistle, disparaged, fortuitous,
# Nearest to had: fringed, superheroes, blackball, successful, navel, lampoon, favoritism, saliva,
# Nearest to use: equipment, raw, rieker, disadvantages, mainstay, rows, internet, arsenate,
# Nearest to brother: succession, elder, embroiled, fates, christina, malmesbury, pastoral, switzer,
# Nearest to existence: reproduced, characterizes, popper, choose, proper, toponyms, tenures, paltrow,
# Nearest to dr: hahn, lanchester, roadside, providence, physiologist, monad, maneuver, abd,
# Nearest to institute: information, ber, homers, sales, vl, gebhard, business, lobby,
# Nearest to animals: nests, squid, diabetes, garages, pedestrian, flagella, curium, junk,
# Nearest to scale: circulation, opposite, alshehhi, braintree, consumes, restriction, mush, malaria,
# Nearest to grand: cleese, ibero, ertegun, reelection, corby, kippur, mercia, italiana,
# Nearest to accepted: imminent, physical, lactic, settlement, numerous, thermostat, enough, entire,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2774 0.3938 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2735 0.3857 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2488 0.3803 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1839 0.3870 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2121 0.3761 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1971 0.3762 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.2216 0.3760 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2201 0.3759 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2072 0.3786 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.2041 0.3794 sec/batch
# Nearest to can: linearity, utilized, unrelated, maxima, disruptive, grams, purposefully, lovingly,
# Nearest to which: beauty, definite, corrective, deciding, ciders, xb, almohads, underlies,
# Nearest to their: irrevocably, hypothermia, reborn, coherentism, microtubule, be, blood, lyrically,
# Nearest to during: affan, delineates, syria, rte, demerger, increased, forecast, long,
# Nearest to from: spatially, the, fibre, cretian, dubliners, pharaohs, heights, nihilo,
# Nearest to also: heterotic, intolerant, threshold, whistle, rique, disparaged, banishing, pokemon,
# Nearest to had: blackball, successful, superheroes, fringed, navel, favoritism, realize, lampoon,
# Nearest to use: raw, disadvantages, usemodwiki, equipment, mainstay, selected, context, gpo,
# Nearest to brother: succession, elder, embroiled, fates, malmesbury, switzer, appointment, pastoral,
# Nearest to existence: reproduced, characterizes, popper, choose, scientifically, ought, proper, toponyms,
# Nearest to dr: hahn, roadside, physiologist, lanchester, providence, monad, hospitaller, kestrel,
# Nearest to institute: information, ber, educational, gebhard, vl, homers, engineering, bawerk,
# Nearest to animals: nests, squid, flagella, diabetes, plants, junk, garages, wandering,
# Nearest to scale: braintree, opposite, circulation, consumes, alshehhi, mush, stabilize, anoa,
# Nearest to grand: cleese, ibero, ertegun, corby, kippur, mercia, reelection, cocktails,
# Nearest to accepted: physical, imminent, lactic, numerous, astrophysics, settlement, thermostat, entire,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1944 0.3877 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2334 0.3807 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.2001 0.3892 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1745 0.3848 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.2101 0.3819 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2002 0.3859 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2324 0.3873 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1660 0.3821 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1669 0.3843 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2233 0.3835 sec/batch
# Nearest to can: linearity, disruptive, unrelated, grams, utilized, maxima, lovingly, ringing,
# Nearest to which: beauty, corrective, definite, ciders, deciding, aldington, almohads, underlies,
# Nearest to their: irrevocably, hypothermia, microtubule, coherentism, blood, lyrically, restrict, reborn,
# Nearest to during: affan, rte, delineates, syria, increased, demerger, long, obispo,
# Nearest to from: the, spatially, heights, cretian, fibre, nihilo, dubliners, barcode,
# Nearest to also: whistle, threshold, heterotic, disparaged, fortuitous, intolerant, pokemon, rique,
# Nearest to had: blackball, fringed, superheroes, successful, favoritism, navel, hypnotherapy, realize,
# Nearest to use: usemodwiki, selected, disadvantages, mainstay, raw, rows, handel, reciprocals,
# Nearest to brother: elder, succession, embroiled, fates, malmesbury, pastoral, switzer, heroines,
# Nearest to existence: characterizes, popper, reproduced, toponyms, proper, scientifically, choose, incoherent,
# Nearest to dr: hahn, roadside, physiologist, monad, providence, lanchester, voluminous, hira,
# Nearest to institute: information, educational, ber, engineering, vl, gebhard, homers, fellows,
# Nearest to animals: nests, flagella, squid, plants, grasses, diabetes, junk, garages,
# Nearest to scale: braintree, circulation, opposite, consumes, alshehhi, malaria, anoa, mush,
# Nearest to grand: cleese, ibero, ertegun, corby, mercia, kippur, reelection, cocktails,
# Nearest to accepted: physical, imminent, lactic, numerous, astrophysics, settlement, select, shred,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2247 0.3861 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1904 0.3842 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1948 0.3834 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1895 0.3851 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1633 0.3865 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1739 0.3812 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1783 0.3841 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1568 0.3815 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2408 0.3930 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2149 0.3856 sec/batch
# Nearest to can: linearity, disruptive, unrelated, purposefully, lovingly, say, want, maxima,
# Nearest to which: beauty, corrective, definite, ciders, almohads, deciding, aldington, mantra,
# Nearest to their: irrevocably, coherentism, hypothermia, be, blood, lyrically, reborn, microtubule,
# Nearest to during: affan, rte, delineates, syria, increased, demerger, fermium, obispo,
# Nearest to from: the, lakshadweep, dubliners, heights, cretian, osnabr, pharaohs, spatially,
# Nearest to also: whistle, intolerant, disparaged, heterotic, pokemon, rique, virginity, threshold,
# Nearest to had: blackball, successful, navel, fringed, favoritism, zoran, superheroes, saliva,
# Nearest to use: usemodwiki, disadvantages, handel, reciprocals, selected, raw, context, mainstay,
# Nearest to brother: elder, succession, embroiled, fates, malmesbury, switzer, christina, gaslight,
# Nearest to existence: popper, reproduced, characterizes, toponyms, scientifically, proper, narmer, choose,
# Nearest to dr: hahn, roadside, physiologist, providence, lanchester, monad, voluminous, ubi,
# Nearest to institute: educational, information, ber, fellows, engineering, vl, gebhard, homers,
# Nearest to animals: nests, squid, flagella, grasses, ritually, plants, mozi, otters,
# Nearest to scale: braintree, circulation, alshehhi, anoa, consumes, malaria, opposite, clustered,
# Nearest to grand: cleese, ertegun, ibero, corby, mercia, kippur, reelection, cocktails,
# Nearest to accepted: physical, numerous, imminent, settlement, astrophysics, lactic, kaaba, select,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2616 0.3780 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1532 0.3788 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1688 0.3773 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1720 0.3836 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0722 0.3853 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1487 0.3797 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1650 0.4181 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1483 0.4511 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1892 0.0853 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1771 0.4431 sec/batch
# Nearest to can: linearity, unrelated, disruptive, grams, unoccupied, ringing, purposefully, say,
# Nearest to which: beauty, ciders, definite, corrective, almohads, deciding, xb, underlies,
# Nearest to their: hypothermia, irrevocably, lyrically, coherentism, restrict, microtubule, be, goals,
# Nearest to during: affan, rte, syria, increased, demerger, delineates, fermium, long,
# Nearest to from: the, spatially, cretian, lakshadweep, fibre, dubliners, inexact, constants,
# Nearest to also: heterotic, intolerant, rique, whistle, threshold, disparaged, pokemon, fortuitous,
# Nearest to had: blackball, successful, superheroes, saliva, favoritism, navel, realize, fringed,
# Nearest to use: usemodwiki, disadvantages, mainstay, arsenate, vocabulary, handel, reciprocals, context,
# Nearest to brother: elder, succession, embroiled, fates, malmesbury, appointment, christina, switzer,
# Nearest to existence: popper, reproduced, toponyms, proper, scientifically, characterizes, choose, paltrow,
# Nearest to dr: hahn, roadside, physiologist, lanchester, voluminous, hira, ubi, providence,
# Nearest to institute: educational, information, fellows, engineering, ber, vl, gebhard, bawerk,
# Nearest to animals: nests, squid, grasses, flagella, plants, ritually, eggs, otters,
# Nearest to scale: braintree, circulation, opposite, anoa, consumes, mush, clustered, alshehhi,
# Nearest to grand: cleese, ertegun, ibero, mercia, corby, nana, kippur, immediately,
# Nearest to accepted: physical, astrophysics, imminent, numerous, settlement, kaaba, lactic, thermostat,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0899 0.4544 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.1128 0.4477 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1195 0.4491 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.1052 0.4468 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.1024 0.4410 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0585 0.4568 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1477 0.4676 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1123 0.4243 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1576 0.3742 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0534 0.3920 sec/batch
# Nearest to can: linearity, unrelated, grams, utilized, disruptive, ringing, purposefully, unoccupied,
# Nearest to which: beauty, definite, ciders, corrective, xb, deciding, almohads, have,
# Nearest to their: hypothermia, irrevocably, to, be, restrict, coherentism, microtubule, lyrically,
# Nearest to during: affan, increased, demerger, rte, syria, fermium, long, delineates,
# Nearest to from: the, spatially, rarely, cretian, lakshadweep, fibre, indo, dubliners,
# Nearest to also: heterotic, whistle, intolerant, disparaged, rique, threshold, pokemon, sixths,
# Nearest to had: blackball, successful, favoritism, superheroes, realize, saliva, fringed, steamship,
# Nearest to use: usemodwiki, disadvantages, handel, vocabulary, mainstay, equipment, raw, networking,
# Nearest to brother: elder, succession, fates, embroiled, appointment, switzer, christina, yastrzemski,
# Nearest to existence: popper, toponyms, reproduced, scientifically, characterizes, proper, choose, ammon,
# Nearest to dr: roadside, hahn, voluminous, physiologist, lanchester, hira, providence, monad,
# Nearest to institute: educational, information, fellows, engineering, ber, bawerk, vl, research,
# Nearest to animals: nests, flagella, squid, ritually, grasses, otters, plants, mozi,
# Nearest to scale: opposite, circulation, braintree, anoa, consumes, mush, clustered, replays,
# Nearest to grand: cleese, ibero, ertegun, mercia, immediately, corby, helge, erected,
# Nearest to accepted: numerous, astrophysics, physical, settlement, imminent, lactic, kaaba, unclear,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0481 0.3661 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0664 0.3513 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0814 0.3505 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0771 0.3620 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.1059 0.3651 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0627 0.3733 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.1050 0.3704 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1026 0.3683 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0764 0.3734 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0622 0.3679 sec/batch
# Nearest to can: linearity, disruptive, say, unrelated, want, db, toggle, ringing,
# Nearest to which: beauty, definite, corrective, ciders, mantra, connectionist, the, flagellates,
# Nearest to their: hypothermia, irrevocably, lyrically, coherentism, to, microtubule, restrict, frighten,
# Nearest to during: affan, rte, increased, demerger, syria, fermium, displace, delineates,
# Nearest to from: the, spatially, cretian, lakshadweep, fibre, barcode, clustering, powermac,
# Nearest to also: whistle, heterotic, rique, intolerant, disparaged, pokemon, threshold, customs,
# Nearest to had: blackball, successful, fringed, realize, superheroes, favoritism, navel, hypnotherapy,
# Nearest to use: usemodwiki, disadvantages, vocabulary, context, pos, selected, handel, arsenate,
# Nearest to brother: elder, succession, fates, embroiled, switzer, yastrzemski, appointment, gaslight,
# Nearest to existence: popper, toponyms, reproduced, scientifically, characterizes, proper, exists, dieu,
# Nearest to dr: hahn, roadside, physiologist, voluminous, hira, monad, lanchester, ubi,
# Nearest to institute: educational, engineering, fellows, information, vl, bawerk, professors, gebhard,
# Nearest to animals: nests, flagella, squid, ritually, otters, plants, grasses, mozi,
# Nearest to scale: opposite, circulation, braintree, consumes, anoa, replays, mush, clustered,
# Nearest to grand: cleese, ibero, ertegun, mercia, corby, assailed, helge, kippur,
# Nearest to accepted: astrophysics, physical, numerous, lactic, imminent, settlement, kaaba, shred,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0825 0.3721 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1179 0.3665 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0950 0.3741 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0851 0.3722 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0800 0.3882 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0813 0.3817 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.1236 0.3831 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.1076 0.3906 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.1076 0.3843 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.1027 0.3819 sec/batch
# Nearest to can: linearity, disruptive, ringing, say, toggle, want, cmb, db,
# Nearest to which: beauty, the, ciders, definite, corrective, almohads, mantra, fremantle,
# Nearest to their: coherentism, irrevocably, to, hypothermia, microtubule, restrict, frighten, lyrically,
# Nearest to during: affan, increased, rte, demerger, syria, displace, fermium, straits,
# Nearest to from: the, spatially, lakshadweep, heights, throughout, osnabr, indo, middle,
# Nearest to also: whistle, intolerant, disparaged, heterotic, vyanjana, customs, rique, fortuitous,
# Nearest to had: blackball, successful, was, fringed, steamship, realize, favoritism, amounting,
# Nearest to use: usemodwiki, disadvantages, handel, pos, arsenate, selected, rows, reciprocals,
# Nearest to brother: elder, succession, fates, embroiled, appointment, inherited, switzer, christina,
# Nearest to existence: popper, toponyms, reproduced, scientifically, characterizes, callisthenes, dieu, sufi,
# Nearest to dr: roadside, hahn, voluminous, physiologist, hira, ubi, monad, providence,
# Nearest to institute: educational, engineering, fellows, vl, professors, bawerk, gebhard, information,
# Nearest to animals: nests, flagella, squid, otters, ritually, plants, grasses, mozi,
# Nearest to scale: opposite, circulation, braintree, anoa, consumes, replays, artificially, mauna,
# Nearest to grand: cleese, mercia, ertegun, assailed, helge, ibero, immediately, corby,
# Nearest to accepted: numerous, astrophysics, physical, settlement, imminent, lactic, shred, kaaba,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0924 0.3833 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0209 0.3882 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0573 0.3812 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0953 0.3815 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0932 0.3797 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1191 0.3798 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1715 0.4053 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0662 0.3848 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0669 0.4272 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0867 0.4128 sec/batch
# Nearest to can: linearity, say, disruptive, or, unrelated, db, cmb, ringing,
# Nearest to which: beauty, the, corrective, ciders, definite, connectionist, fremantle, almohads,
# Nearest to their: to, hypothermia, restrict, microtubule, irrevocably, coherentism, lyrically, deletes,
# Nearest to during: affan, increased, rte, demerger, displace, fermium, syria, escaped,
# Nearest to from: the, spatially, lakshadweep, cretian, fibre, rarely, osnabr, sprouted,
# Nearest to also: rique, disparaged, intolerant, whistle, dte, customs, heterotic, which,
# Nearest to had: blackball, successful, saliva, realize, steamship, navel, lacked, hypnotherapy,
# Nearest to use: usemodwiki, disadvantages, handel, arsenate, vocabulary, context, clarify, reciprocals,
# Nearest to brother: elder, succession, fates, embroiled, christina, yastrzemski, inherited, switzer,
# Nearest to existence: popper, toponyms, reproduced, scientifically, dieu, dictionnaire, proper, callisthenes,
# Nearest to dr: roadside, hahn, voluminous, physiologist, ubi, hira, syntagma, hospitaller,
# Nearest to institute: educational, engineering, fellows, vl, gebhard, bawerk, professors, information,
# Nearest to animals: nests, flagella, squid, ritually, otters, plants, mozi, junk,
# Nearest to scale: opposite, circulation, replays, anoa, consumes, braintree, artificially, mauna,
# Nearest to grand: cleese, mercia, assailed, helge, ertegun, habsburg, corby, ibero,
# Nearest to accepted: astrophysics, numerous, physical, settlement, imminent, kaaba, lactic, select,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0111 0.5231 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0874 0.4094 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0547 0.3842 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0653 0.4004 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.1092 0.3954 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0721 0.3500 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0354 0.3996 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 4.0517 0.3880 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0581 0.4334 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 4.0120 0.4211 sec/batch
# Nearest to can: linearity, cmb, unrelated, toggle, say, ringing, db, disruptive,
# Nearest to which: beauty, the, corrective, ciders, fremantle, deciding, mantra, definite,
# Nearest to their: microtubule, hypothermia, to, coherentism, restrict, goals, xilinx, irrevocably,
# Nearest to during: affan, increased, rte, demerger, syria, fermium, displace, gleam,
# Nearest to from: the, spatially, cretian, fibre, osnabr, repulsion, sprouted, rarely,
# Nearest to also: rique, intolerant, whistle, heterotic, dte, vyanjana, sixths, disparaged,
# Nearest to had: blackball, realize, successful, navel, prudence, saliva, steps, hypnotherapy,
# Nearest to use: usemodwiki, disadvantages, equipment, handel, arsenate, unfaithful, reciprocals, sturdy,
# Nearest to brother: elder, succession, fates, embroiled, appointment, inherited, yastrzemski, fulgencio,
# Nearest to existence: popper, toponyms, scientifically, reproduced, sufi, ammon, exists, callisthenes,
# Nearest to dr: roadside, hahn, voluminous, physiologist, hira, ubi, contradiction, providence,
# Nearest to institute: educational, fellows, engineering, vl, professors, bawerk, information, lobby,
# Nearest to animals: nests, flagella, squid, ritually, otters, mozi, plants, junk,
# Nearest to scale: opposite, anoa, circulation, viru, mush, braintree, replays, curves,
# Nearest to grand: cleese, mercia, ertegun, helge, habsburg, erected, assailed, ibero,
# Nearest to accepted: astrophysics, numerous, lactic, imminent, physical, kaaba, counsel, shred,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0227 0.3988 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9457 0.4041 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0815 0.4656 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0150 0.3924 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0588 0.3833 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0139 0.3937 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9519 0.4084 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9884 0.4045 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9742 0.3861 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0060 0.3851 sec/batch
# Nearest to can: linearity, unrelated, say, toggle, ringing, cmb, subsets, separated,
# Nearest to which: the, beauty, definite, corrective, also, ciders, fremantle, have,
# Nearest to their: to, hypothermia, microtubule, tenacious, goals, frighten, restrict, infiltrated,
# Nearest to during: increased, rte, affan, demerger, syria, fermium, displace, lasts,
# Nearest to from: the, spatially, powermac, lakshadweep, rarely, cretian, in, celera,
# Nearest to also: rique, whistle, dte, which, intolerant, disparaged, heterotic, shapiro,
# Nearest to had: blackball, successful, realize, amounting, navel, saliva, electrode, favoritism,
# Nearest to use: usemodwiki, disadvantages, handel, arsenate, equipment, vocabulary, pos, context,
# Nearest to brother: elder, succession, fates, embroiled, appointment, yastrzemski, inherited, someone,
# Nearest to existence: popper, toponyms, reproduced, scientifically, exists, characterizes, callisthenes, ammon,
# Nearest to dr: roadside, hahn, voluminous, ubi, contradiction, hira, physiologist, providence,
# Nearest to institute: educational, fellows, engineering, professors, vl, bawerk, professor, gebhard,
# Nearest to animals: nests, squid, flagella, otters, ritually, mozi, plants, junk,
# Nearest to scale: opposite, anoa, circulation, replays, viru, braintree, mush, octave,
# Nearest to grand: cleese, ertegun, mercia, helge, assailed, habsburg, wept, erected,
# Nearest to accepted: astrophysics, lactic, numerous, imminent, settlement, counsel, select, physical,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0508 0.4013 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0137 0.3885 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9988 0.3861 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0171 0.4273 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0752 0.3975 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9657 0.4057 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 4.0179 0.3997 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0308 0.3957 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9988 0.4596 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0324 0.4069 sec/batch
# Nearest to can: linearity, say, toggle, ringing, db, unrelated, subsets, disruptive,
# Nearest to which: the, beauty, corrective, also, mantra, fremantle, deciding, ciders,
# Nearest to their: to, tenacious, restrict, microtubule, goals, hypothermia, deletes, byword,
# Nearest to during: increased, rte, affan, demerger, fermium, lasts, displace, syria,
# Nearest to from: the, spatially, barcode, cretian, lakshadweep, rarely, sprouted, in,
# Nearest to also: disparaged, whistle, intolerant, which, vyanjana, dte, rique, between,
# Nearest to had: blackball, successful, realize, electrode, prudence, amounting, steps, steamship,
# Nearest to use: usemodwiki, disadvantages, handel, equipment, provide, pos, clarify, context,
# Nearest to brother: elder, succession, fates, embroiled, appointment, switzer, yastrzemski, mctell,
# Nearest to existence: popper, toponyms, scientifically, reproduced, exists, characterizes, dieu, callisthenes,
# Nearest to dr: roadside, hahn, ubi, voluminous, hira, hometown, physiologist, glenfinnan,
# Nearest to institute: educational, professors, fellows, engineering, vl, professor, bawerk, information,
# Nearest to animals: nests, flagella, squid, otters, plants, ritually, mozi, eggs,
# Nearest to scale: opposite, anoa, braintree, davey, circulation, replays, elaboration, octave,
# Nearest to grand: cleese, assailed, helge, mercia, ertegun, wept, erected, neoplatonism,
# Nearest to accepted: astrophysics, lactic, physical, imminent, numerous, counsel, select, celebrant,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0232 0.4422 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9917 0.4093 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9975 0.4167 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0172 0.4196 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0129 0.4120 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0428 0.3896 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 4.0218 0.4147 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9872 0.3927 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 4.0194 0.3894 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0573 0.3865 sec/batch
# Nearest to can: linearity, say, toggle, ringing, unrelated, separated, cmb, db,
# Nearest to which: the, beauty, also, mantra, of, to, corrective, deciding,
# Nearest to their: to, tenacious, restrict, microtubule, hypothermia, goals, byword, humiliate,
# Nearest to during: increased, affan, rte, demerger, syria, lasts, displace, fermium,
# Nearest to from: the, in, lakshadweep, spatially, sprouted, rarely, osnabr, glottis,
# Nearest to also: which, dte, intolerant, vyanjana, rique, disparaged, between, whistle,
# Nearest to had: realize, electrode, blackball, steamship, amounting, steps, saliva, was,
# ...
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.8624 0.3642 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.8345 0.3665 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8769 0.3691 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8950 0.3636 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8601 0.3619 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.9048 0.3648 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9390 0.3658 sec/batch
# Nearest to can: be, say, so, will, sure, re, if, want,
# Nearest to which: the, of, to, that, is, a, in, also,
# Nearest to their: to, they, them, restrict, marrying, together, banjar, and,
# Nearest to during: synchronized, lasts, increased, cytosol, rte, were, days, from,
# Nearest to from: the, in, a, to, of, entered, by, as,
# Nearest to also: the, in, and, is, other, of, based, that,
# Nearest to had: was, electrode, began, when, turbografx, as, that, least,
# Nearest to use: usemodwiki, sturdy, genericized, handel, preferred, pronounce, expressions, combustor,
# Nearest to brother: mctell, mother, elder, succession, father, son, fulgencio, sister,
# Nearest to existence: popper, souls, exists, reproduced, toponyms, eroding, worshipping, receded,
# Nearest to dr: roadside, newbery, reentry, hometown, hahn, dredging, glenfinnan, ecw,
# Nearest to institute: technology, professor, professors, vl, university, minneapolis, center, engineering,
# Nearest to animals: nests, flagella, squid, biomechanical, mozi, kinsey, agouti, wandered,
# Nearest to scale: octave, execute, chromatic, anoa, elaboration, vaillant, monmouth, ensconced,
# Nearest to grand: cleese, assailed, coulthard, adiabat, helge, slam, carnot, spreading,
# Nearest to accepted: astrophysics, urgently, counsel, shred, celebrant, not, proselytes, simon,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8311 0.3705 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8816 0.3593 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8748 0.3608 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8598 0.3608 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8968 0.3650 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8830 0.3595 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8765 0.3633 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8511 0.3630 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9002 0.3617 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8880 0.3590 sec/batch
# Nearest to can: say, re, will, be, so, ringing, if, or,
# Nearest to which: the, of, a, anisotropies, to, that, in, also,
# Nearest to their: to, them, they, restrict, living, together, marrying, entire,
# Nearest to during: synchronized, increased, lasts, rte, were, from, cytosol, demerger,
# Nearest to from: the, in, a, to, of, is, and, as,
# Nearest to also: the, is, in, and, of, other, between, are,
# Nearest to had: was, began, as, but, electrode, been, lacked, least,
# Nearest to use: usemodwiki, sturdy, handel, preferred, thomas, expressions, genericized, combustor,
# Nearest to brother: mother, succession, mctell, elder, father, sister, son, fulgencio,
# Nearest to existence: popper, exists, souls, toponyms, reproduced, eroding, receded, dieu,
# Nearest to dr: roadside, newbery, reentry, hometown, hahn, dredging, glenfinnan, collimated,
# Nearest to institute: professor, technology, vl, professors, university, minneapolis, center, educational,
# Nearest to animals: nests, flagella, squid, kinsey, wandered, mozi, impregnated, biomechanical,
# Nearest to scale: octave, execute, anoa, davey, chromatic, attracting, elaboration, vaillant,
# Nearest to grand: cleese, assailed, coulthard, auto, adiabat, ashley, spreading, slam,
# Nearest to accepted: astrophysics, urgently, not, counsel, shred, the, proselytes, that,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.9017 0.3612 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.9041 0.3728 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8456 0.3840 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8473 0.3703 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9122 0.3610 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8701 0.3644 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9830 0.3619 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9352 0.3609 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9350 0.3583 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8498 0.3563 sec/batch
# Nearest to can: say, be, will, re, so, sure, if, antiderivatives,
# Nearest to which: the, of, a, original, in, from, that, anisotropies,
# Nearest to their: to, them, they, restrict, were, always, living, conscripted,
# Nearest to during: from, were, synchronized, in, lasts, increased, after, the,
# Nearest to from: the, in, a, to, of, and, during, as,
# Nearest to also: the, in, of, is, other, and, for, based,
# Nearest to had: was, as, began, been, but, when, lacked, died,
# Nearest to use: expressions, usemodwiki, sturdy, pronounce, handel, reliance, preferred, unfaithful,
# Nearest to brother: succession, mother, mctell, elder, father, fulgencio, sister, son,
# Nearest to existence: popper, exists, souls, reproduced, toponyms, eroding, receded, dieu,
# Nearest to dr: newbery, hometown, roadside, reentry, hahn, dredging, glenfinnan, roh,
# Nearest to institute: professor, technology, professors, vl, university, lab, center, minneapolis,
# Nearest to animals: nests, kinsey, flagella, shinto, mozi, wandered, halevi, agouti,
# Nearest to scale: octave, execute, chromatic, davey, anoa, luminiferous, sectors, attracting,
# Nearest to grand: cleese, assailed, coulthard, ashley, spreading, auto, adiabat, slam,
# Nearest to accepted: astrophysics, urgently, counsel, not, the, simon, hoc, shred,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8127 0.3636 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8800 0.3744 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.8219 0.3827 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8814 0.3804 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8625 0.3730 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8661 0.3687 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9212 0.2111 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8522 0.3641 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8758 0.3647 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8602 0.3643 sec/batch
# Nearest to can: re, say, be, will, sure, aligning, ringing, so,
# Nearest to which: the, of, a, in, from, that, is, to,
# Nearest to their: to, they, them, from, were, have, always, throughout,
# Nearest to during: from, synchronized, lasts, were, increased, in, the, rte,
# Nearest to from: the, in, a, to, of, is, as, and,
# Nearest to also: the, in, is, of, other, and, a, are,
# Nearest to had: was, began, as, but, died, that, he, been,
# Nearest to use: sturdy, usemodwiki, expressions, reliance, preferred, pronounce, unfaithful, handel,
# Nearest to brother: elder, mother, mctell, father, succession, fulgencio, son, sister,
# Nearest to existence: popper, exists, souls, eroding, toponyms, reproduced, dieu, receded,
# Nearest to dr: hometown, reentry, newbery, roadside, hahn, glenfinnan, hospitaller, roh,
# Nearest to institute: professor, technology, professors, vl, lab, nanyang, educational, wissenschaften,
# Nearest to animals: nests, kinsey, flagella, biomechanical, shinto, agouti, wandered, mozi,
# Nearest to scale: octave, execute, chromatic, scales, anoa, davey, sectors, negus,
# Nearest to grand: cleese, assailed, coulthard, slam, auto, adiabat, passau, spreading,
# Nearest to accepted: astrophysics, urgently, counsel, not, theresia, simon, did, shred,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8656 0.3663 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8715 0.3666 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8513 0.3828 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8253 0.3850 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8865 0.3701 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8557 0.3532 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8880 0.3491 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7670 0.3608 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8080 0.3559 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8120 0.3536 sec/batch
# Nearest to can: be, so, say, or, if, re, will, physical,
# Nearest to which: the, of, in, a, is, that, from, for,
# Nearest to their: to, they, them, were, from, thanatos, restrict, throughout,
# Nearest to during: from, synchronized, increased, lasts, were, rte, in, after,
# Nearest to from: the, in, a, to, of, which, is, during,
# Nearest to also: the, in, and, of, other, is, are, which,
# Nearest to had: was, began, but, been, lacked, electrode, least, as,
# Nearest to use: used, usemodwiki, expressions, preferred, pronounce, handel, reliance, refer,
# Nearest to brother: mctell, fulgencio, father, succession, mother, elder, son, sister,
# Nearest to existence: popper, exists, souls, eroding, reproduced, toponyms, dieu, receded,
# Nearest to dr: roadside, hometown, reentry, newbery, hahn, glenfinnan, hospitaller, contradiction,
# Nearest to institute: professor, vl, technology, professors, nanyang, lab, minneapolis, center,
# Nearest to animals: kinsey, flagella, agouti, shinto, halevi, nests, biomechanical, duesberg,
# Nearest to scale: octave, execute, chromatic, scales, sectors, davey, anoa, negus,
# Nearest to grand: cleese, coulthard, assailed, slam, spreading, adiabat, carnot, ashley,
# Nearest to accepted: astrophysics, urgently, counsel, not, theresia, did, that, relegated,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7940 0.3605 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8576 0.3549 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8659 0.3533 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8523 0.3528 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8435 0.3629 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9419 0.3791 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8502 0.3934 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8337 0.3732 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8339 0.3721 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8707 0.3599 sec/batch
# Nearest to can: be, so, say, or, to, will, physical, re,
# Nearest to which: the, of, a, in, is, that, also, from,
# Nearest to their: to, they, them, were, restrict, always, marrying, from,
# Nearest to during: synchronized, lasts, were, from, rte, increased, cytosol, padding,
# Nearest to from: the, in, a, to, as, of, is, and,
# Nearest to also: the, in, is, of, and, are, a, which,
# Nearest to had: was, began, been, as, electrode, but, lacked, later,
# Nearest to use: used, usemodwiki, preferred, sturdy, handel, pronounce, combustor, centronics,
# Nearest to brother: mctell, succession, father, elder, mother, son, fulgencio, sister,
# Nearest to existence: popper, exists, eroding, souls, reproduced, toponyms, dieu, impregnate,
# Nearest to dr: hometown, reentry, newbery, roadside, hahn, glenfinnan, hospitaller, contradiction,
# Nearest to institute: professor, technology, vl, university, minneapolis, educational, professors, nanyang,
# Nearest to animals: flagella, kinsey, agouti, nests, mozi, wandered, today, shinto,
# Nearest to scale: octave, execute, scales, chromatic, davey, negus, sectors, ensconced,
# Nearest to grand: cleese, coulthard, assailed, spreading, slam, adiabat, carnot, ashley,
# Nearest to accepted: astrophysics, urgently, not, counsel, theresia, did, that, lange,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9096 0.3713 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8432 0.3612 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8157 0.3616 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8612 0.3696 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8982 0.3596 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8508 0.3593 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8557 0.3613 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8985 0.3552 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8126 0.3563 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8563 0.3530 sec/batch
# Nearest to can: be, say, so, will, or, re, to, if,
# Nearest to which: the, of, a, in, that, is, from, to,
# Nearest to their: to, they, them, were, from, many, entire, restrict,
# Nearest to during: from, lasts, in, synchronized, were, rte, after, increased,
# Nearest to from: the, in, a, to, of, as, and, is,
# Nearest to also: the, of, in, is, and, between, other, are,
# Nearest to had: was, as, been, began, but, lacked, earlier, that,
# Nearest to use: used, pronounce, preferred, usemodwiki, sturdy, expressions, reliance, handel,
# Nearest to brother: mctell, father, elder, succession, fulgencio, son, mother, sister,
# Nearest to existence: popper, exists, eroding, souls, reproduced, toponyms, dieu, impregnate,
# Nearest to dr: reentry, hometown, newbery, roadside, glenfinnan, hospitaller, contradiction, roh,
# Nearest to institute: professor, technology, vl, university, nanyang, professors, minneapolis, lab,
# Nearest to animals: flagella, kinsey, agouti, nests, biomechanical, today, impregnated, mozi,
# Nearest to scale: octave, execute, scales, chromatic, negus, davey, marlow, attracting,
# Nearest to grand: cleese, coulthard, assailed, spreading, adiabat, slam, grands, ashley,
# Nearest to accepted: astrophysics, that, urgently, not, the, did, counsel, theresia,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8899 0.3598 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8360 0.3596 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9370 0.3568 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9216 0.3500 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8970 0.3499 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8531 0.3510 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8314 0.3472 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8610 0.3533 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7339 0.3492 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8662 0.3485 sec/batch
# Nearest to can: be, say, will, so, or, physical, if, re,
# Nearest to which: the, of, a, from, in, that, is, it,
# Nearest to their: to, they, them, were, from, always, have, restrict,
# Nearest to during: synchronized, from, lasts, rte, were, increased, after, padding,
# Nearest to from: the, in, a, to, of, as, and, which,
# Nearest to also: the, in, of, other, and, is, for, a,
# Nearest to had: was, been, he, as, began, but, lacked, died,
# Nearest to use: used, expressions, pronounce, preferred, sturdy, usemodwiki, kinematic, dyes,
# Nearest to brother: mctell, father, fulgencio, elder, succession, mother, son, sister,
# Nearest to existence: popper, exists, eroding, souls, reproduced, decoherence, toponyms, dieu,
# Nearest to dr: reentry, roadside, hometown, newbery, roh, glenfinnan, contradiction, hospitaller,
# Nearest to institute: professor, technology, vl, lab, nanyang, minneapolis, university, professors,
# Nearest to animals: agouti, kinsey, flagella, nests, mozi, impregnated, shinto, biomechanical,
# Nearest to scale: octave, execute, scales, chromatic, keyed, harmonically, sectors, davey,
# Nearest to grand: cleese, coulthard, assailed, spreading, slam, adiabat, carnot, grands,
# Nearest to accepted: astrophysics, urgently, not, counsel, that, did, theresia, proselytes,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8810 0.3553 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8634 0.3489 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
