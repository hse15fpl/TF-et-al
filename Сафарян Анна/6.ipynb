# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time
import random
import math

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %%
text[:1000]
# Out:
# ' anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti'

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(int_words[:30])
# Out:
# [5233, 3080, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10571, 133, 0, 27349, 1, 0, 102, 854, 2, 0, 15067, 58112, 1, 0, 150, 854, 3580]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter

def subsampling(int_words, threshold):
    p = np.random.random() # порог вероятности для отбрасывания
    print(p)
    word_count = Counter(int_words) # подсчёт слов
    word_freq = {word: count/len(int_words) for word, count in word_count.items()} # относительная частота
    p_drop = {word:(1-np.sqrt(threshold/word_freq[word])) for word in word_freq} # вероятность отбрасывания
    print(p_drop)
    train_words = [word for word in int_words if p_drop[word]<p] # если вероятность отбрасывания меньше порога
    return train_words

train_words = subsampling(int_words, threshold=1e-5)
# Out:
# 0.28765580937250235
# {5233: 0.25803314192489146, 3080: 0.4599825339524992, 11: 0.9644267615025448, 5: 0.9773753623879587, 194: 0.8479917006734952, 1: 0.9832378119313352, 3133: 0.45568334430257695, 45: 0.9239088422795724, 58: 0.9143476584471071, 155: 0.8593497455736082, 127: 0.8719431999366315, 741: 0.7289825504731466, 476: 0.778893601917191, 10571: -0.19915915224535286, 133: 0.8684093473492618, 0: 0.9874637657774047, 27349: -1.5830678659299684, 102: 0.8814457705299201, 854: 0.7132755043218617, 2: 0.9799907379071721, 15067: -0.5662149484364791, 58112: -4.272665202090242, 150: 0.8618186254884372, 3580: 0.4111112159329233, 10: 0.9698214198790636, 190: 0.8496385533068163, 4: 0.9788301854663046, 10712: -0.20963235679130676, 214: 0.8389728726654947, 6: 0.9770382990950545, 1324: 0.6487490761030492, 104: 0.8811197752484013, 454: 0.7817532675894523, 19: 0.9609717631821799, 2731: 0.49458371591885264, 362: 0.7998763947382689, 3672: 0.401708458826014, 708: 0.7349270180451688, 371: 0.797479619423606, 26: 0.9523071655474, 40: 0.9336285805499689, 36: 0.938677501290233, 53: 0.9189348209710559, 539: 0.7658711969491824, 97: 0.8842267112009115, 1423: 0.635282121659084, 2757: 0.4918527705367808, 18: 0.9613788930888291, 567: 0.7592950682080766, 686: 0.7390174750722174, 7088: 0.09352088593478713, 247: 0.8286010618921413, 1052: 0.6868490999779862, 27: 0.952155892625934, 320: 0.8090958520417412, 248: 0.828343899049687, 44611: -3.0841889035645744, 2877: 0.48004801680364584, 792: 0.7201559874474668, 186: 0.8504271147065035, 200: 0.8453003140714279, 602: 0.7540715966985536, 1134: 0.6742536559505578, 2621: 0.5072490701239205, 25: 0.9533127303087054, 8983: -0.06888108825159689, 279: 0.8193791321377977, 31: 0.9478273496542321, 4147: 0.35342430813300507, 141: 0.8659732515984259, 59: 0.9142910961074863, 6437: 0.150233059707632, 4186: 0.3501587535639029, 153: 0.8605762145149576, 32: 0.946752525433321, 1137: 0.6740462402376914, 447: 0.7828050651928495, 344: 0.8032030401208085, 1818: 0.5919889169248271, 4860: 0.290108748381932, 6753: 0.12122246631829292, 7573: 0.05044536755382001, 1774: 0.5958031263917645, 566: 0.7594203809793247, 93: 0.8863044036750649, 11064: -0.2370651492489142, 51: 0.9192207324390971, 89: 0.8908883170301986, 270: 0.821257028136983, 37: 0.938451611928361, 5948: 0.19436326750384458, 4861: 0.290108748381932, 20299: -0.992880124462129, 28: 0.9508125358605267, 53721: -3.8815394234664486, 41: 0.9313149884988742, 317: 0.8096771187392884, 25636: -1.4407697117332243, 527: 0.7681458182702706, 258: 0.8233425463216144, 1206: 0.6646214787308851, 1576: 0.6173127800139522, 15200: -0.5778598295764568, 332: 0.8060637431980097, 764: 0.7255779806661652, 160: 0.8577550589963036, 406: 0.7895977528011476, 5690: 0.21689252578176044, 755: 0.7265637836522414, 4105: 0.3574378521408329, 1131: 0.6749765049657859, 4331: 0.33832712207970306, 1536: 0.6216072050155588, 8117: 0.0065123592577044365, 98: 0.8838434013266906, 1407: 0.6368713138737907, 2033: 0.5682878183080433, 8174: 0.000581037065508716, 46: 0.9235671685358116, 693: 0.7365861600417876, 4148: 0.35342430813300507, 246: 0.8286915496792353, 76: 0.8974488491479711, 948: 0.7013345279897205, 78: 0.8965082487782162, 310: 0.8121492125610255, 30: 0.9480993480329353, 4778: 0.29645663666341393, 507: 0.7731706147376247, 139: 0.866703335979051, 2312: 0.5378528234381418, 3553: 0.41354465106995586, 364: 0.7989084393675961, 23: 0.9582294627884679, 1821: 0.5913767469135378, 1902: 0.5822880739815113, 8399: -0.021047225891143606, 753: 0.7271745421016114, 1732: 0.5997047319377293, 8040: 0.012339316500350805, 24172: -1.3196634210800444, 275: 0.8202036089125757, 1693: 0.6044264737951409, 151: 0.8615330281299884, 1032: 0.6891252669444243, 95: 0.8850458829722607, 224: 0.835762970842619, 17: 0.9615463298924405, 1813: 0.5921923630023351, 24: 0.9572447564699361, 1556: 0.6196432153780096, 8118: 0.0065123592577044365, 1465: 0.6308395963882756, 12743: -0.3767797985285677, 6130: 0.17821663758820094, 4187: 0.3501587535639029, 21148: -1.0681094426230606, 2427: 0.5 ...

# %%
print(len(int_words))
print(len(train_words))
# Out:
# 16680599
# 2441404

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    n_words = np.random.randint(1,window_size+1) # сколько слов берём из окна
    # задаём границы окон в зависимости от индекса
    if idx<n_words: # спереди маловато
        l_idx = 0 # берём сначала
    else: 
        l_idx = idx - n_words
    r_idx = idx+n_words
    
    left_window = words[l_idx:idx]
    right_window = words[idx+1:r_idx+1]
    
    word_window = list(set(left_window + right_window))
    return word_window

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name = 'inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab,n_embedding],-1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=1.0/math.sqrt(n_embedding))) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# Џ®¤Ї ЇЄ  Ё«Ё д ©« checkpoints г¦Ґ бгйҐбвўгҐв.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 2000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 4.0877 0.6800 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 4.1128 0.6973 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 4.0743 0.6302 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 4.0626 0.6521 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 4.0552 0.6386 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 4.0379 0.6638 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 3.9847 0.7009 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 3.9747 0.6331 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 4.0054 0.7740 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 3.9577 0.6750 sec/batch
# Nearest to six: butterfly, cine, cccc, hermon, gambia, jie, rims, ottavio,
# Nearest to most: cleverly, salination, rochester, factorizations, purchaser, amorphous, cucurbitaceae, expensive,
# Nearest to such: zubr, liquified, showgirls, koenig, almagro, winthrop, rioted, pleadings,
# Nearest to american: waved, nazi, shoppers, premier, mol, tarquinius, letsie, johannine,
# Nearest to used: colloquialisms, albeniz, vos, momenta, bradshaw, indicts, reformation, muriel,
# Nearest to by: catapulted, enclosing, vdp, sikh, gratian, mercenary, kitakyushu, gophers,
# Nearest to after: recompilation, willows, motoren, keiretsu, dl, vacuoles, slits, fulcrum,
# Nearest to for: marva, ash, zealot, contending, capita, fouled, fad, amazona,
# Nearest to shown: eur, gheg, prebiotic, supernovae, integer, mlm, spartans, magus,
# Nearest to prince: cruz, caen, aventine, martius, interpolated, antinomies, andorran, formations,
# Nearest to discovered: ambition, ksh, kom, woodworking, reuse, exclude, unifying, unsatisfactory,
# Nearest to bible: fora, vah, jpl, radiological, tactician, reanimation, mourner, hatchlings,
# Nearest to taking: tajiks, signalling, karachi, australopithecines, bootlegged, interfaces, koala, dictates,
# Nearest to defense: chandra, karabiner, multilingual, using, sufficiently, poses, heydrich, benefited,
# Nearest to recorded: ote, berklee, murdering, adin, sabina, exegesis, inflatable, successive,
# Nearest to arts: modernized, stockpiled, mole, orbit, braunschweig, concrete, editors, slugger,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 3.9565 0.6943 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 3.8996 0.6776 sec/batch
# Epoch 2/10 Iteration: 1300 Avg. Training loss: 3.8808 0.4985 sec/batch
# Epoch 2/10 Iteration: 1400 Avg. Training loss: 3.7650 0.5894 sec/batch
# Epoch 2/10 Iteration: 1500 Avg. Training loss: 3.7636 0.6259 sec/batch
# Epoch 2/10 Iteration: 1600 Avg. Training loss: 3.6921 0.6124 sec/batch
# Epoch 2/10 Iteration: 1700 Avg. Training loss: 3.6646 0.7372 sec/batch
# Epoch 2/10 Iteration: 1800 Avg. Training loss: 3.6370 0.6042 sec/batch
# Epoch 2/10 Iteration: 1900 Avg. Training loss: 3.6433 0.6050 sec/batch
# Epoch 2/10 Iteration: 2000 Avg. Training loss: 3.5824 0.6242 sec/batch
# Nearest to six: butterfly, cine, cccc, jie, hermon, gambia, rims, mamie,
# Nearest to most: cleverly, salination, rochester, factorizations, purchaser, amorphous, haggard, expensive,
# Nearest to such: zubr, showgirls, koenig, winthrop, almagro, rioted, pleadings, liquified,
# Nearest to american: waved, nazi, shoppers, tarquinius, premier, mol, chin, tyres,
# Nearest to used: albeniz, colloquialisms, vos, momenta, indicts, reformation, attainment, bradshaw,
# Nearest to by: catapulted, vdp, enclosing, sikh, gratian, gophers, mercenary, kitakyushu,
# Nearest to after: recompilation, willows, motoren, keiretsu, vacuoles, dl, uranhay, fulcrum,
# Nearest to for: marva, ash, zealot, capita, amazona, fouled, rheumatology, contending,
# Nearest to shown: eur, prebiotic, gheg, supernovae, integer, magus, mlm, cpes,
# Nearest to prince: caen, cruz, martius, aventine, antinomies, interpolated, andorran, historically,
# Nearest to discovered: ambition, ksh, woodworking, kom, acls, gough, exclude, unifying,
# Nearest to bible: fora, vah, radiological, jpl, tactician, reanimation, hatchlings, mourner,
# Nearest to taking: tajiks, signalling, karachi, bootlegged, australopithecines, interfaces, bushy, koala,
# Nearest to defense: karabiner, chandra, multilingual, using, heydrich, poses, reckoning, colombia,
# Nearest to recorded: ote, berklee, adin, murdering, sabina, hatchet, exegesis, inflatable,
# Nearest to arts: modernized, stockpiled, orbit, mole, slugger, concrete, braunschweig, denys,
# Epoch 2/10 Iteration: 2100 Avg. Training loss: 3.5951 0.5916 sec/batch
# Epoch 2/10 Iteration: 2200 Avg. Training loss: 3.5952 0.7865 sec/batch
# Epoch 2/10 Iteration: 2300 Avg. Training loss: 3.5171 0.6368 sec/batch
# Epoch 2/10 Iteration: 2400 Avg. Training loss: 3.5001 0.6266 sec/batch
# Epoch 3/10 Iteration: 2500 Avg. Training loss: 3.4909 0.4286 sec/batch
# Epoch 3/10 Iteration: 2600 Avg. Training loss: 3.4326 0.7121 sec/batch
# Epoch 3/10 Iteration: 2700 Avg. Training loss: 3.3805 0.5778 sec/batch
# Epoch 3/10 Iteration: 2800 Avg. Training loss: 3.3216 0.5983 sec/batch
# Epoch 3/10 Iteration: 2900 Avg. Training loss: 3.3471 0.6084 sec/batch
# Epoch 3/10 Iteration: 3000 Avg. Training loss: 3.3375 0.5510 sec/batch
# Nearest to six: butterfly, cine, jie, cccc, hermon, devises, rims, mamie,
# Nearest to most: cleverly, salination, rochester, factorizations, purchaser, unwritten, dumnonii, expensive,
# Nearest to such: zubr, koenig, showgirls, winthrop, rioted, almagro, pleadings, bisexuality,
# Nearest to american: waved, nazi, chin, tarquinius, tyres, shoppers, premier, mol,
# Nearest to used: colloquialisms, albeniz, vos, momenta, attainment, reformation, indicts, bradshaw,
# Nearest to by: catapulted, vdp, enclosing, sikh, gratian, gophers, cruijff, mercenary,
# Nearest to after: recompilation, willows, motoren, keiretsu, vacuoles, dl, uranhay, fulcrum,
# Nearest to for: marva, zealot, capita, ash, amazona, pentagram, optative, rheumatology,
# Nearest to shown: eur, gheg, prebiotic, supernovae, magus, integer, mlm, cpes,
# Nearest to prince: caen, martius, cruz, antinomies, aventine, interpolated, andorran, historically,
# Nearest to discovered: ambition, ksh, kom, woodworking, gough, acls, exclude, eisler,
# Nearest to bible: vah, radiological, fora, jpl, tactician, reanimation, mourner, hatchlings,
# Nearest to taking: tajiks, signalling, karachi, bootlegged, interfaces, australopithecines, bushy, koala,
# Nearest to defense: karabiner, using, multilingual, chandra, dye, sufficiently, daniell, colombia,
# Nearest to recorded: ote, berklee, murdering, adin, sabina, mollymawks, scherer, inflatable,
# Nearest to arts: stockpiled, modernized, orbit, mole, slugger, concrete, denys, editors,
# Epoch 3/10 Iteration: 3100 Avg. Training loss: 3.3558 0.6001 sec/batch
# Epoch 3/10 Iteration: 3200 Avg. Training loss: 3.3150 0.5646 sec/batch
# Epoch 3/10 Iteration: 3300 Avg. Training loss: 3.2870 0.5740 sec/batch
# Epoch 3/10 Iteration: 3400 Avg. Training loss: 3.3542 0.5558 sec/batch
# Epoch 3/10 Iteration: 3500 Avg. Training loss: 3.3199 0.5728 sec/batch
# Epoch 3/10 Iteration: 3600 Avg. Training loss: 3.3257 0.5741 sec/batch
# Epoch 4/10 Iteration: 3700 Avg. Training loss: 3.2601 0.2292 sec/batch
# Epoch 4/10 Iteration: 3800 Avg. Training loss: 3.2397 0.6213 sec/batch
# Epoch 4/10 Iteration: 3900 Avg. Training loss: 3.1788 0.6889 sec/batch
# Epoch 4/10 Iteration: 4000 Avg. Training loss: 3.1687 0.6744 sec/batch
# Nearest to six: butterfly, cine, jie, cccc, devises, unionised, improvisation, hermon,
# Nearest to most: cleverly, rochester, salination, purchaser, factorizations, canola, hamburg, android,
# Nearest to such: zubr, koenig, showgirls, winthrop, rioted, bisexuality, anterior, almagro,
# Nearest to american: waved, chin, nazi, tyres, tarquinius, shoppers, premier, matures,
# Nearest to used: colloquialisms, albeniz, vos, momenta, attainment, reformation, indicts, eightfold,
# Nearest to by: catapulted, vdp, enclosing, sikh, gratian, gophers, cruijff, suburban,
# Nearest to after: recompilation, willows, keiretsu, motoren, vacuoles, dl, uranhay, fulcrum,
# Nearest to for: marva, zealot, capita, ash, ruhollah, contending, macgregor, amazona,
# Nearest to shown: eur, gheg, prebiotic, supernovae, magus, integer, mlm, cpes,
# Nearest to prince: caen, martius, antinomies, cruz, andorran, aventine, interpolated, historically,
# Nearest to discovered: ambition, kom, ksh, woodworking, acls, gough, eisler, unifying,
# Nearest to bible: vah, radiological, jpl, fora, tactician, mourner, reanimation, getaway,
# Nearest to taking: signalling, tajiks, karachi, interfaces, bootlegged, australopithecines, bushy, workstations,
# Nearest to defense: karabiner, using, sufficiently, dye, daniell, multilingual, colombia, poses,
# Nearest to recorded: ote, berklee, murdering, adin, hatchet, mollymawks, sabina, hecht,
# Nearest to arts: stockpiled, modernized, orbit, slugger, concrete, mole, warhammer, editors,
# Epoch 4/10 Iteration: 4100 Avg. Training loss: 3.1578 0.7030 sec/batch
# Epoch 4/10 Iteration: 4200 Avg. Training loss: 3.1457 0.6184 sec/batch
# Epoch 4/10 Iteration: 4300 Avg. Training loss: 3.1741 0.6598 sec/batch
# Epoch 4/10 Iteration: 4400 Avg. Training loss: 3.1451 0.6293 sec/batch
# Epoch 4/10 Iteration: 4500 Avg. Training loss: 3.1704 0.6369 sec/batch
# Epoch 4/10 Iteration: 4600 Avg. Training loss: 3.1583 0.6704 sec/batch
# Epoch 4/10 Iteration: 4700 Avg. Training loss: 3.1667 0.6123 sec/batch
# Epoch 4/10 Iteration: 4800 Avg. Training loss: 3.1022 0.6132 sec/batch
# Epoch 5/10 Iteration: 4900 Avg. Training loss: 3.1389 0.1311 sec/batch
# Epoch 5/10 Iteration: 5000 Avg. Training loss: 3.1160 0.6503 sec/batch
# Nearest to six: butterfly, cine, jie, cccc, devises, unionised, improvisation, slipping,
# Nearest to most: cleverly, rochester, salination, purchaser, factorizations, canola, hamburg, dumnonii,
# Nearest to such: zubr, showgirls, koenig, rioted, anterior, bisexuality, winthrop, manmohan,
# Nearest to american: waved, tyres, nazi, chin, matures, tarquinius, stockings, crests,
# Nearest to used: colloquialisms, albeniz, momenta, vos, attainment, reformation, eightfold, entail,
# Nearest to by: catapulted, vdp, enclosing, gratian, sikh, cruijff, suburban, gophers,
# Nearest to after: recompilation, willows, keiretsu, motoren, vacuoles, uranhay, dl, demo,
# Nearest to for: marva, zealot, ruhollah, ash, capita, macgregor, contending, pentagram,
# Nearest to shown: eur, gheg, prebiotic, supernovae, magus, integer, mlm, cpes,
# Nearest to prince: caen, martius, antinomies, andorran, cruz, interpolated, odi, aventine,
# Nearest to discovered: ambition, ksh, kom, gough, woodworking, acls, unifying, eisler,
# Nearest to bible: vah, radiological, jpl, fora, tactician, mourner, reanimation, hatchlings,
# Nearest to taking: signalling, interfaces, tajiks, karachi, bootlegged, workstations, bushy, australopithecines,
# Nearest to defense: karabiner, using, dye, sufficiently, daniell, colombia, multilingual, corrode,
# Nearest to recorded: ote, berklee, murdering, adin, hatchet, sabina, hecht, mollymawks,
# Nearest to arts: modernized, stockpiled, orbit, slugger, concrete, mole, warhammer, editors,
# Epoch 5/10 Iteration: 5100 Avg. Training loss: 3.0239 0.7295 sec/batch
# Epoch 5/10 Iteration: 5200 Avg. Training loss: 2.9993 0.6587 sec/batch
# Epoch 5/10 Iteration: 5300 Avg. Training loss: 2.9960 0.6414 sec/batch
# Epoch 5/10 Iteration: 5400 Avg. Training loss: 3.0542 0.5406 sec/batch
# Epoch 5/10 Iteration: 5500 Avg. Training loss: 2.9722 0.5460 sec/batch
# Epoch 5/10 Iteration: 5600 Avg. Training loss: 3.0214 0.5482 sec/batch
# Epoch 5/10 Iteration: 5700 Avg. Training loss: 3.0330 0.5481 sec/batch
# Epoch 5/10 Iteration: 5800 Avg. Training loss: 2.9824 0.5366 sec/batch
# Epoch 5/10 Iteration: 5900 Avg. Training loss: 3.0933 0.5377 sec/batch
# Epoch 5/10 Iteration: 6000 Avg. Training loss: 2.9670 0.5339 sec/batch
# Nearest to six: butterfly, cine, jie, cccc, devises, unionised, improvisation, slipping,
# Nearest to most: cleverly, rochester, salination, purchaser, factorizations, canola, dumnonii, expensive,
# Nearest to such: zubr, showgirls, koenig, anterior, rioted, bisexuality, winthrop, manmohan,
# Nearest to american: waved, tyres, nazi, matures, crests, chin, tarquinius, shoppers,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, attainment, reformation, entail,
# Nearest to by: catapulted, vdp, enclosing, gratian, sikh, gophers, cruijff, kitakyushu,
# Nearest to after: recompilation, willows, keiretsu, motoren, uranhay, demo, vacuoles, dl,
# Nearest to for: ruhollah, marva, zealot, capita, ash, macgregor, contending, pentagram,
# Nearest to shown: eur, gheg, prebiotic, supernovae, magus, integer, mlm, ba,
# Nearest to prince: caen, martius, antinomies, odi, andorran, recitation, interpolated, jesuits,
# Nearest to discovered: ambition, ksh, kom, gough, woodworking, acls, unifying, pizza,
# Nearest to bible: vah, radiological, jpl, tactician, mourner, fora, reanimation, proscription,
# Nearest to taking: signalling, interfaces, tajiks, karachi, bootlegged, bushy, workstations, hafizullah,
# Nearest to defense: karabiner, using, daniell, dye, sufficiently, uncover, tanning, colombia,
# Nearest to recorded: ote, berklee, murdering, adin, landers, hecht, maxillofacial, hatchet,
# Nearest to arts: stockpiled, modernized, orbit, slugger, concrete, warhammer, mole, denys,
# Epoch 5/10 Iteration: 6100 Avg. Training loss: 2.9734 0.5367 sec/batch
# Epoch 6/10 Iteration: 6200 Avg. Training loss: 3.0022 0.5405 sec/batch
# Epoch 6/10 Iteration: 6300 Avg. Training loss: 2.8799 0.5475 sec/batch
# Epoch 6/10 Iteration: 6400 Avg. Training loss: 2.9033 0.5346 sec/batch
# Epoch 6/10 Iteration: 6500 Avg. Training loss: 2.8692 0.5384 sec/batch
# Epoch 6/10 Iteration: 6600 Avg. Training loss: 2.9062 0.5472 sec/batch
# Epoch 6/10 Iteration: 6700 Avg. Training loss: 2.9304 0.7863 sec/batch
# Epoch 6/10 Iteration: 6800 Avg. Training loss: 2.9413 0.6436 sec/batch
# Epoch 6/10 Iteration: 6900 Avg. Training loss: 2.8915 0.6118 sec/batch
# Epoch 6/10 Iteration: 7000 Avg. Training loss: 2.8545 0.5728 sec/batch
# Nearest to six: butterfly, cine, jie, devises, cccc, improvisation, ovens, qam,
# Nearest to most: cleverly, rochester, salination, purchaser, canola, factorizations, dumnonii, sitar,
# Nearest to such: zubr, showgirls, koenig, bisexuality, rioted, anterior, winthrop, manmohan,
# Nearest to american: waved, tyres, crests, nazi, stockings, matures, belts, chin,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, reformation, ranged, attainment,
# Nearest to by: catapulted, vdp, enclosing, cruijff, gophers, gratian, sikh, kitakyushu,
# Nearest to after: recompilation, willows, keiretsu, uranhay, demo, motoren, vacuoles, flattening,
# Nearest to for: ruhollah, marva, zealot, capita, ash, macgregor, contending, optative,
# Nearest to shown: eur, prebiotic, gheg, supernovae, magus, ba, integer, mlm,
# Nearest to prince: caen, odi, martius, antinomies, andorran, interpolated, recitation, historically,
# Nearest to discovered: ambition, ksh, kom, gough, woodworking, photographic, pizza, acls,
# Nearest to bible: vah, radiological, jpl, tactician, mourner, fora, reanimation, proscription,
# Nearest to taking: signalling, interfaces, karachi, bushy, parl, tajiks, bootlegged, hafizullah,
# Nearest to defense: karabiner, daniell, using, dye, uncover, sufficiently, corrode, tanning,
# Nearest to recorded: ote, berklee, murdering, adin, hecht, landers, lafur, maxillofacial,
# Nearest to arts: orbit, stockpiled, modernized, slugger, warhammer, concrete, denys, jelena,
# Epoch 6/10 Iteration: 7100 Avg. Training loss: 2.9951 0.5729 sec/batch
# Epoch 6/10 Iteration: 7200 Avg. Training loss: 2.8828 0.5733 sec/batch
# Epoch 6/10 Iteration: 7300 Avg. Training loss: 2.8747 0.5749 sec/batch
# Epoch 7/10 Iteration: 7400 Avg. Training loss: 2.8617 0.4620 sec/batch
# Epoch 7/10 Iteration: 7500 Avg. Training loss: 2.8280 0.6001 sec/batch
# Epoch 7/10 Iteration: 7600 Avg. Training loss: 2.8123 0.5664 sec/batch
# Epoch 7/10 Iteration: 7700 Avg. Training loss: 2.7406 0.5579 sec/batch
# Epoch 7/10 Iteration: 7800 Avg. Training loss: 2.7912 0.6767 sec/batch
# Epoch 7/10 Iteration: 7900 Avg. Training loss: 2.7813 0.6623 sec/batch
# Epoch 7/10 Iteration: 8000 Avg. Training loss: 2.8838 0.7280 sec/batch
# Nearest to six: butterfly, cine, jie, improvisation, devises, cccc, qam, unionised,
# Nearest to most: cleverly, rochester, salination, purchaser, canola, factorizations, dumnonii, unwritten,
# Nearest to such: zubr, showgirls, bisexuality, koenig, anterior, rioted, winthrop, manmohan,
# Nearest to american: waved, tyres, matures, stockings, crests, belts, nazi, chin,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, reformation, ranged, peyote,
# Nearest to by: catapulted, vdp, enclosing, cruijff, gophers, gratian, kitakyushu, sikh,
# Nearest to after: recompilation, willows, keiretsu, uranhay, demo, vacuoles, motoren, dl,
# Nearest to for: ruhollah, marva, zealot, capita, ash, macgregor, contending, breezes,
# Nearest to shown: eur, gheg, prebiotic, magus, supernovae, ba, integer, mlm,
# Nearest to prince: caen, odi, antinomies, martius, interpolated, andorran, recitation, historically,
# Nearest to discovered: ambition, ksh, kom, gough, woodworking, pizza, photographic, moored,
# Nearest to bible: vah, radiological, tactician, mourner, jpl, reanimation, fora, proscription,
# Nearest to taking: signalling, interfaces, karachi, parl, bushy, bootlegged, merits, hafizullah,
# Nearest to defense: karabiner, daniell, using, uncover, sufficiently, kohl, dye, corrode,
# Nearest to recorded: ote, berklee, murdering, adin, landers, hecht, lafur, metallurgical,
# Nearest to arts: orbit, stockpiled, warhammer, slugger, modernized, concrete, denys, coloane,
# Epoch 7/10 Iteration: 8100 Avg. Training loss: 2.7966 0.7079 sec/batch
# Epoch 7/10 Iteration: 8200 Avg. Training loss: 2.7880 0.7235 sec/batch
# Epoch 7/10 Iteration: 8300 Avg. Training loss: 2.9688 0.7626 sec/batch
# Epoch 7/10 Iteration: 8400 Avg. Training loss: 2.7896 0.8421 sec/batch
# Epoch 7/10 Iteration: 8500 Avg. Training loss: 2.8518 0.6369 sec/batch
# Epoch 8/10 Iteration: 8600 Avg. Training loss: 2.8319 0.4009 sec/batch
# Epoch 8/10 Iteration: 8700 Avg. Training loss: 2.7763 0.6021 sec/batch
# Epoch 8/10 Iteration: 8800 Avg. Training loss: 2.7417 0.7041 sec/batch
# Epoch 8/10 Iteration: 8900 Avg. Training loss: 2.7045 0.7715 sec/batch
# Epoch 8/10 Iteration: 9000 Avg. Training loss: 2.7287 0.5713 sec/batch
# Nearest to six: butterfly, cine, jie, devises, improvisation, qam, unionised, cccc,
# Nearest to most: cleverly, rochester, salination, purchaser, canola, unwritten, dumnonii, factorizations,
# Nearest to such: zubr, showgirls, koenig, bisexuality, anterior, winthrop, beloved, rioted,
# Nearest to american: waved, belts, stockings, tyres, matures, crests, nazi, pups,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, reformation, theorie, ranged,
# Nearest to by: catapulted, vdp, cruijff, enclosing, gophers, sikh, kitakyushu, gratian,
# Nearest to after: recompilation, willows, keiretsu, demo, uranhay, vacuoles, motoren, cristofano,
# Nearest to for: ruhollah, zealot, marva, capita, contending, ash, macgregor, breezes,
# Nearest to shown: eur, gheg, prebiotic, magus, ba, supernovae, integer, ordinary,
# Nearest to prince: caen, odi, martius, antinomies, interpolated, andorran, historically, machaut,
# Nearest to discovered: ambition, ksh, gough, kom, woodworking, pizza, moored, photographic,
# Nearest to bible: vah, radiological, tactician, mourner, jpl, reanimation, fora, proscription,
# Nearest to taking: signalling, interfaces, parl, karachi, merits, hafizullah, bushy, bootlegged,
# Nearest to defense: karabiner, daniell, using, uncover, sufficiently, kohl, tanning, colombia,
# Nearest to recorded: ote, berklee, murdering, landers, lafur, adin, metallurgical, hecht,
# Nearest to arts: stockpiled, warhammer, orbit, slugger, concrete, modernized, coloane, jelena,
# Epoch 8/10 Iteration: 9100 Avg. Training loss: 2.7967 0.6173 sec/batch
# Epoch 8/10 Iteration: 9200 Avg. Training loss: 2.7692 0.5573 sec/batch
# Epoch 8/10 Iteration: 9300 Avg. Training loss: 2.7470 0.5397 sec/batch
# Epoch 8/10 Iteration: 9400 Avg. Training loss: 2.7405 0.5470 sec/batch
# Epoch 8/10 Iteration: 9500 Avg. Training loss: 2.8197 0.5552 sec/batch
# Epoch 8/10 Iteration: 9600 Avg. Training loss: 2.7409 0.5572 sec/batch
# Epoch 8/10 Iteration: 9700 Avg. Training loss: 2.7759 0.7473 sec/batch
# Epoch 9/10 Iteration: 9800 Avg. Training loss: 2.7467 0.2750 sec/batch
# Epoch 9/10 Iteration: 9900 Avg. Training loss: 2.7333 0.6201 sec/batch
# Epoch 9/10 Iteration: 10000 Avg. Training loss: 2.6854 0.5613 sec/batch
# Nearest to six: butterfly, cine, jie, unionised, devises, improvisation, ovens, qam,
# Nearest to most: cleverly, rochester, salination, purchaser, canola, unwritten, factorizations, dumnonii,
# Nearest to such: zubr, showgirls, bisexuality, koenig, beloved, winthrop, anterior, manmohan,
# Nearest to american: waved, belts, tyres, matures, stockings, crests, nazi, pups,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, reformation, attainment, theorie,
# Nearest to by: catapulted, vdp, cruijff, enclosing, gophers, sikh, gratian, kitakyushu,
# Nearest to after: recompilation, willows, keiretsu, uranhay, demo, racehorse, vacuoles, motoren,
# Nearest to for: ruhollah, marva, contending, zealot, capita, ash, breezes, jerzy,
# Nearest to shown: eur, gheg, prebiotic, magus, ba, supernovae, integer, nord,
# Nearest to prince: caen, andorran, antinomies, interpolated, odi, machaut, martius, historically,
# Nearest to discovered: ambition, ksh, gough, kom, woodworking, moored, pizza, tricolore,
# Nearest to bible: vah, radiological, tactician, jpl, mourner, reanimation, fora, proscription,
# Nearest to taking: signalling, interfaces, parl, merits, karachi, hafizullah, yards, bushy,
# Nearest to defense: karabiner, daniell, using, kohl, tanning, uncover, sufficiently, colombia,
# Nearest to recorded: ote, berklee, murdering, lafur, landers, adin, metallurgical, hatchet,
# Nearest to arts: warhammer, orbit, stockpiled, slugger, concrete, modernized, jelena, coloane,
# Epoch 9/10 Iteration: 10100 Avg. Training loss: 2.6764 0.6294 sec/batch
# Epoch 9/10 Iteration: 10200 Avg. Training loss: 2.6903 0.5463 sec/batch
# Epoch 9/10 Iteration: 10300 Avg. Training loss: 2.6984 0.5292 sec/batch
# Epoch 9/10 Iteration: 10400 Avg. Training loss: 2.6881 0.5257 sec/batch
# Epoch 9/10 Iteration: 10500 Avg. Training loss: 2.6886 0.5433 sec/batch
# Epoch 9/10 Iteration: 10600 Avg. Training loss: 2.6965 0.5772 sec/batch
# Epoch 9/10 Iteration: 10700 Avg. Training loss: 2.7271 0.5675 sec/batch
# Epoch 9/10 Iteration: 10800 Avg. Training loss: 2.7320 0.5628 sec/batch
# Epoch 9/10 Iteration: 10900 Avg. Training loss: 2.6622 0.5815 sec/batch
# Epoch 10/10 Iteration: 11000 Avg. Training loss: 2.7353 0.1104 sec/batch
# Nearest to six: butterfly, cine, improvisation, unionised, jie, qam, ovens, devises,
# Nearest to most: rochester, cleverly, salination, unwritten, canola, purchaser, factorizations, sitar,
# Nearest to such: zubr, showgirls, bisexuality, beloved, koenig, winthrop, anterior, rioted,
# Nearest to american: waved, stockings, belts, tyres, matures, crests, nazi, pups,
# Nearest to used: colloquialisms, albeniz, momenta, vos, eightfold, reformation, ranged, theorie,
# Nearest to by: catapulted, vdp, cruijff, enclosing, sikh, gophers, gratian, kitakyushu,
# Nearest to after: recompilation, willows, keiretsu, uranhay, demo, racehorse, admirable, vacuoles,
# Nearest to for: ruhollah, marva, zealot, breezes, contending, ash, capita, jerzy,
# Nearest to shown: eur, gheg, prebiotic, ba, magus, supernovae, integer, picot,
# Nearest to prince: caen, antinomies, andorran, odi, interpolated, machaut, mazovia, historically,
# Nearest to discovered: gough, ksh, ambition, kom, woodworking, pizza, moored, kato,
# Nearest to bible: vah, tactician, radiological, mourner, jpl, reanimation, proscription, fora,
# Nearest to taking: signalling, interfaces, parl, merits, hafizullah, karachi, repel, centralized,
# Nearest to defense: karabiner, daniell, using, kohl, tanning, sufficiently, colombia, uncover,
# Nearest to recorded: ote, berklee, murdering, lafur, landers, adin, metallurgical, hatchet,
# Nearest to arts: warhammer, orbit, slugger, stockpiled, concrete, clu, jelena, coloane,
# Epoch 10/10 Iteration: 11100 Avg. Training loss: 2.7199 0.5724 sec/batch
# Epoch 10/10 Iteration: 11200 Avg. Training loss: 2.6145 0.5655 sec/batch
# Epoch 10/10 Iteration: 11300 Avg. Training loss: 2.6543 0.5684 sec/batch
# Epoch 10/10 Iteration: 11400 Avg. Training loss: 2.6166 0.5627 sec/batch
# Epoch 10/10 Iteration: 11500 Avg. Training loss: 2.6813 0.5613 sec/batch
# Epoch 10/10 Iteration: 11600 Avg. Training loss: 2.6065 0.5957 sec/batch
# Epoch 10/10 Iteration: 11700 Avg. Training loss: 2.6481 0.5535 sec/batch
# Epoch 10/10 Iteration: 11800 Avg. Training loss: 2.5866 0.5417 sec/batch
# Epoch 10/10 Iteration: 11900 Avg. Training loss: 2.6226 0.5340 sec/batch
# Epoch 10/10 Iteration: 12000 Avg. Training loss: 2.7549 0.5430 sec/batch
# Nearest to six: butterfly, cine, improvisation, unionised, jie, qam, ovens, devises,
# Nearest to most: cleverly, rochester, salination, purchaser, unwritten, canola, factorizations, sitar,
# Nearest to such: zubr, beloved, showgirls, bisexuality, koenig, manmohan, winthrop, https,
# Nearest to american: waved, belts, stockings, tyres, matures, crests, nazi, pups,
# Nearest to used: colloquialisms, albeniz, vos, eightfold, momenta, reformation, ranged, theorie,
# Nearest to by: catapulted, vdp, cruijff, gophers, gratian, kitakyushu, sikh, enclosing,
# Nearest to after: recompilation, willows, keiretsu, demo, uranhay, racehorse, admirable, vacuoles,
# Nearest to for: ruhollah, marva, contending, zealot, ash, capita, breezes, jerzy,
# Nearest to shown: eur, gheg, prebiotic, ba, magus, supernovae, integer, picot,
# Nearest to prince: caen, andorran, odi, interpolated, antinomies, machaut, mazovia, sartre,
# Nearest to discovered: ksh, gough, woodworking, kom, ambition, moored, tricolore, pizza,
# Nearest to bible: vah, tactician, radiological, mourner, jpl, reanimation, proscription, fora,
# Nearest to taking: signalling, interfaces, parl, merits, karachi, hafizullah, repel, easing,
# Nearest to defense: karabiner, daniell, using, kohl, sufficiently, tanning, colombia, corrode,
# Nearest to recorded: ote, berklee, murdering, lafur, landers, adin, metallurgical, hecht,
# Nearest to arts: warhammer, orbit, slugger, stockpiled, concrete, clu, jelena, coloane,
# Epoch 10/10 Iteration: 12100 Avg. Training loss: 2.5904 0.5542 sec/batch
# Epoch 10/10 Iteration: 12200 Avg. Training loss: 2.6997 0.5489 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
