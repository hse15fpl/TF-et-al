# %%
#В списке указаны: 1)Фамилия, инициалы студента 2)Номер зачетной книжки 3)Оценки по 4 предметам
list = [['Семенова Т.А.', '11234', 5, 4, 5, 4],
        ['Артюхов А.А.', '11234', 5, 3, 4, 4],
        ['Халева А.И.', '01234', 4, 4, 4, 4],
        ['Ворошилов Е.В.', '31234', 5, 4, 5, 5],
        ['Воеводина В.А.', '12234', 5, 4, 5, 4],
        ['Дымов Р.В.', '03234', 5, 5, 5, 5],
        ['Никитин К.А.', '21134', 5, 5, 5, 4],
        ['Ревина Е.А.', '11134', 3, 4, 3, 4],
        ['Пугин К.О.', '11235', 4, 4, 5, 2],
        ['Смирнов В.П.', '11236', 5, 4, 3, 4],
        ['Зиновьев А.А.', '11237', 4, 4, 2, 4],
        ['Алиев Р.М.', '11238', 3, 4, 3, 3],
        ['Яковлев В.К.', '11334', 5, 5, 5, 4],
        ['Бодров В.А.', '11239', 5, 5, 5, 5],
        ['Васильева Е.Л.', '11214', 5, 4, 5, 3],
        ['Белкина Я.А.', '11534', 3, 3, 5, 4],
        ['Ковыляев М.М.', '17234', 5, 5, 5, 5],
        ['Руков Д.А.', '03234', 5, 4, 5, 4],
        ['Абросимов К.Н.', '22234', 5, 3, 3, 4],
        ['Смирнова Е.А.', '15234', 5, 4, 4, 4],
        ['Ржевский Н.К.', '34234', 5, 4, 4, 5],
        ['Петрова А.А.', '16234', 5, 4, 3, 4],
        ['Миронов И.В.', '13534', 5, 5, 5, 5],
        ['Васнецова Д.А.', '21734', 2, 5, 5, 4],
        ['Богомолов В.Е.', '11434', 5, 4, 3, 4],
        ['Романова Т.В.', '13935', 5, 5, 5, 5],
        ['Копытова Д.В.', '38236', 5, 4, 3, 4],
        ['Савельев С.А.', '11257', 4, 4, 3, 4],
        ['Никулина О.В.', '11568', 4, 4, 3, 3],
        ['Богатырев А.А.', '44334', 4, 5, 4, 4],
        ['Денисова Ю.Ю.', '11243', 5, 5, 5, 5],
        ['Сомова О.Р.', '17214', 3, 5, 5, 3],
        ['Белянина Е.С.', '41534', 3, 3, 5, 4],
        ['Бондаренко А.С.', '37334', 5, 4, 5, 5],
        ['Сушинков Д.С.', '11134', 5, 4, 4, 5]]

#1 Сортировка списка по фамилиям
n = 0 #сортируем по первому элементу списка
def sort_ByAlphabet(i):
    return i[n]
list.sort(key=sort_ByAlphabet)
for i in list:
    print("%7s %3s %4d %3d %4d %3d" % (i[0],i[1],i[2],i[3],i[4],i[5])) #указываем типы аргументов
# Out:
# Абросимов К.Н. 22234    5   3    3   4
# Алиев Р.М. 11238    3   4    3   3
# Артюхов А.А. 11234    5   3    4   4
# Белкина Я.А. 11534    3   3    5   4
# Белянина Е.С. 41534    3   3    5   4
# Богатырев А.А. 44334    4   5    4   4
# Богомолов В.Е. 11434    5   4    3   4
# Бодров В.А. 11239    5   5    5   5
# Бондаренко А.С. 37334    5   4    5   5
# Васильева Е.Л. 11214    5   4    5   3
# Васнецова Д.А. 21734    2   5    5   4
# Воеводина В.А. 12234    5   4    5   4
# Ворошилов Е.В. 31234    5   4    5   5
# Денисова Ю.Ю. 11243    5   5    5   5
# Дымов Р.В. 03234    5   5    5   5
# Зиновьев А.А. 11237    4   4    2   4
# Ковыляев М.М. 17234    5   5    5   5
# Копытова Д.В. 38236    5   4    3   4
# Миронов И.В. 13534    5   5    5   5
# Никитин К.А. 21134    5   5    5   4
# Никулина О.В. 11568    4   4    3   3
# Петрова А.А. 16234    5   4    3   4
# Пугин К.О. 11235    4   4    5   2
# Ревина Е.А. 11134    3   4    3   4
# Ржевский Н.К. 34234    5   4    4   5
# ...

# %%
#2 Вычисляем средний балл студентов и сортируем по убыванию
avg_list = []
for i in list:
    avg = (i[2] + i[3] + i[4] + i[5])/ 4
    avg_list.append([i[0],i[1],avg])
#print(avg_list)
t = 2   #сортируем по второму элементу списка
def sort_ByAvg(i):
    return i[t]

avg_list.sort(key=sort_ByAvg, reverse = True) #сортируем в обратном порядке
print("Cписок студентов по убыванию среднего балла:", avg_list)
# Out:
# Cписок студентов по убыванию среднего балла: [['Бодров В.А.', '11239', 5.0], ['Денисова Ю.Ю.', '11243', 5.0], ['Дымов Р.В.', '03234', 5.0], ['Ковыляев М.М.', '17234', 5.0], ['Миронов И.В.', '13534', 5.0], ['Романова Т.В.', '13935', 5.0], ['Бондаренко А.С.', '37334', 4.75], ['Ворошилов Е.В.', '31234', 4.75], ['Никитин К.А.', '21134', 4.75], ['Яковлев В.К.', '11334', 4.75], ['Воеводина В.А.', '12234', 4.5], ['Ржевский Н.К.', '34234', 4.5], ['Руков Д.А.', '03234', 4.5], ['Семенова Т.А.', '11234', 4.5], ['Сушинков Д.С.', '11134', 4.5], ['Богатырев А.А.', '44334', 4.25], ['Васильева Е.Л.', '11214', 4.25], ['Смирнова Е.А.', '15234', 4.25], ['Артюхов А.А.', '11234', 4.0], ['Богомолов В.Е.', '11434', 4.0], ['Васнецова Д.А.', '21734', 4.0], ['Копытова Д.В.', '38236', 4.0], ['Петрова А.А.', '16234', 4.0], ['Смирнов В.П.', '11236', 4.0], ['Сомова О.Р.', '17214', 4.0], ['Халева А.И.', '01234', 4.0], ['Абросимов К.Н.', '22234', 3.75], ['Белкина Я.А.', '11534', 3.75], ['Белянина Е.С.', '41534', 3.
# ...

# %%
#3 Вычисление среднего балла группы
avg_group = []
for i in avg_list:
    avg_group.append(i[2])
print("Средний балл группы:", sum(avg_group)/len(avg_group))
# Out:
# Средний балл группы: 4.25

# %%
#4 Поиск отличников, хорошистов, имеющих оценки «удовлетворительно» и не сдавших сессию
for i in list:
    if i[2] == 5 and i[3] == 5 and i[4] == 5 and i[5] == 5:
        print("Отлично:", i)
    elif i[2] == 3 or i[3] == 3 or i[4] == 3 or i[5] == 3:
        print("Удовлетворительно:", i)
    elif i[2] == 2 or i[3] == 2 or i[4] == 2 or i[5] == 2:
        print("Сессия не сдана:", i)
    elif i[2] == 4 or i[3] == 4 or i[4] == 4 or i[5] == 4:
        print("Хорошо:", i)
# Out:
# Удовлетворительно: ['Абросимов К.Н.', '22234', 5, 3, 3, 4]
# Удовлетворительно: ['Алиев Р.М.', '11238', 3, 4, 3, 3]
# Удовлетворительно: ['Артюхов А.А.', '11234', 5, 3, 4, 4]
# Удовлетворительно: ['Белкина Я.А.', '11534', 3, 3, 5, 4]
# Удовлетворительно: ['Белянина Е.С.', '41534', 3, 3, 5, 4]
# Хорошо: ['Богатырев А.А.', '44334', 4, 5, 4, 4]
# Удовлетворительно: ['Богомолов В.Е.', '11434', 5, 4, 3, 4]
# Отлично: ['Бодров В.А.', '11239', 5, 5, 5, 5]
# Хорошо: ['Бондаренко А.С.', '37334', 5, 4, 5, 5]
# Удовлетворительно: ['Васильева Е.Л.', '11214', 5, 4, 5, 3]
# Сессия не сдана: ['Васнецова Д.А.', '21734', 2, 5, 5, 4]
# Хорошо: ['Воеводина В.А.', '12234', 5, 4, 5, 4]
# Хорошо: ['Ворошилов Е.В.', '31234', 5, 4, 5, 5]
# Отлично: ['Денисова Ю.Ю.', '11243', 5, 5, 5, 5]
# Отлично: ['Дымов Р.В.', '03234', 5, 5, 5, 5]
# Сессия не сдана: ['Зиновьев А.А.', '11237', 4, 4, 2, 4]
# Отлично: ['Ковыляев М.М.', '17234', 5, 5, 5, 5]
# Удовлетворительно: ['Копытова Д.В.', '38236', 5, 4, 3, 4]
# ...
